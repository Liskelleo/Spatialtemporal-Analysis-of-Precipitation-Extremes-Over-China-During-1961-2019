# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import pandas as pd
sns.set(style='ticks')
Districts = ['All of China','DongBei','HuaBei','HuaDong','HuaNan','HuaZhong','XiBei','XiNan']

filename = os.listdir('C:/Users/***/Desktop/500_100/precip_r')
PRCPTOP_ = []
SDII_ = []
RX1D_ = []
RX5D_ = []
R95p_ = []
R95T_ = []
R99p_ = []
R99T_ = []
CWD_ = []
CDD_ = []
R10MM_ = []
R20MM_ = []
R25MM_ = []
R50MM_ = []
R65MM_ = []
R115MM_ = []
R205MM_ = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/precip_r/{}'.format(i))
    PRCPTOP_.append(data['PRCPTOP'].mean())
    SDII_.append(data['SDII'].mean())
    RX1D_.append(data['RX1D'].mean())
    RX5D_.append(data['RX5D'].mean())
    R95p_.append(data['R95p'].mean())
    R95T_.append(data['R95T'].mean())
    R99p_.append(data['R99p'].mean())
    R99T_.append(data['R99T'].mean())
    CWD_.append(data['CWD'].mean())
    CDD_.append(data['CDD'].mean())
    R10MM_.append(data['R10MM'].mean())
    R20MM_.append(data['R20MM'].mean())
    R25MM_.append(data['R25MM'].mean())
    R50MM_.append(data['R50MM'].mean())
    R65MM_.append(data['R65MM'].mean())
    R115MM_.append(data['R115MM'].mean())
    R205MM_.append(data['R205MM'].mean())
    
filename = os.listdir('C:/Users/***/Desktop/500_100/DongBei')
PRCPTOP_DongBei = []
SDII_DongBei = []
RX1D_DongBei = []
RX5D_DongBei = []
R95p_DongBei = []
R95T_DongBei = []
R99p_DongBei = []
R99T_DongBei = []
CWD_DongBei= []
CDD_DongBei = []
R10MM_DongBei = []
R20MM_DongBei = []
R25MM_DongBei = []
R50MM_DongBei = []
R65MM_DongBei = []
R115MM_DongBei = []
R205MM_DongBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/DongBei/{}'.format(i))
    PRCPTOP_DongBei.append(data['PRCPTOP'].mean())
    SDII_DongBei.append(data['SDII'].mean())
    RX1D_DongBei.append(data['RX1D'].mean())
    RX5D_DongBei.append(data['RX5D'].mean())
    R95p_DongBei.append(data['R95p'].mean())
    R95T_DongBei.append(data['R95T'].mean())
    R99p_DongBei.append(data['R99p'].mean())
    R99T_DongBei.append(data['R99T'].mean())
    CWD_DongBei.append(data['CWD'].mean())
    CDD_DongBei.append(data['CDD'].mean())
    R10MM_DongBei.append(data['R10MM'].mean())
    R20MM_DongBei.append(data['R20MM'].mean())
    R25MM_DongBei.append(data['R25MM'].mean())
    R50MM_DongBei.append(data['R50MM'].mean())
    R65MM_DongBei.append(data['R65MM'].mean())
    R115MM_DongBei.append(data['R115MM'].mean())
    R205MM_DongBei.append(data['R205MM'].mean())
    
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaBei')
PRCPTOP_HuaBei = []
SDII_HuaBei = []
RX1D_HuaBei = []
RX5D_HuaBei = []
R95p_HuaBei = []
R95T_HuaBei = []
R99p_HuaBei = []
R99T_HuaBei = []
CWD_HuaBei= []
CDD_HuaBei = []
R10MM_HuaBei = []
R20MM_HuaBei = []
R25MM_HuaBei = []
R50MM_HuaBei = []
R65MM_HuaBei = []
R115MM_HuaBei = []
R205MM_HuaBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaBei/{}'.format(i))
    PRCPTOP_HuaBei.append(data['PRCPTOP'].mean())
    SDII_HuaBei.append(data['SDII'].mean())
    RX1D_HuaBei.append(data['RX1D'].mean())
    RX5D_HuaBei.append(data['RX5D'].mean())
    R95p_HuaBei.append(data['R95p'].mean())
    R95T_HuaBei.append(data['R95T'].mean())
    R99p_HuaBei.append(data['R99p'].mean())
    R99T_HuaBei.append(data['R99T'].mean())
    CWD_HuaBei.append(data['CWD'].mean())
    CDD_HuaBei.append(data['CDD'].mean())
    R10MM_HuaBei.append(data['R10MM'].mean())
    R20MM_HuaBei.append(data['R20MM'].mean())
    R25MM_HuaBei.append(data['R25MM'].mean())
    R50MM_HuaBei.append(data['R50MM'].mean())
    R65MM_HuaBei.append(data['R65MM'].mean())
    R115MM_HuaBei.append(data['R115MM'].mean())
    R205MM_HuaBei.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaDong')
PRCPTOP_HuaDong = []
SDII_HuaDong = []
RX1D_HuaDong = []
RX5D_HuaDong = []
R95p_HuaDong = []
R95T_HuaDong = []
R99p_HuaDong = []
R99T_HuaDong = []
CWD_HuaDong = []
CDD_HuaDong = []
R10MM_HuaDong = []
R20MM_HuaDong = []
R25MM_HuaDong = []
R50MM_HuaDong = []
R65MM_HuaDong = []
R115MM_HuaDong = []
R205MM_HuaDong = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaDong/{}'.format(i))
    PRCPTOP_HuaDong.append(data['PRCPTOP'].mean())
    SDII_HuaDong.append(data['SDII'].mean())
    RX1D_HuaDong.append(data['RX1D'].mean())
    RX5D_HuaDong.append(data['RX5D'].mean())
    R95p_HuaDong.append(data['R95p'].mean())
    R95T_HuaDong.append(data['R95T'].mean())
    R99p_HuaDong.append(data['R99p'].mean())
    R99T_HuaDong.append(data['R99T'].mean())
    CWD_HuaDong.append(data['CWD'].mean())
    CDD_HuaDong.append(data['CDD'].mean())
    R10MM_HuaDong.append(data['R10MM'].mean())
    R20MM_HuaDong.append(data['R20MM'].mean())
    R25MM_HuaDong.append(data['R25MM'].mean())
    R50MM_HuaDong.append(data['R50MM'].mean())
    R65MM_HuaDong.append(data['R65MM'].mean())
    R115MM_HuaDong.append(data['R115MM'].mean())
    R205MM_HuaDong.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaNan')
PRCPTOP_HuaNan = []
SDII_HuaNan = []
RX1D_HuaNan = []
RX5D_HuaNan = []
R95p_HuaNan = []
R95T_HuaNan = []
R99p_HuaNan = []
R99T_HuaNan = []
CWD_HuaNan = []
CDD_HuaNan = []
R10MM_HuaNan = []
R20MM_HuaNan = []
R25MM_HuaNan = []
R50MM_HuaNan = []
R65MM_HuaNan = []
R115MM_HuaNan = []
R205MM_HuaNan = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaNan/{}'.format(i))
    PRCPTOP_HuaNan.append(data['PRCPTOP'].mean())
    SDII_HuaNan.append(data['SDII'].mean())
    RX1D_HuaNan.append(data['RX1D'].mean())
    RX5D_HuaNan.append(data['RX5D'].mean())
    R95p_HuaNan.append(data['R95p'].mean())
    R95T_HuaNan.append(data['R95T'].mean())
    R99p_HuaNan.append(data['R99p'].mean())
    R99T_HuaNan.append(data['R99T'].mean())
    CWD_HuaNan.append(data['CWD'].mean())
    CDD_HuaNan.append(data['CDD'].mean())
    R10MM_HuaNan.append(data['R10MM'].mean())
    R20MM_HuaNan.append(data['R20MM'].mean())
    R25MM_HuaNan.append(data['R25MM'].mean())
    R50MM_HuaNan.append(data['R50MM'].mean())
    R65MM_HuaNan.append(data['R65MM'].mean())
    R115MM_HuaNan.append(data['R115MM'].mean())
    R205MM_HuaNan.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaZhong')
PRCPTOP_HuaZhong = []
SDII_HuaZhong = []
RX1D_HuaZhong = []
RX5D_HuaZhong = []
R95p_HuaZhong = []
R95T_HuaZhong = []
R99p_HuaZhong = []
R99T_HuaZhong = []
CWD_HuaZhong = []
CDD_HuaZhong = []
R10MM_HuaZhong = []
R20MM_HuaZhong = []
R25MM_HuaZhong = []
R50MM_HuaZhong = []
R65MM_HuaZhong = []
R115MM_HuaZhong = []
R205MM_HuaZhong = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaZhong/{}'.format(i))
    PRCPTOP_HuaZhong.append(data['PRCPTOP'].mean())
    SDII_HuaZhong.append(data['SDII'].mean())
    RX1D_HuaZhong.append(data['RX1D'].mean())
    RX5D_HuaZhong.append(data['RX5D'].mean())
    R95p_HuaZhong.append(data['R95p'].mean())
    R95T_HuaZhong.append(data['R95T'].mean())
    R99p_HuaZhong.append(data['R99p'].mean())
    R99T_HuaZhong.append(data['R99T'].mean())
    CWD_HuaZhong.append(data['CWD'].mean())
    CDD_HuaZhong.append(data['CDD'].mean())
    R10MM_HuaZhong.append(data['R10MM'].mean())
    R20MM_HuaZhong.append(data['R20MM'].mean())
    R25MM_HuaZhong.append(data['R25MM'].mean())
    R50MM_HuaZhong.append(data['R50MM'].mean())
    R65MM_HuaZhong.append(data['R65MM'].mean())
    R115MM_HuaZhong.append(data['R115MM'].mean())
    R205MM_HuaZhong.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/XiBei')
PRCPTOP_XiBei = []
SDII_XiBei = []
RX1D_XiBei = []
RX5D_XiBei = []
R95p_XiBei = []
R95T_XiBei = []
R99p_XiBei = []
R99T_XiBei = []
CWD_XiBei = []
CDD_XiBei = []
R10MM_XiBei = []
R20MM_XiBei = []
R25MM_XiBei = []
R50MM_XiBei = []
R65MM_XiBei = []
R115MM_XiBei = []
R205MM_XiBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/XiBei/{}'.format(i))
    PRCPTOP_XiBei.append(data['PRCPTOP'].mean())
    SDII_XiBei.append(data['SDII'].mean())
    RX1D_XiBei.append(data['RX1D'].mean())
    RX5D_XiBei.append(data['RX5D'].mean())
    R95p_XiBei.append(data['R95p'].mean())
    R95T_XiBei.append(data['R95T'].mean())
    R99p_XiBei.append(data['R99p'].mean())
    R99T_XiBei.append(data['R99T'].mean())
    CWD_XiBei.append(data['CWD'].mean())
    CDD_XiBei.append(data['CDD'].mean())
    R10MM_XiBei.append(data['R10MM'].mean())
    R20MM_XiBei.append(data['R20MM'].mean())
    R25MM_XiBei.append(data['R25MM'].mean())
    R50MM_XiBei.append(data['R50MM'].mean())
    R65MM_XiBei.append(data['R65MM'].mean())
    R115MM_XiBei.append(data['R115MM'].mean())
    R205MM_XiBei.append(data['R205MM'].mean())

filename = os.listdir('C:/Users/***/Desktop/500_100/XiNan')
PRCPTOP_XiNan = []
SDII_XiNan = []
RX1D_XiNan = []
RX5D_XiNan = []
R95p_XiNan = []
R95T_XiNan = []
R99p_XiNan = []
R99T_XiNan = []
CWD_XiNan = []
CDD_XiNan = []
R10MM_XiNan = []
R20MM_XiNan = []
R25MM_XiNan = []
R50MM_XiNan = []
R65MM_XiNan = []
R115MM_XiNan = []
R205MM_XiNan = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/XiNan/{}'.format(i))
    PRCPTOP_XiNan.append(data['PRCPTOP'].mean())
    SDII_XiNan.append(data['SDII'].mean())
    RX1D_XiNan.append(data['RX1D'].mean())
    RX5D_XiNan.append(data['RX5D'].mean())
    R95p_XiNan.append(data['R95p'].mean())
    R95T_XiNan.append(data['R95T'].mean())
    R99p_XiNan.append(data['R99p'].mean())
    R99T_XiNan.append(data['R99T'].mean())
    CWD_XiNan.append(data['CWD'].mean())
    CDD_XiNan.append(data['CDD'].mean())
    R10MM_XiNan.append(data['R10MM'].mean())
    R20MM_XiNan.append(data['R20MM'].mean())
    R25MM_XiNan.append(data['R25MM'].mean())
    R50MM_XiNan.append(data['R50MM'].mean())
    R65MM_XiNan.append(data['R65MM'].mean())
    R115MM_XiNan.append(data['R115MM'].mean())
    R205MM_XiNan.append(data['R205MM'].mean())
    
fig = sns.kdeplot(R10MM_, color="darkorange", cut=0, linewidth = 3)
fig = sns.kdeplot(R10MM_DongBei, color="r", cut=0, linewidth = 3)
fig = sns.kdeplot(R10MM_HuaBei, color="mediumaquamarine", cut=0, linewidth = 3)
fig = sns.kdeplot(R10MM_HuaDong, color="peru", cut=0, linewidth = 3)
fig = sns.kdeplot(R10MM_HuaNan, color="tan", cut=0, linewidth = 3)
fig = sns.kdeplot(R10MM_HuaZhong, color="teal", cut=0, linewidth = 3)
fig = sns.kdeplot(R10MM_XiBei, color="deepskyblue", cut=0, linewidth = 3)
fig = sns.kdeplot(R10MM_XiNan, color="b", cut=0, linewidth = 3)
plt.title('R10MM',fontdict={'weight':'bold','size': 14})

col_labels = ['District','Mean']
table_vals = [['All',round(np.mean(R10MM_))],['DongBei',round(np.mean(R10MM_DongBei))],['HuaBei',round(np.mean(R10MM_HuaBei))],['HuaDong',round(np.mean(R10MM_HuaDong))],['HuaNan',round(np.mean(R10MM_HuaNan))],['HuaZhong',round(np.mean(R10MM_HuaZhong))],['XiBei',round(np.mean(R10MM_XiBei))],['XiNan',round(np.mean(R10MM_XiNan))]]
my_table = plt.table(cellText=table_vals, colWidths=[0.1]*8, colLabels=col_labels, loc='best', cellLoc='center', colColours=['gold','gold'])
my_table.scale(1.8, 1.6)
my_table.auto_set_font_size(False)
my_table.set_fontsize(11)
sns.despine()
fig.set_xlabel("R10MM(day)", fontsize = 10, weight='bold', style='italic')
ax = plt.gca()
plt.text(-0.15,1, '(k)', fontsize=16, color='k',weight='bold', transform=ax.transAxes)
fig.set_ylabel('')
plt.savefig('R10MM.tiff', dpi = 600)

sns.set(style='darkgrid')
Districts = ['All']*15388+['DongBei']*1424+['HuaBei']*2572+['HuaDong']*1219+['HuaNan']*641+['HuaZhong']*852+['XiBei']*4901+['XiNan']*3445
df = pd.DataFrame({'Districts' : Districts, 
                  'R10MM' : R10MM_+R10MM_DongBei+R10MM_HuaBei+R10MM_HuaDong+R10MM_HuaNan+R10MM_HuaZhong+R10MM_XiBei+R10MM_XiNan})
plt.title('R10MM',fontdict={'weight':'bold','size': 14})
fig = sns.violinplot(x='Districts', y='R10MM', data=df, linewidth=0.8, palette='Set3', scale='width')
fig.set_ylabel('Density(day)',fontsize = 10, weight='bold', style='italic')
fig.set_xlabel('')
fig.set_xticklabels(labels=['All','DongBei','HuaBei','HuaDong','HuaNan','HuaZhong','XiBei','XiNan'], rotation = 15, fontsize = 10)
ax = plt.gca()
plt.text(-0.15,1, '(k)', fontsize=16, color='k',weight='bold', transform=ax.transAxes)
plt.savefig('R10MM.tiff', dpi =600)

sns.set(style='ticks')
filename = os.listdir('C:/Users/***/Desktop/500_100/precip_r')
R10MM = pd.DataFrame()
for name in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/precip_r/{}'.format(name))
    R10MM.insert(loc=len(R10MM.columns), column=name, value=list(data['R10MM']))
results = list(R10MM.mean(axis=1))
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
years = [i for i in range(1961,2020)]
plt.xticks(years)
ax1.set_xticks([1961,1965,1970,1975,1980,1985,1990,1995,2000,2005,2010,2015,2019])
ax1.set_xticklabels(['1961','1965','1970','1975','1980','1985','1990','1995','2000','2005','2010','2015','2019'], fontsize = 14)
ax1.set_ylabel('R10MM(days)', fontsize=16, weight='bold')
ax1.tick_params(axis='y', colors='navy', labelsize=12)
ax1.plot(years, results, 'b--', color = "deepskyblue")
sns.regplot(years, results, color='darkorange')
ax = plt.gca()
plt.text(-0.08,1, '(k)', fontsize=22, color='k', weight='bold', transform=ax.transAxes)
plt.savefig('R10MM.tiff',dpi = 600)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import pandas as pd
sns.set(style='ticks')
Districts = ['All of China','DongBei','HuaBei','HuaDong','HuaNan','HuaZhong','XiBei','XiNan']

filename = os.listdir('C:/Users/***/Desktop/500_100/precip_r')
PRCPTOP_ = []
SDII_ = []
RX1D_ = []
RX5D_ = []
R95p_ = []
R95T_ = []
R99p_ = []
R99T_ = []
CWD_ = []
CDD_ = []
R10MM_ = []
R20MM_ = []
R25MM_ = []
R50MM_ = []
R65MM_ = []
R115MM_ = []
R205MM_ = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/precip_r/{}'.format(i))
    PRCPTOP_.append(data['PRCPTOP'].mean())
    SDII_.append(data['SDII'].mean())
    RX1D_.append(data['RX1D'].mean())
    RX5D_.append(data['RX5D'].mean())
    R95p_.append(data['R95p'].mean())
    R95T_.append(data['R95T'].mean())
    R99p_.append(data['R99p'].mean())
    R99T_.append(data['R99T'].mean())
    CWD_.append(data['CWD'].mean())
    CDD_.append(data['CDD'].mean())
    R10MM_.append(data['R10MM'].mean())
    R20MM_.append(data['R20MM'].mean())
    R25MM_.append(data['R25MM'].mean())
    R50MM_.append(data['R50MM'].mean())
    R65MM_.append(data['R65MM'].mean())
    R115MM_.append(data['R115MM'].mean())
    R205MM_.append(data['R205MM'].mean())
    
filename = os.listdir('C:/Users/***/Desktop/500_100/DongBei')
PRCPTOP_DongBei = []
SDII_DongBei = []
RX1D_DongBei = []
RX5D_DongBei = []
R95p_DongBei = []
R95T_DongBei = []
R99p_DongBei = []
R99T_DongBei = []
CWD_DongBei= []
CDD_DongBei = []
R10MM_DongBei = []
R20MM_DongBei = []
R25MM_DongBei = []
R50MM_DongBei = []
R65MM_DongBei = []
R115MM_DongBei = []
R205MM_DongBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/DongBei/{}'.format(i))
    PRCPTOP_DongBei.append(data['PRCPTOP'].mean())
    SDII_DongBei.append(data['SDII'].mean())
    RX1D_DongBei.append(data['RX1D'].mean())
    RX5D_DongBei.append(data['RX5D'].mean())
    R95p_DongBei.append(data['R95p'].mean())
    R95T_DongBei.append(data['R95T'].mean())
    R99p_DongBei.append(data['R99p'].mean())
    R99T_DongBei.append(data['R99T'].mean())
    CWD_DongBei.append(data['CWD'].mean())
    CDD_DongBei.append(data['CDD'].mean())
    R10MM_DongBei.append(data['R10MM'].mean())
    R20MM_DongBei.append(data['R20MM'].mean())
    R25MM_DongBei.append(data['R25MM'].mean())
    R50MM_DongBei.append(data['R50MM'].mean())
    R65MM_DongBei.append(data['R65MM'].mean())
    R115MM_DongBei.append(data['R115MM'].mean())
    R205MM_DongBei.append(data['R205MM'].mean())
    
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaBei')
PRCPTOP_HuaBei = []
SDII_HuaBei = []
RX1D_HuaBei = []
RX5D_HuaBei = []
R95p_HuaBei = []
R95T_HuaBei = []
R99p_HuaBei = []
R99T_HuaBei = []
CWD_HuaBei= []
CDD_HuaBei = []
R10MM_HuaBei = []
R20MM_HuaBei = []
R25MM_HuaBei = []
R50MM_HuaBei = []
R65MM_HuaBei = []
R115MM_HuaBei = []
R205MM_HuaBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaBei/{}'.format(i))
    PRCPTOP_HuaBei.append(data['PRCPTOP'].mean())
    SDII_HuaBei.append(data['SDII'].mean())
    RX1D_HuaBei.append(data['RX1D'].mean())
    RX5D_HuaBei.append(data['RX5D'].mean())
    R95p_HuaBei.append(data['R95p'].mean())
    R95T_HuaBei.append(data['R95T'].mean())
    R99p_HuaBei.append(data['R99p'].mean())
    R99T_HuaBei.append(data['R99T'].mean())
    CWD_HuaBei.append(data['CWD'].mean())
    CDD_HuaBei.append(data['CDD'].mean())
    R10MM_HuaBei.append(data['R10MM'].mean())
    R20MM_HuaBei.append(data['R20MM'].mean())
    R25MM_HuaBei.append(data['R25MM'].mean())
    R50MM_HuaBei.append(data['R50MM'].mean())
    R65MM_HuaBei.append(data['R65MM'].mean())
    R115MM_HuaBei.append(data['R115MM'].mean())
    R205MM_HuaBei.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaDong')
PRCPTOP_HuaDong = []
SDII_HuaDong = []
RX1D_HuaDong = []
RX5D_HuaDong = []
R95p_HuaDong = []
R95T_HuaDong = []
R99p_HuaDong = []
R99T_HuaDong = []
CWD_HuaDong = []
CDD_HuaDong = []
R10MM_HuaDong = []
R20MM_HuaDong = []
R25MM_HuaDong = []
R50MM_HuaDong = []
R65MM_HuaDong = []
R115MM_HuaDong = []
R205MM_HuaDong = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaDong/{}'.format(i))
    PRCPTOP_HuaDong.append(data['PRCPTOP'].mean())
    SDII_HuaDong.append(data['SDII'].mean())
    RX1D_HuaDong.append(data['RX1D'].mean())
    RX5D_HuaDong.append(data['RX5D'].mean())
    R95p_HuaDong.append(data['R95p'].mean())
    R95T_HuaDong.append(data['R95T'].mean())
    R99p_HuaDong.append(data['R99p'].mean())
    R99T_HuaDong.append(data['R99T'].mean())
    CWD_HuaDong.append(data['CWD'].mean())
    CDD_HuaDong.append(data['CDD'].mean())
    R10MM_HuaDong.append(data['R10MM'].mean())
    R20MM_HuaDong.append(data['R20MM'].mean())
    R25MM_HuaDong.append(data['R25MM'].mean())
    R50MM_HuaDong.append(data['R50MM'].mean())
    R65MM_HuaDong.append(data['R65MM'].mean())
    R115MM_HuaDong.append(data['R115MM'].mean())
    R205MM_HuaDong.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaNan')
PRCPTOP_HuaNan = []
SDII_HuaNan = []
RX1D_HuaNan = []
RX5D_HuaNan = []
R95p_HuaNan = []
R95T_HuaNan = []
R99p_HuaNan = []
R99T_HuaNan = []
CWD_HuaNan = []
CDD_HuaNan = []
R10MM_HuaNan = []
R20MM_HuaNan = []
R25MM_HuaNan = []
R50MM_HuaNan = []
R65MM_HuaNan = []
R115MM_HuaNan = []
R205MM_HuaNan = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaNan/{}'.format(i))
    PRCPTOP_HuaNan.append(data['PRCPTOP'].mean())
    SDII_HuaNan.append(data['SDII'].mean())
    RX1D_HuaNan.append(data['RX1D'].mean())
    RX5D_HuaNan.append(data['RX5D'].mean())
    R95p_HuaNan.append(data['R95p'].mean())
    R95T_HuaNan.append(data['R95T'].mean())
    R99p_HuaNan.append(data['R99p'].mean())
    R99T_HuaNan.append(data['R99T'].mean())
    CWD_HuaNan.append(data['CWD'].mean())
    CDD_HuaNan.append(data['CDD'].mean())
    R10MM_HuaNan.append(data['R10MM'].mean())
    R20MM_HuaNan.append(data['R20MM'].mean())
    R25MM_HuaNan.append(data['R25MM'].mean())
    R50MM_HuaNan.append(data['R50MM'].mean())
    R65MM_HuaNan.append(data['R65MM'].mean())
    R115MM_HuaNan.append(data['R115MM'].mean())
    R205MM_HuaNan.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaZhong')
PRCPTOP_HuaZhong = []
SDII_HuaZhong = []
RX1D_HuaZhong = []
RX5D_HuaZhong = []
R95p_HuaZhong = []
R95T_HuaZhong = []
R99p_HuaZhong = []
R99T_HuaZhong = []
CWD_HuaZhong = []
CDD_HuaZhong = []
R10MM_HuaZhong = []
R20MM_HuaZhong = []
R25MM_HuaZhong = []
R50MM_HuaZhong = []
R65MM_HuaZhong = []
R115MM_HuaZhong = []
R205MM_HuaZhong = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaZhong/{}'.format(i))
    PRCPTOP_HuaZhong.append(data['PRCPTOP'].mean())
    SDII_HuaZhong.append(data['SDII'].mean())
    RX1D_HuaZhong.append(data['RX1D'].mean())
    RX5D_HuaZhong.append(data['RX5D'].mean())
    R95p_HuaZhong.append(data['R95p'].mean())
    R95T_HuaZhong.append(data['R95T'].mean())
    R99p_HuaZhong.append(data['R99p'].mean())
    R99T_HuaZhong.append(data['R99T'].mean())
    CWD_HuaZhong.append(data['CWD'].mean())
    CDD_HuaZhong.append(data['CDD'].mean())
    R10MM_HuaZhong.append(data['R10MM'].mean())
    R20MM_HuaZhong.append(data['R20MM'].mean())
    R25MM_HuaZhong.append(data['R25MM'].mean())
    R50MM_HuaZhong.append(data['R50MM'].mean())
    R65MM_HuaZhong.append(data['R65MM'].mean())
    R115MM_HuaZhong.append(data['R115MM'].mean())
    R205MM_HuaZhong.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/XiBei')
PRCPTOP_XiBei = []
SDII_XiBei = []
RX1D_XiBei = []
RX5D_XiBei = []
R95p_XiBei = []
R95T_XiBei = []
R99p_XiBei = []
R99T_XiBei = []
CWD_XiBei = []
CDD_XiBei = []
R10MM_XiBei = []
R20MM_XiBei = []
R25MM_XiBei = []
R50MM_XiBei = []
R65MM_XiBei = []
R115MM_XiBei = []
R205MM_XiBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/XiBei/{}'.format(i))
    PRCPTOP_XiBei.append(data['PRCPTOP'].mean())
    SDII_XiBei.append(data['SDII'].mean())
    RX1D_XiBei.append(data['RX1D'].mean())
    RX5D_XiBei.append(data['RX5D'].mean())
    R95p_XiBei.append(data['R95p'].mean())
    R95T_XiBei.append(data['R95T'].mean())
    R99p_XiBei.append(data['R99p'].mean())
    R99T_XiBei.append(data['R99T'].mean())
    CWD_XiBei.append(data['CWD'].mean())
    CDD_XiBei.append(data['CDD'].mean())
    R10MM_XiBei.append(data['R10MM'].mean())
    R20MM_XiBei.append(data['R20MM'].mean())
    R25MM_XiBei.append(data['R25MM'].mean())
    R50MM_XiBei.append(data['R50MM'].mean())
    R65MM_XiBei.append(data['R65MM'].mean())
    R115MM_XiBei.append(data['R115MM'].mean())
    R205MM_XiBei.append(data['R205MM'].mean())

filename = os.listdir('C:/Users/***/Desktop/500_100/XiNan')
PRCPTOP_XiNan = []
SDII_XiNan = []
RX1D_XiNan = []
RX5D_XiNan = []
R95p_XiNan = []
R95T_XiNan = []
R99p_XiNan = []
R99T_XiNan = []
CWD_XiNan = []
CDD_XiNan = []
R10MM_XiNan = []
R20MM_XiNan = []
R25MM_XiNan = []
R50MM_XiNan = []
R65MM_XiNan = []
R115MM_XiNan = []
R205MM_XiNan = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/XiNan/{}'.format(i))
    PRCPTOP_XiNan.append(data['PRCPTOP'].mean())
    SDII_XiNan.append(data['SDII'].mean())
    RX1D_XiNan.append(data['RX1D'].mean())
    RX5D_XiNan.append(data['RX5D'].mean())
    R95p_XiNan.append(data['R95p'].mean())
    R95T_XiNan.append(data['R95T'].mean())
    R99p_XiNan.append(data['R99p'].mean())
    R99T_XiNan.append(data['R99T'].mean())
    CWD_XiNan.append(data['CWD'].mean())
    CDD_XiNan.append(data['CDD'].mean())
    R10MM_XiNan.append(data['R10MM'].mean())
    R20MM_XiNan.append(data['R20MM'].mean())
    R25MM_XiNan.append(data['R25MM'].mean())
    R50MM_XiNan.append(data['R50MM'].mean())
    R65MM_XiNan.append(data['R65MM'].mean())
    R115MM_XiNan.append(data['R115MM'].mean())
    R205MM_XiNan.append(data['R205MM'].mean())
    
fig = sns.kdeplot(R20MM_, color="darkorange", cut=0, linewidth = 3)
fig = sns.kdeplot(R20MM_DongBei, color="r", cut=0, linewidth = 3)
fig = sns.kdeplot(R20MM_HuaBei, color="mediumaquamarine", cut=0, linewidth = 3)
fig = sns.kdeplot(R20MM_HuaDong, color="peru", cut=0, linewidth = 3)
fig = sns.kdeplot(R20MM_HuaNan, color="tan", cut=0, linewidth = 3)
fig = sns.kdeplot(R20MM_HuaZhong, color="teal", cut=0, linewidth = 3)
fig = sns.kdeplot(R20MM_XiBei, color="deepskyblue", cut=0, linewidth = 3)
fig = sns.kdeplot(R20MM_XiNan, color="b", cut=0, linewidth = 3)
plt.title('R20MM',fontdict={'weight':'bold','size': 14})
col_labels = ['District','Mean']
table_vals = [['All',round(np.mean(R20MM_))],['DongBei',round(np.mean(R20MM_DongBei))],['HuaBei',round(np.mean(R20MM_HuaBei))],['HuaDong',round(np.mean(R20MM_HuaDong))],['HuaNan',round(np.mean(R20MM_HuaNan))],['HuaZhong',round(np.mean(R20MM_HuaZhong))],['XiBei',round(np.mean(R20MM_XiBei))],['XiNan',round(np.mean(R20MM_XiNan))]]
my_table = plt.table(cellText=table_vals, colWidths=[0.1]*8, colLabels=col_labels, loc='best', cellLoc='center', colColours=['gold','gold'])
my_table.scale(1.8, 1.6)
my_table.auto_set_font_size(False)
my_table.set_fontsize(11)
sns.despine()
fig.set_xlabel("R20MM(day)", fontsize = 10, weight='bold', style='italic')
ax = plt.gca()
plt.text(-0.15,1, '(l)', fontsize=16, color='k',weight='bold', transform=ax.transAxes)
fig.set_xlim([-1.25, 32])
fig.set_ylabel('')
plt.savefig('R20MM.tiff', dpi = 600)

sns.set(style='darkgrid')
Districts = ['All']*15388+['DongBei']*1424+['HuaBei']*2572+['HuaDong']*1219+['HuaNan']*641+['HuaZhong']*852+['XiBei']*4901+['XiNan']*3445
df = pd.DataFrame({'Districts' : Districts, 'R20MM' : R20MM_+R20MM_DongBei+R20MM_HuaBei+R20MM_HuaDong+R20MM_HuaNan+R20MM_HuaZhong+R20MM_XiBei+R20MM_XiNan})
plt.title('R20MM',fontdict={'weight':'bold','size': 14})
fig = sns.violinplot(x='Districts', y='R20MM', data=df, linewidth=0.8, palette='Set3', scale='width')
fig.set_ylabel('Density(day)',fontsize = 10, weight='bold', style='italic')
fig.set_xlabel('')
fig.set_xticklabels(labels=['All','DongBei','HuaBei','HuaDong','HuaNan','HuaZhong','XiBei','XiNan'], rotation = 15, fontsize = 10)
ax = plt.gca()
plt.text(-0.15,1, '(l)', fontsize=16, color='k',weight='bold', transform=ax.transAxes)
plt.savefig('R20MM.tiff', dpi =600)

sns.set(style='ticks')
filename = os.listdir('C:/Users/***/Desktop/500_100/precip_r')
R20MM = pd.DataFrame()
for name in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/precip_r/{}'.format(name))
    R20MM.insert(loc=len(R20MM.columns), column=name, value=list(data['R20MM']))
results = list(R20MM.mean(axis=1))
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
years = [i for i in range(1961,2020)]
plt.xticks(years)
ax1.set_xticks([1961,1965,1970,1975,1980,1985,1990,1995,2000,2005,2010,2015,2019])
ax1.set_xticklabels(['1961','1965','1970','1975','1980','1985','1990','1995','2000','2005','2010','2015','2019'], fontsize = 14)
ax1.set_ylabel('R20MM(days)', fontsize=16, weight='bold')
ax1.set_yticks([4,5,6,7,8])
ax1.set_yticklabels(['4','5','6','7','8'], fontsize = 14)
ax1.tick_params(axis='y', colors='navy', labelsize=12)
ax1.plot(years, results, 'b--', color = "deepskyblue")
sns.regplot(years, results, color='darkorange')
ax = plt.gca()
plt.text(-0.08,1, '(l)', fontsize=22, color='k', weight='bold', transform=ax.transAxes)
plt.savefig('R20MM.tiff',dpi = 600)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import pandas as pd
sns.set(style='ticks')
Districts = ['All of China','DongBei','HuaBei','HuaDong','HuaNan','HuaZhong','XiBei','XiNan']

filename = os.listdir('C:/Users/***/Desktop/500_100/precip_r')
PRCPTOP_ = []
SDII_ = []
RX1D_ = []
RX5D_ = []
R95p_ = []
R95T_ = []
R99p_ = []
R99T_ = []
CWD_ = []
CDD_ = []
R10MM_ = []
R20MM_ = []
R25MM_ = []
R50MM_ = []
R65MM_ = []
R115MM_ = []
R205MM_ = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/precip_r/{}'.format(i))
    PRCPTOP_.append(data['PRCPTOP'].mean())
    SDII_.append(data['SDII'].mean())
    RX1D_.append(data['RX1D'].mean())
    RX5D_.append(data['RX5D'].mean())
    R95p_.append(data['R95p'].mean())
    R95T_.append(data['R95T'].mean())
    R99p_.append(data['R99p'].mean())
    R99T_.append(data['R99T'].mean())
    CWD_.append(data['CWD'].mean())
    CDD_.append(data['CDD'].mean())
    R10MM_.append(data['R10MM'].mean())
    R20MM_.append(data['R20MM'].mean())
    R25MM_.append(data['R25MM'].mean())
    R50MM_.append(data['R50MM'].mean())
    R65MM_.append(data['R65MM'].mean())
    R115MM_.append(data['R115MM'].mean())
    R205MM_.append(data['R205MM'].mean())
    
filename = os.listdir('C:/Users/***/Desktop/500_100/DongBei')
PRCPTOP_DongBei = []
SDII_DongBei = []
RX1D_DongBei = []
RX5D_DongBei = []
R95p_DongBei = []
R95T_DongBei = []
R99p_DongBei = []
R99T_DongBei = []
CWD_DongBei= []
CDD_DongBei = []
R10MM_DongBei = []
R20MM_DongBei = []
R25MM_DongBei = []
R50MM_DongBei = []
R65MM_DongBei = []
R115MM_DongBei = []
R205MM_DongBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/DongBei/{}'.format(i))
    PRCPTOP_DongBei.append(data['PRCPTOP'].mean())
    SDII_DongBei.append(data['SDII'].mean())
    RX1D_DongBei.append(data['RX1D'].mean())
    RX5D_DongBei.append(data['RX5D'].mean())
    R95p_DongBei.append(data['R95p'].mean())
    R95T_DongBei.append(data['R95T'].mean())
    R99p_DongBei.append(data['R99p'].mean())
    R99T_DongBei.append(data['R99T'].mean())
    CWD_DongBei.append(data['CWD'].mean())
    CDD_DongBei.append(data['CDD'].mean())
    R10MM_DongBei.append(data['R10MM'].mean())
    R20MM_DongBei.append(data['R20MM'].mean())
    R25MM_DongBei.append(data['R25MM'].mean())
    R50MM_DongBei.append(data['R50MM'].mean())
    R65MM_DongBei.append(data['R65MM'].mean())
    R115MM_DongBei.append(data['R115MM'].mean())
    R205MM_DongBei.append(data['R205MM'].mean())
    
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaBei')
PRCPTOP_HuaBei = []
SDII_HuaBei = []
RX1D_HuaBei = []
RX5D_HuaBei = []
R95p_HuaBei = []
R95T_HuaBei = []
R99p_HuaBei = []
R99T_HuaBei = []
CWD_HuaBei= []
CDD_HuaBei = []
R10MM_HuaBei = []
R20MM_HuaBei = []
R25MM_HuaBei = []
R50MM_HuaBei = []
R65MM_HuaBei = []
R115MM_HuaBei = []
R205MM_HuaBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaBei/{}'.format(i))
    PRCPTOP_HuaBei.append(data['PRCPTOP'].mean())
    SDII_HuaBei.append(data['SDII'].mean())
    RX1D_HuaBei.append(data['RX1D'].mean())
    RX5D_HuaBei.append(data['RX5D'].mean())
    R95p_HuaBei.append(data['R95p'].mean())
    R95T_HuaBei.append(data['R95T'].mean())
    R99p_HuaBei.append(data['R99p'].mean())
    R99T_HuaBei.append(data['R99T'].mean())
    CWD_HuaBei.append(data['CWD'].mean())
    CDD_HuaBei.append(data['CDD'].mean())
    R10MM_HuaBei.append(data['R10MM'].mean())
    R20MM_HuaBei.append(data['R20MM'].mean())
    R25MM_HuaBei.append(data['R25MM'].mean())
    R50MM_HuaBei.append(data['R50MM'].mean())
    R65MM_HuaBei.append(data['R65MM'].mean())
    R115MM_HuaBei.append(data['R115MM'].mean())
    R205MM_HuaBei.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaDong')
PRCPTOP_HuaDong = []
SDII_HuaDong = []
RX1D_HuaDong = []
RX5D_HuaDong = []
R95p_HuaDong = []
R95T_HuaDong = []
R99p_HuaDong = []
R99T_HuaDong = []
CWD_HuaDong = []
CDD_HuaDong = []
R10MM_HuaDong = []
R20MM_HuaDong = []
R25MM_HuaDong = []
R50MM_HuaDong = []
R65MM_HuaDong = []
R115MM_HuaDong = []
R205MM_HuaDong = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaDong/{}'.format(i))
    PRCPTOP_HuaDong.append(data['PRCPTOP'].mean())
    SDII_HuaDong.append(data['SDII'].mean())
    RX1D_HuaDong.append(data['RX1D'].mean())
    RX5D_HuaDong.append(data['RX5D'].mean())
    R95p_HuaDong.append(data['R95p'].mean())
    R95T_HuaDong.append(data['R95T'].mean())
    R99p_HuaDong.append(data['R99p'].mean())
    R99T_HuaDong.append(data['R99T'].mean())
    CWD_HuaDong.append(data['CWD'].mean())
    CDD_HuaDong.append(data['CDD'].mean())
    R10MM_HuaDong.append(data['R10MM'].mean())
    R20MM_HuaDong.append(data['R20MM'].mean())
    R25MM_HuaDong.append(data['R25MM'].mean())
    R50MM_HuaDong.append(data['R50MM'].mean())
    R65MM_HuaDong.append(data['R65MM'].mean())
    R115MM_HuaDong.append(data['R115MM'].mean())
    R205MM_HuaDong.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaNan')
PRCPTOP_HuaNan = []
SDII_HuaNan = []
RX1D_HuaNan = []
RX5D_HuaNan = []
R95p_HuaNan = []
R95T_HuaNan = []
R99p_HuaNan = []
R99T_HuaNan = []
CWD_HuaNan = []
CDD_HuaNan = []
R10MM_HuaNan = []
R20MM_HuaNan = []
R25MM_HuaNan = []
R50MM_HuaNan = []
R65MM_HuaNan = []
R115MM_HuaNan = []
R205MM_HuaNan = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaNan/{}'.format(i))
    PRCPTOP_HuaNan.append(data['PRCPTOP'].mean())
    SDII_HuaNan.append(data['SDII'].mean())
    RX1D_HuaNan.append(data['RX1D'].mean())
    RX5D_HuaNan.append(data['RX5D'].mean())
    R95p_HuaNan.append(data['R95p'].mean())
    R95T_HuaNan.append(data['R95T'].mean())
    R99p_HuaNan.append(data['R99p'].mean())
    R99T_HuaNan.append(data['R99T'].mean())
    CWD_HuaNan.append(data['CWD'].mean())
    CDD_HuaNan.append(data['CDD'].mean())
    R10MM_HuaNan.append(data['R10MM'].mean())
    R20MM_HuaNan.append(data['R20MM'].mean())
    R25MM_HuaNan.append(data['R25MM'].mean())
    R50MM_HuaNan.append(data['R50MM'].mean())
    R65MM_HuaNan.append(data['R65MM'].mean())
    R115MM_HuaNan.append(data['R115MM'].mean())
    R205MM_HuaNan.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaZhong')
PRCPTOP_HuaZhong = []
SDII_HuaZhong = []
RX1D_HuaZhong = []
RX5D_HuaZhong = []
R95p_HuaZhong = []
R95T_HuaZhong = []
R99p_HuaZhong = []
R99T_HuaZhong = []
CWD_HuaZhong = []
CDD_HuaZhong = []
R10MM_HuaZhong = []
R20MM_HuaZhong = []
R25MM_HuaZhong = []
R50MM_HuaZhong = []
R65MM_HuaZhong = []
R115MM_HuaZhong = []
R205MM_HuaZhong = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaZhong/{}'.format(i))
    PRCPTOP_HuaZhong.append(data['PRCPTOP'].mean())
    SDII_HuaZhong.append(data['SDII'].mean())
    RX1D_HuaZhong.append(data['RX1D'].mean())
    RX5D_HuaZhong.append(data['RX5D'].mean())
    R95p_HuaZhong.append(data['R95p'].mean())
    R95T_HuaZhong.append(data['R95T'].mean())
    R99p_HuaZhong.append(data['R99p'].mean())
    R99T_HuaZhong.append(data['R99T'].mean())
    CWD_HuaZhong.append(data['CWD'].mean())
    CDD_HuaZhong.append(data['CDD'].mean())
    R10MM_HuaZhong.append(data['R10MM'].mean())
    R20MM_HuaZhong.append(data['R20MM'].mean())
    R25MM_HuaZhong.append(data['R25MM'].mean())
    R50MM_HuaZhong.append(data['R50MM'].mean())
    R65MM_HuaZhong.append(data['R65MM'].mean())
    R115MM_HuaZhong.append(data['R115MM'].mean())
    R205MM_HuaZhong.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/XiBei')
PRCPTOP_XiBei = []
SDII_XiBei = []
RX1D_XiBei = []
RX5D_XiBei = []
R95p_XiBei = []
R95T_XiBei = []
R99p_XiBei = []
R99T_XiBei = []
CWD_XiBei = []
CDD_XiBei = []
R10MM_XiBei = []
R20MM_XiBei = []
R25MM_XiBei = []
R50MM_XiBei = []
R65MM_XiBei = []
R115MM_XiBei = []
R205MM_XiBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/XiBei/{}'.format(i))
    PRCPTOP_XiBei.append(data['PRCPTOP'].mean())
    SDII_XiBei.append(data['SDII'].mean())
    RX1D_XiBei.append(data['RX1D'].mean())
    RX5D_XiBei.append(data['RX5D'].mean())
    R95p_XiBei.append(data['R95p'].mean())
    R95T_XiBei.append(data['R95T'].mean())
    R99p_XiBei.append(data['R99p'].mean())
    R99T_XiBei.append(data['R99T'].mean())
    CWD_XiBei.append(data['CWD'].mean())
    CDD_XiBei.append(data['CDD'].mean())
    R10MM_XiBei.append(data['R10MM'].mean())
    R20MM_XiBei.append(data['R20MM'].mean())
    R25MM_XiBei.append(data['R25MM'].mean())
    R50MM_XiBei.append(data['R50MM'].mean())
    R65MM_XiBei.append(data['R65MM'].mean())
    R115MM_XiBei.append(data['R115MM'].mean())
    R205MM_XiBei.append(data['R205MM'].mean())

filename = os.listdir('C:/Users/***/Desktop/500_100/XiNan')
PRCPTOP_XiNan = []
SDII_XiNan = []
RX1D_XiNan = []
RX5D_XiNan = []
R95p_XiNan = []
R95T_XiNan = []
R99p_XiNan = []
R99T_XiNan = []
CWD_XiNan = []
CDD_XiNan = []
R10MM_XiNan = []
R20MM_XiNan = []
R25MM_XiNan = []
R50MM_XiNan = []
R65MM_XiNan = []
R115MM_XiNan = []
R205MM_XiNan = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/XiNan/{}'.format(i))
    PRCPTOP_XiNan.append(data['PRCPTOP'].mean())
    SDII_XiNan.append(data['SDII'].mean())
    RX1D_XiNan.append(data['RX1D'].mean())
    RX5D_XiNan.append(data['RX5D'].mean())
    R95p_XiNan.append(data['R95p'].mean())
    R95T_XiNan.append(data['R95T'].mean())
    R99p_XiNan.append(data['R99p'].mean())
    R99T_XiNan.append(data['R99T'].mean())
    CWD_XiNan.append(data['CWD'].mean())
    CDD_XiNan.append(data['CDD'].mean())
    R10MM_XiNan.append(data['R10MM'].mean())
    R20MM_XiNan.append(data['R20MM'].mean())
    R25MM_XiNan.append(data['R25MM'].mean())
    R50MM_XiNan.append(data['R50MM'].mean())
    R65MM_XiNan.append(data['R65MM'].mean())
    R115MM_XiNan.append(data['R115MM'].mean())
    R205MM_XiNan.append(data['R205MM'].mean())
    
fig = sns.kdeplot(R95p_, color="darkorange", cut=0, linewidth = 3)
fig = sns.kdeplot(R95p_DongBei, color="r", cut=0, linewidth = 3)
fig = sns.kdeplot(R95p_HuaBei, color="mediumaquamarine", cut=0, linewidth = 3)
fig = sns.kdeplot(R95p_HuaDong, color="peru", cut=0, linewidth = 3)
fig = sns.kdeplot(R95p_HuaNan, color="tan", cut=0, linewidth = 3)
fig = sns.kdeplot(R95p_HuaZhong, color="teal", cut=0, linewidth = 3)
fig = sns.kdeplot(R95p_XiBei, color="deepskyblue", cut=0, linewidth = 3)
fig = sns.kdeplot(R95p_XiNan, color="b", cut=0, linewidth = 3)
plt.title('R95p',fontdict={'weight':'bold','size': 14})
col_labels = ['District','Mean']
table_vals = [['All',round(np.mean(R95p_))],['DongBei',round(np.mean(R95p_DongBei))],['HuaBei',round(np.mean(R95p_HuaBei))],['HuaDong',round(np.mean(R95p_HuaDong))],['HuaNan',round(np.mean(R95p_HuaNan))],['HuaZhong',round(np.mean(R95p_HuaZhong))],['XiBei',round(np.mean(R95p_XiBei))],['XiNan',round(np.mean(R95p_XiNan))]]
my_table = plt.table(cellText=table_vals, colWidths=[0.1]*8, colLabels=col_labels, loc='best', cellLoc='center', colColours=['gold','gold'])
my_table.scale(1.8, 1.6)
my_table.auto_set_font_size(False)
my_table.set_fontsize(11)
sns.despine()
fig.set_xlabel("R95p(mm)", fontsize = 10, weight='bold', style='italic')
ax = plt.gca()
plt.text(-0.15,1, '(e)', fontsize=16, color='k',weight='bold', transform=ax.transAxes)
fig.set_xlim([-40, 1200])
fig.set_ylabel('')
plt.savefig('R95p.tiff', dpi = 600)

sns.set(style='darkgrid')
Districts = ['All']*15388+['DongBei']*1424+['HuaBei']*2572+['HuaDong']*1219+['HuaNan']*641+['HuaZhong']*852+['XiBei']*4901+['XiNan']*3445
df = pd.DataFrame({'Districts' : Districts, 'R95p' : R95p_+R95p_DongBei+R95p_HuaBei+R95p_HuaDong+R95p_HuaNan+R95p_HuaZhong+R95p_XiBei+R95p_XiNan})
plt.title('R95p',fontdict={'weight':'bold','size': 14})
fig = sns.violinplot(x='Districts', y='R95p', data=df, linewidth=0.8, palette='Set3', scale='width')
fig.set_ylabel('Density(mm)',fontsize = 10, weight='bold', style='italic')
fig.set_xlabel('')
fig.set_xticklabels(labels=['All','DongBei','HuaBei','HuaDong','HuaNan','HuaZhong','XiBei','XiNan'], rotation = 15, fontsize = 10)
ax = plt.gca()
plt.text(-0.15,1, '(e)', fontsize=16, color='k',weight='bold', transform=ax.transAxes)
plt.savefig('R95p.tiff', dpi =600)

sns.set(style='ticks')
filename = os.listdir('C:/Users/***/Desktop/500_100/precip_r')
R95p = pd.DataFrame()
for name in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/precip_r/{}'.format(name))
    R95p.insert(loc=len(R95p.columns), column=name, value=list(data['R95p']))
results = list(R95p.mean(axis=1))
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
years = [i for i in range(1961,2020)]
plt.xticks(years)
ax1.set_xticks([1961,1965,1970,1975,1980,1985,1990,1995,2000,2005,2010,2015,2019])
ax1.set_xticklabels(['1961','1965','1970','1975','1980','1985','1990','1995','2000','2005','2010','2015','2019'], fontsize = 14)
ax1.set_ylabel('R95p(mm)', fontsize=16, weight='bold')
ax1.tick_params(axis='y', colors='navy', labelsize=12)
ax1.plot(years, results, 'b--', color = "deepskyblue")
sns.regplot(years, results, color='darkorange')
ax = plt.gca()
plt.text(-0.08,1, '(e)', fontsize=22, color='k', weight='bold', transform=ax.transAxes)
plt.savefig('R95p.tiff',dpi = 600)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import pandas as pd
sns.set(style='ticks')
Districts = ['All of China','DongBei','HuaBei','HuaDong','HuaNan','HuaZhong','XiBei','XiNan']

filename = os.listdir('C:/Users/***/Desktop/500_100/precip_r')
PRCPTOP_ = []
SDII_ = []
RX1D_ = []
RX5D_ = []
R95p_ = []
R95T_ = []
R99p_ = []
R99T_ = []
CWD_ = []
CDD_ = []
R10MM_ = []
R20MM_ = []
R25MM_ = []
R50MM_ = []
R65MM_ = []
R115MM_ = []
R205MM_ = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/precip_r/{}'.format(i))
    PRCPTOP_.append(data['PRCPTOP'].mean())
    SDII_.append(data['SDII'].mean())
    RX1D_.append(data['RX1D'].mean())
    RX5D_.append(data['RX5D'].mean())
    R95p_.append(data['R95p'].mean())
    R95T_.append(data['R95T'].mean())
    R99p_.append(data['R99p'].mean())
    R99T_.append(data['R99T'].mean())
    CWD_.append(data['CWD'].mean())
    CDD_.append(data['CDD'].mean())
    R10MM_.append(data['R10MM'].mean())
    R20MM_.append(data['R20MM'].mean())
    R25MM_.append(data['R25MM'].mean())
    R50MM_.append(data['R50MM'].mean())
    R65MM_.append(data['R65MM'].mean())
    R115MM_.append(data['R115MM'].mean())
    R205MM_.append(data['R205MM'].mean())
    
filename = os.listdir('C:/Users/***/Desktop/500_100/DongBei')
PRCPTOP_DongBei = []
SDII_DongBei = []
RX1D_DongBei = []
RX5D_DongBei = []
R95p_DongBei = []
R95T_DongBei = []
R99p_DongBei = []
R99T_DongBei = []
CWD_DongBei= []
CDD_DongBei = []
R10MM_DongBei = []
R20MM_DongBei = []
R25MM_DongBei = []
R50MM_DongBei = []
R65MM_DongBei = []
R115MM_DongBei = []
R205MM_DongBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/DongBei/{}'.format(i))
    PRCPTOP_DongBei.append(data['PRCPTOP'].mean())
    SDII_DongBei.append(data['SDII'].mean())
    RX1D_DongBei.append(data['RX1D'].mean())
    RX5D_DongBei.append(data['RX5D'].mean())
    R95p_DongBei.append(data['R95p'].mean())
    R95T_DongBei.append(data['R95T'].mean())
    R99p_DongBei.append(data['R99p'].mean())
    R99T_DongBei.append(data['R99T'].mean())
    CWD_DongBei.append(data['CWD'].mean())
    CDD_DongBei.append(data['CDD'].mean())
    R10MM_DongBei.append(data['R10MM'].mean())
    R20MM_DongBei.append(data['R20MM'].mean())
    R25MM_DongBei.append(data['R25MM'].mean())
    R50MM_DongBei.append(data['R50MM'].mean())
    R65MM_DongBei.append(data['R65MM'].mean())
    R115MM_DongBei.append(data['R115MM'].mean())
    R205MM_DongBei.append(data['R205MM'].mean())
    
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaBei')
PRCPTOP_HuaBei = []
SDII_HuaBei = []
RX1D_HuaBei = []
RX5D_HuaBei = []
R95p_HuaBei = []
R95T_HuaBei = []
R99p_HuaBei = []
R99T_HuaBei = []
CWD_HuaBei= []
CDD_HuaBei = []
R10MM_HuaBei = []
R20MM_HuaBei = []
R25MM_HuaBei = []
R50MM_HuaBei = []
R65MM_HuaBei = []
R115MM_HuaBei = []
R205MM_HuaBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaBei/{}'.format(i))
    PRCPTOP_HuaBei.append(data['PRCPTOP'].mean())
    SDII_HuaBei.append(data['SDII'].mean())
    RX1D_HuaBei.append(data['RX1D'].mean())
    RX5D_HuaBei.append(data['RX5D'].mean())
    R95p_HuaBei.append(data['R95p'].mean())
    R95T_HuaBei.append(data['R95T'].mean())
    R99p_HuaBei.append(data['R99p'].mean())
    R99T_HuaBei.append(data['R99T'].mean())
    CWD_HuaBei.append(data['CWD'].mean())
    CDD_HuaBei.append(data['CDD'].mean())
    R10MM_HuaBei.append(data['R10MM'].mean())
    R20MM_HuaBei.append(data['R20MM'].mean())
    R25MM_HuaBei.append(data['R25MM'].mean())
    R50MM_HuaBei.append(data['R50MM'].mean())
    R65MM_HuaBei.append(data['R65MM'].mean())
    R115MM_HuaBei.append(data['R115MM'].mean())
    R205MM_HuaBei.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaDong')
PRCPTOP_HuaDong = []
SDII_HuaDong = []
RX1D_HuaDong = []
RX5D_HuaDong = []
R95p_HuaDong = []
R95T_HuaDong = []
R99p_HuaDong = []
R99T_HuaDong = []
CWD_HuaDong = []
CDD_HuaDong = []
R10MM_HuaDong = []
R20MM_HuaDong = []
R25MM_HuaDong = []
R50MM_HuaDong = []
R65MM_HuaDong = []
R115MM_HuaDong = []
R205MM_HuaDong = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaDong/{}'.format(i))
    PRCPTOP_HuaDong.append(data['PRCPTOP'].mean())
    SDII_HuaDong.append(data['SDII'].mean())
    RX1D_HuaDong.append(data['RX1D'].mean())
    RX5D_HuaDong.append(data['RX5D'].mean())
    R95p_HuaDong.append(data['R95p'].mean())
    R95T_HuaDong.append(data['R95T'].mean())
    R99p_HuaDong.append(data['R99p'].mean())
    R99T_HuaDong.append(data['R99T'].mean())
    CWD_HuaDong.append(data['CWD'].mean())
    CDD_HuaDong.append(data['CDD'].mean())
    R10MM_HuaDong.append(data['R10MM'].mean())
    R20MM_HuaDong.append(data['R20MM'].mean())
    R25MM_HuaDong.append(data['R25MM'].mean())
    R50MM_HuaDong.append(data['R50MM'].mean())
    R65MM_HuaDong.append(data['R65MM'].mean())
    R115MM_HuaDong.append(data['R115MM'].mean())
    R205MM_HuaDong.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaNan')
PRCPTOP_HuaNan = []
SDII_HuaNan = []
RX1D_HuaNan = []
RX5D_HuaNan = []
R95p_HuaNan = []
R95T_HuaNan = []
R99p_HuaNan = []
R99T_HuaNan = []
CWD_HuaNan = []
CDD_HuaNan = []
R10MM_HuaNan = []
R20MM_HuaNan = []
R25MM_HuaNan = []
R50MM_HuaNan = []
R65MM_HuaNan = []
R115MM_HuaNan = []
R205MM_HuaNan = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaNan/{}'.format(i))
    PRCPTOP_HuaNan.append(data['PRCPTOP'].mean())
    SDII_HuaNan.append(data['SDII'].mean())
    RX1D_HuaNan.append(data['RX1D'].mean())
    RX5D_HuaNan.append(data['RX5D'].mean())
    R95p_HuaNan.append(data['R95p'].mean())
    R95T_HuaNan.append(data['R95T'].mean())
    R99p_HuaNan.append(data['R99p'].mean())
    R99T_HuaNan.append(data['R99T'].mean())
    CWD_HuaNan.append(data['CWD'].mean())
    CDD_HuaNan.append(data['CDD'].mean())
    R10MM_HuaNan.append(data['R10MM'].mean())
    R20MM_HuaNan.append(data['R20MM'].mean())
    R25MM_HuaNan.append(data['R25MM'].mean())
    R50MM_HuaNan.append(data['R50MM'].mean())
    R65MM_HuaNan.append(data['R65MM'].mean())
    R115MM_HuaNan.append(data['R115MM'].mean())
    R205MM_HuaNan.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaZhong')
PRCPTOP_HuaZhong = []
SDII_HuaZhong = []
RX1D_HuaZhong = []
RX5D_HuaZhong = []
R95p_HuaZhong = []
R95T_HuaZhong = []
R99p_HuaZhong = []
R99T_HuaZhong = []
CWD_HuaZhong = []
CDD_HuaZhong = []
R10MM_HuaZhong = []
R20MM_HuaZhong = []
R25MM_HuaZhong = []
R50MM_HuaZhong = []
R65MM_HuaZhong = []
R115MM_HuaZhong = []
R205MM_HuaZhong = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaZhong/{}'.format(i))
    PRCPTOP_HuaZhong.append(data['PRCPTOP'].mean())
    SDII_HuaZhong.append(data['SDII'].mean())
    RX1D_HuaZhong.append(data['RX1D'].mean())
    RX5D_HuaZhong.append(data['RX5D'].mean())
    R95p_HuaZhong.append(data['R95p'].mean())
    R95T_HuaZhong.append(data['R95T'].mean())
    R99p_HuaZhong.append(data['R99p'].mean())
    R99T_HuaZhong.append(data['R99T'].mean())
    CWD_HuaZhong.append(data['CWD'].mean())
    CDD_HuaZhong.append(data['CDD'].mean())
    R10MM_HuaZhong.append(data['R10MM'].mean())
    R20MM_HuaZhong.append(data['R20MM'].mean())
    R25MM_HuaZhong.append(data['R25MM'].mean())
    R50MM_HuaZhong.append(data['R50MM'].mean())
    R65MM_HuaZhong.append(data['R65MM'].mean())
    R115MM_HuaZhong.append(data['R115MM'].mean())
    R205MM_HuaZhong.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/XiBei')
PRCPTOP_XiBei = []
SDII_XiBei = []
RX1D_XiBei = []
RX5D_XiBei = []
R95p_XiBei = []
R95T_XiBei = []
R99p_XiBei = []
R99T_XiBei = []
CWD_XiBei = []
CDD_XiBei = []
R10MM_XiBei = []
R20MM_XiBei = []
R25MM_XiBei = []
R50MM_XiBei = []
R65MM_XiBei = []
R115MM_XiBei = []
R205MM_XiBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/XiBei/{}'.format(i))
    PRCPTOP_XiBei.append(data['PRCPTOP'].mean())
    SDII_XiBei.append(data['SDII'].mean())
    RX1D_XiBei.append(data['RX1D'].mean())
    RX5D_XiBei.append(data['RX5D'].mean())
    R95p_XiBei.append(data['R95p'].mean())
    R95T_XiBei.append(data['R95T'].mean())
    R99p_XiBei.append(data['R99p'].mean())
    R99T_XiBei.append(data['R99T'].mean())
    CWD_XiBei.append(data['CWD'].mean())
    CDD_XiBei.append(data['CDD'].mean())
    R10MM_XiBei.append(data['R10MM'].mean())
    R20MM_XiBei.append(data['R20MM'].mean())
    R25MM_XiBei.append(data['R25MM'].mean())
    R50MM_XiBei.append(data['R50MM'].mean())
    R65MM_XiBei.append(data['R65MM'].mean())
    R115MM_XiBei.append(data['R115MM'].mean())
    R205MM_XiBei.append(data['R205MM'].mean())

filename = os.listdir('C:/Users/***/Desktop/500_100/XiNan')
PRCPTOP_XiNan = []
SDII_XiNan = []
RX1D_XiNan = []
RX5D_XiNan = []
R95p_XiNan = []
R95T_XiNan = []
R99p_XiNan = []
R99T_XiNan = []
CWD_XiNan = []
CDD_XiNan = []
R10MM_XiNan = []
R20MM_XiNan = []
R25MM_XiNan = []
R50MM_XiNan = []
R65MM_XiNan = []
R115MM_XiNan = []
R205MM_XiNan = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/XiNan/{}'.format(i))
    PRCPTOP_XiNan.append(data['PRCPTOP'].mean())
    SDII_XiNan.append(data['SDII'].mean())
    RX1D_XiNan.append(data['RX1D'].mean())
    RX5D_XiNan.append(data['RX5D'].mean())
    R95p_XiNan.append(data['R95p'].mean())
    R95T_XiNan.append(data['R95T'].mean())
    R99p_XiNan.append(data['R99p'].mean())
    R99T_XiNan.append(data['R99T'].mean())
    CWD_XiNan.append(data['CWD'].mean())
    CDD_XiNan.append(data['CDD'].mean())
    R10MM_XiNan.append(data['R10MM'].mean())
    R20MM_XiNan.append(data['R20MM'].mean())
    R25MM_XiNan.append(data['R25MM'].mean())
    R50MM_XiNan.append(data['R50MM'].mean())
    R65MM_XiNan.append(data['R65MM'].mean())
    R115MM_XiNan.append(data['R115MM'].mean())
    R205MM_XiNan.append(data['R205MM'].mean())
    
fig = sns.kdeplot(R95T_, color="darkorange", cut=0, linewidth = 3)
fig = sns.kdeplot(R95T_DongBei, color="r", cut=0, linewidth = 3)
fig = sns.kdeplot(R95T_HuaBei, color="mediumaquamarine", cut=0, linewidth = 3)
fig = sns.kdeplot(R95T_HuaDong, color="peru", cut=0, linewidth = 3)
fig = sns.kdeplot(R95T_HuaNan, color="tan", cut=0, linewidth = 3)
fig = sns.kdeplot(R95T_HuaZhong, color="teal", cut=0, linewidth = 3)
fig = sns.kdeplot(R95T_XiBei, color="deepskyblue", cut=0, linewidth = 3)
fig = sns.kdeplot(R95T_XiNan, color="b", cut=0, linewidth = 3)
plt.title('R95T',fontdict={'weight':'bold','size': 14})
col_labels = ['District','Mean']
table_vals = [['All',round(np.mean(R95T_))],['DongBei',round(np.mean(R95T_DongBei))],['HuaBei',round(np.mean(R95T_HuaBei))],['HuaDong',round(np.mean(R95T_HuaDong))],['HuaNan',round(np.mean(R95T_HuaNan))],['HuaZhong',round(np.mean(R95T_HuaZhong))],['XiBei',round(np.mean(R95T_XiBei))],['XiNan',round(np.mean(R95T_XiNan))]]
my_table = plt.table(cellText=table_vals, colWidths=[0.1]*8, colLabels=col_labels, loc=2, cellLoc='center', colColours=['gold','gold'])
my_table.scale(1.8, 1.6)
my_table.auto_set_font_size(False)
my_table.set_fontsize(11)
sns.despine()
fig.set_xlabel("R95T(day)", fontsize = 10, weight='bold', style='italic')
ax = plt.gca()
plt.text(-0.15,1, '(g)', fontsize=16, color='k',weight='bold', transform=ax.transAxes)
fig.set_ylabel('')
plt.savefig('R95T.tiff', dpi = 600)

sns.set(style='darkgrid')
Districts = ['All']*15388+['DongBei']*1424+['HuaBei']*2572+['HuaDong']*1219+['HuaNan']*641+['HuaZhong']*852+['XiBei']*4901+['XiNan']*3445
df = pd.DataFrame({'Districts' : Districts, 
                  'R95T' : R95T_+R95T_DongBei+R95T_HuaBei+R95T_HuaDong+R95T_HuaNan+R95T_HuaZhong+R95T_XiBei+R95T_XiNan})
plt.title('R95T',fontdict={'weight':'bold','size': 14})
fig = sns.violinplot(x='Districts', y='R95T', data=df, linewidth=0.8, palette='Set3', scale='width')
fig.set_ylabel('Density(day)',fontsize = 10, weight='bold', style='italic')
fig.set_xlabel('')
fig.set_xticklabels(labels=['All','DongBei','HuaBei','HuaDong','HuaNan','HuaZhong','XiBei','XiNan'], rotation = 15, fontsize = 10)
ax = plt.gca()
plt.text(-0.15,1, '(g)', fontsize=16, color='k',weight='bold', transform=ax.transAxes)
plt.savefig('R95T.tiff', dpi =600)

sns.set(style='ticks')
filename = os.listdir('C:/Users/***/Desktop/500_100/precip_r')
R95T = pd.DataFrame()
for name in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/precip_r/{}'.format(name))
    R95T.insert(loc=len(R95T.columns), column=name, value=list(data['R95T']))
results = list(R95T.mean(axis=1))
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
years = [i for i in range(1961,2020)]
plt.xticks(years)
ax1.set_xticks([1961,1965,1970,1975,1980,1985,1990,1995,2000,2005,2010,2015,2019])
ax1.set_xticklabels(['1961','1965','1970','1975','1980','1985','1990','1995','2000','2005','2010','2015','2019'], fontsize = 14)
ax1.set_ylabel('R95T(days)', fontsize=16, weight='bold')
ax1.tick_params(axis='y', colors='navy', labelsize=12)
ax1.plot(years, results, 'b--', color = "deepskyblue")
sns.regplot(years, results, color='darkorange')
ax = plt.gca()
plt.text(-0.08,1, '(g)', fontsize=22, color='k', weight='bold', transform=ax.transAxes)
plt.savefig('R95T.tiff',dpi = 600)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import pandas as pd
sns.set(style='ticks')
Districts = ['All of China','DongBei','HuaBei','HuaDong','HuaNan','HuaZhong','XiBei','XiNan']

filename = os.listdir('C:/Users/***/Desktop/500_100/precip_r')
PRCPTOP_ = []
SDII_ = []
RX1D_ = []
RX5D_ = []
R95p_ = []
R95T_ = []
R99p_ = []
R99T_ = []
CWD_ = []
CDD_ = []
R10MM_ = []
R20MM_ = []
R25MM_ = []
R50MM_ = []
R65MM_ = []
R115MM_ = []
R205MM_ = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/precip_r/{}'.format(i))
    PRCPTOP_.append(data['PRCPTOP'].mean())
    SDII_.append(data['SDII'].mean())
    RX1D_.append(data['RX1D'].mean())
    RX5D_.append(data['RX5D'].mean())
    R95p_.append(data['R95p'].mean())
    R95T_.append(data['R95T'].mean())
    R99p_.append(data['R99p'].mean())
    R99T_.append(data['R99T'].mean())
    CWD_.append(data['CWD'].mean())
    CDD_.append(data['CDD'].mean())
    R10MM_.append(data['R10MM'].mean())
    R20MM_.append(data['R20MM'].mean())
    R25MM_.append(data['R25MM'].mean())
    R50MM_.append(data['R50MM'].mean())
    R65MM_.append(data['R65MM'].mean())
    R115MM_.append(data['R115MM'].mean())
    R205MM_.append(data['R205MM'].mean())
    
filename = os.listdir('C:/Users/***/Desktop/500_100/DongBei')
PRCPTOP_DongBei = []
SDII_DongBei = []
RX1D_DongBei = []
RX5D_DongBei = []
R95p_DongBei = []
R95T_DongBei = []
R99p_DongBei = []
R99T_DongBei = []
CWD_DongBei= []
CDD_DongBei = []
R10MM_DongBei = []
R20MM_DongBei = []
R25MM_DongBei = []
R50MM_DongBei = []
R65MM_DongBei = []
R115MM_DongBei = []
R205MM_DongBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/DongBei/{}'.format(i))
    PRCPTOP_DongBei.append(data['PRCPTOP'].mean())
    SDII_DongBei.append(data['SDII'].mean())
    RX1D_DongBei.append(data['RX1D'].mean())
    RX5D_DongBei.append(data['RX5D'].mean())
    R95p_DongBei.append(data['R95p'].mean())
    R95T_DongBei.append(data['R95T'].mean())
    R99p_DongBei.append(data['R99p'].mean())
    R99T_DongBei.append(data['R99T'].mean())
    CWD_DongBei.append(data['CWD'].mean())
    CDD_DongBei.append(data['CDD'].mean())
    R10MM_DongBei.append(data['R10MM'].mean())
    R20MM_DongBei.append(data['R20MM'].mean())
    R25MM_DongBei.append(data['R25MM'].mean())
    R50MM_DongBei.append(data['R50MM'].mean())
    R65MM_DongBei.append(data['R65MM'].mean())
    R115MM_DongBei.append(data['R115MM'].mean())
    R205MM_DongBei.append(data['R205MM'].mean())
    
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaBei')
PRCPTOP_HuaBei = []
SDII_HuaBei = []
RX1D_HuaBei = []
RX5D_HuaBei = []
R95p_HuaBei = []
R95T_HuaBei = []
R99p_HuaBei = []
R99T_HuaBei = []
CWD_HuaBei= []
CDD_HuaBei = []
R10MM_HuaBei = []
R20MM_HuaBei = []
R25MM_HuaBei = []
R50MM_HuaBei = []
R65MM_HuaBei = []
R115MM_HuaBei = []
R205MM_HuaBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaBei/{}'.format(i))
    PRCPTOP_HuaBei.append(data['PRCPTOP'].mean())
    SDII_HuaBei.append(data['SDII'].mean())
    RX1D_HuaBei.append(data['RX1D'].mean())
    RX5D_HuaBei.append(data['RX5D'].mean())
    R95p_HuaBei.append(data['R95p'].mean())
    R95T_HuaBei.append(data['R95T'].mean())
    R99p_HuaBei.append(data['R99p'].mean())
    R99T_HuaBei.append(data['R99T'].mean())
    CWD_HuaBei.append(data['CWD'].mean())
    CDD_HuaBei.append(data['CDD'].mean())
    R10MM_HuaBei.append(data['R10MM'].mean())
    R20MM_HuaBei.append(data['R20MM'].mean())
    R25MM_HuaBei.append(data['R25MM'].mean())
    R50MM_HuaBei.append(data['R50MM'].mean())
    R65MM_HuaBei.append(data['R65MM'].mean())
    R115MM_HuaBei.append(data['R115MM'].mean())
    R205MM_HuaBei.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaDong')
PRCPTOP_HuaDong = []
SDII_HuaDong = []
RX1D_HuaDong = []
RX5D_HuaDong = []
R95p_HuaDong = []
R95T_HuaDong = []
R99p_HuaDong = []
R99T_HuaDong = []
CWD_HuaDong = []
CDD_HuaDong = []
R10MM_HuaDong = []
R20MM_HuaDong = []
R25MM_HuaDong = []
R50MM_HuaDong = []
R65MM_HuaDong = []
R115MM_HuaDong = []
R205MM_HuaDong = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaDong/{}'.format(i))
    PRCPTOP_HuaDong.append(data['PRCPTOP'].mean())
    SDII_HuaDong.append(data['SDII'].mean())
    RX1D_HuaDong.append(data['RX1D'].mean())
    RX5D_HuaDong.append(data['RX5D'].mean())
    R95p_HuaDong.append(data['R95p'].mean())
    R95T_HuaDong.append(data['R95T'].mean())
    R99p_HuaDong.append(data['R99p'].mean())
    R99T_HuaDong.append(data['R99T'].mean())
    CWD_HuaDong.append(data['CWD'].mean())
    CDD_HuaDong.append(data['CDD'].mean())
    R10MM_HuaDong.append(data['R10MM'].mean())
    R20MM_HuaDong.append(data['R20MM'].mean())
    R25MM_HuaDong.append(data['R25MM'].mean())
    R50MM_HuaDong.append(data['R50MM'].mean())
    R65MM_HuaDong.append(data['R65MM'].mean())
    R115MM_HuaDong.append(data['R115MM'].mean())
    R205MM_HuaDong.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaNan')
PRCPTOP_HuaNan = []
SDII_HuaNan = []
RX1D_HuaNan = []
RX5D_HuaNan = []
R95p_HuaNan = []
R95T_HuaNan = []
R99p_HuaNan = []
R99T_HuaNan = []
CWD_HuaNan = []
CDD_HuaNan = []
R10MM_HuaNan = []
R20MM_HuaNan = []
R25MM_HuaNan = []
R50MM_HuaNan = []
R65MM_HuaNan = []
R115MM_HuaNan = []
R205MM_HuaNan = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaNan/{}'.format(i))
    PRCPTOP_HuaNan.append(data['PRCPTOP'].mean())
    SDII_HuaNan.append(data['SDII'].mean())
    RX1D_HuaNan.append(data['RX1D'].mean())
    RX5D_HuaNan.append(data['RX5D'].mean())
    R95p_HuaNan.append(data['R95p'].mean())
    R95T_HuaNan.append(data['R95T'].mean())
    R99p_HuaNan.append(data['R99p'].mean())
    R99T_HuaNan.append(data['R99T'].mean())
    CWD_HuaNan.append(data['CWD'].mean())
    CDD_HuaNan.append(data['CDD'].mean())
    R10MM_HuaNan.append(data['R10MM'].mean())
    R20MM_HuaNan.append(data['R20MM'].mean())
    R25MM_HuaNan.append(data['R25MM'].mean())
    R50MM_HuaNan.append(data['R50MM'].mean())
    R65MM_HuaNan.append(data['R65MM'].mean())
    R115MM_HuaNan.append(data['R115MM'].mean())
    R205MM_HuaNan.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaZhong')
PRCPTOP_HuaZhong = []
SDII_HuaZhong = []
RX1D_HuaZhong = []
RX5D_HuaZhong = []
R95p_HuaZhong = []
R95T_HuaZhong = []
R99p_HuaZhong = []
R99T_HuaZhong = []
CWD_HuaZhong = []
CDD_HuaZhong = []
R10MM_HuaZhong = []
R20MM_HuaZhong = []
R25MM_HuaZhong = []
R50MM_HuaZhong = []
R65MM_HuaZhong = []
R115MM_HuaZhong = []
R205MM_HuaZhong = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaZhong/{}'.format(i))
    PRCPTOP_HuaZhong.append(data['PRCPTOP'].mean())
    SDII_HuaZhong.append(data['SDII'].mean())
    RX1D_HuaZhong.append(data['RX1D'].mean())
    RX5D_HuaZhong.append(data['RX5D'].mean())
    R95p_HuaZhong.append(data['R95p'].mean())
    R95T_HuaZhong.append(data['R95T'].mean())
    R99p_HuaZhong.append(data['R99p'].mean())
    R99T_HuaZhong.append(data['R99T'].mean())
    CWD_HuaZhong.append(data['CWD'].mean())
    CDD_HuaZhong.append(data['CDD'].mean())
    R10MM_HuaZhong.append(data['R10MM'].mean())
    R20MM_HuaZhong.append(data['R20MM'].mean())
    R25MM_HuaZhong.append(data['R25MM'].mean())
    R50MM_HuaZhong.append(data['R50MM'].mean())
    R65MM_HuaZhong.append(data['R65MM'].mean())
    R115MM_HuaZhong.append(data['R115MM'].mean())
    R205MM_HuaZhong.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/XiBei')
PRCPTOP_XiBei = []
SDII_XiBei = []
RX1D_XiBei = []
RX5D_XiBei = []
R95p_XiBei = []
R95T_XiBei = []
R99p_XiBei = []
R99T_XiBei = []
CWD_XiBei = []
CDD_XiBei = []
R10MM_XiBei = []
R20MM_XiBei = []
R25MM_XiBei = []
R50MM_XiBei = []
R65MM_XiBei = []
R115MM_XiBei = []
R205MM_XiBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/XiBei/{}'.format(i))
    PRCPTOP_XiBei.append(data['PRCPTOP'].mean())
    SDII_XiBei.append(data['SDII'].mean())
    RX1D_XiBei.append(data['RX1D'].mean())
    RX5D_XiBei.append(data['RX5D'].mean())
    R95p_XiBei.append(data['R95p'].mean())
    R95T_XiBei.append(data['R95T'].mean())
    R99p_XiBei.append(data['R99p'].mean())
    R99T_XiBei.append(data['R99T'].mean())
    CWD_XiBei.append(data['CWD'].mean())
    CDD_XiBei.append(data['CDD'].mean())
    R10MM_XiBei.append(data['R10MM'].mean())
    R20MM_XiBei.append(data['R20MM'].mean())
    R25MM_XiBei.append(data['R25MM'].mean())
    R50MM_XiBei.append(data['R50MM'].mean())
    R65MM_XiBei.append(data['R65MM'].mean())
    R115MM_XiBei.append(data['R115MM'].mean())
    R205MM_XiBei.append(data['R205MM'].mean())

filename = os.listdir('C:/Users/***/Desktop/500_100/XiNan')
PRCPTOP_XiNan = []
SDII_XiNan = []
RX1D_XiNan = []
RX5D_XiNan = []
R95p_XiNan = []
R95T_XiNan = []
R99p_XiNan = []
R99T_XiNan = []
CWD_XiNan = []
CDD_XiNan = []
R10MM_XiNan = []
R20MM_XiNan = []
R25MM_XiNan = []
R50MM_XiNan = []
R65MM_XiNan = []
R115MM_XiNan = []
R205MM_XiNan = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/XiNan/{}'.format(i))
    PRCPTOP_XiNan.append(data['PRCPTOP'].mean())
    SDII_XiNan.append(data['SDII'].mean())
    RX1D_XiNan.append(data['RX1D'].mean())
    RX5D_XiNan.append(data['RX5D'].mean())
    R95p_XiNan.append(data['R95p'].mean())
    R95T_XiNan.append(data['R95T'].mean())
    R99p_XiNan.append(data['R99p'].mean())
    R99T_XiNan.append(data['R99T'].mean())
    CWD_XiNan.append(data['CWD'].mean())
    CDD_XiNan.append(data['CDD'].mean())
    R10MM_XiNan.append(data['R10MM'].mean())
    R20MM_XiNan.append(data['R20MM'].mean())
    R25MM_XiNan.append(data['R25MM'].mean())
    R50MM_XiNan.append(data['R50MM'].mean())
    R65MM_XiNan.append(data['R65MM'].mean())
    R115MM_XiNan.append(data['R115MM'].mean())
    R205MM_XiNan.append(data['R205MM'].mean())
    
fig = sns.kdeplot(R99p_, color="darkorange", cut=0, linewidth = 3)
fig = sns.kdeplot(R99p_DongBei, color="r", cut=0, linewidth = 3)
fig = sns.kdeplot(R99p_HuaBei, color="mediumaquamarine", cut=0, linewidth = 3)
fig = sns.kdeplot(R99p_HuaDong, color="peru", cut=0, linewidth = 3)
fig = sns.kdeplot(R99p_HuaNan, color="tan", cut=0, linewidth = 3)
fig = sns.kdeplot(R99p_HuaZhong, color="teal", cut=0, linewidth = 3)
fig = sns.kdeplot(R99p_XiBei, color="deepskyblue", cut=0, linewidth = 3)
fig = sns.kdeplot(R99p_XiNan, color="b", cut=0, linewidth = 3)
plt.title('R99p',fontdict={'weight':'bold','size': 14})
col_labels = ['District','Mean']
table_vals = [['All',round(np.mean(R99p_))],['DongBei',round(np.mean(R99p_DongBei))],['HuaBei',round(np.mean(R99p_HuaBei))],['HuaDong',round(np.mean(R99p_HuaDong))],['HuaNan',round(np.mean(R99p_HuaNan))],['HuaZhong',round(np.mean(R99p_HuaZhong))],['XiBei',round(np.mean(R99p_XiBei))],['XiNan',round(np.mean(R99p_XiNan))]]
my_table = plt.table(cellText=table_vals, colWidths=[0.1]*8, colLabels=col_labels, loc='best', cellLoc='center', colColours=['gold','gold'])
my_table.scale(1.8, 1.6)
my_table.auto_set_font_size(False)
my_table.set_fontsize(11)
sns.despine()
fig.set_xlabel("R99p(mm)", fontsize = 10, weight='bold', style='italic')
ax = plt.gca()
plt.text(-0.15,1, '(f)', fontsize=16, color='k',weight='bold', transform=ax.transAxes)
fig.set_xlim([-10, 330])
fig.set_ylabel('')
plt.savefig('R99p.tiff', dpi = 600)

sns.set(style='darkgrid')
Districts = ['All']*15388+['DongBei']*1424+['HuaBei']*2572+['HuaDong']*1219+['HuaNan']*641+['HuaZhong']*852+['XiBei']*4901+['XiNan']*3445
df = pd.DataFrame({'Districts' : Districts, 
                  'R99p' : R99p_+R99p_DongBei+R99p_HuaBei+R99p_HuaDong+R99p_HuaNan+R99p_HuaZhong+R99p_XiBei+R99p_XiNan})
plt.title('R99p',fontdict={'weight':'bold','size': 14})
fig = sns.violinplot(x='Districts', y='R99p', data=df, linewidth=0.8, palette='Set3', scale='width')
fig.set_ylabel('Density(mm)',fontsize = 10, weight='bold', style='italic')
fig.set_xlabel('')
fig.set_xticklabels(labels=['All','DongBei','HuaBei','HuaDong','HuaNan','HuaZhong','XiBei','XiNan'], rotation = 15, fontsize = 10)
ax = plt.gca()
plt.text(-0.15,1, '(f)', fontsize=16, color='k',weight='bold', transform=ax.transAxes)
plt.savefig('R99p.tiff', dpi =600)

sns.set(style='ticks')
filename = os.listdir('C:/Users/***/Desktop/500_100/precip_r')
R99p = pd.DataFrame()
for name in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/precip_r/{}'.format(name))
    R99p.insert(loc=len(R99p.columns), column=name, value=list(data['R99p']))
results = list(R99p.mean(axis=1))
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
years = [i for i in range(1961,2020)]
plt.xticks(years)
ax1.set_xticks([1961,1965,1970,1975,1980,1985,1990,1995,2000,2005,2010,2015,2019])
ax1.set_xticklabels(['1961','1965','1970','1975','1980','1985','1990','1995','2000','2005','2010','2015','2019'], fontsize = 14)
ax1.set_ylabel('R99p(mm)', fontsize=16, weight='bold')
ax1.tick_params(axis='y', colors='navy', labelsize=12)
ax1.plot(years, results, 'b--', color = "deepskyblue")
sns.regplot(years, results, color='darkorange')
ax = plt.gca()
plt.text(-0.08,1, '(f)', fontsize=22, color='k', weight='bold', transform=ax.transAxes)
plt.savefig('R99p.tiff',dpi = 600)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import pandas as pd
sns.set(style='ticks')
Districts = ['All of China','DongBei','HuaBei','HuaDong','HuaNan','HuaZhong','XiBei','XiNan']

filename = os.listdir('C:/Users/***/Desktop/500_100/precip_r')
PRCPTOP_ = []
SDII_ = []
RX1D_ = []
RX5D_ = []
R95p_ = []
R95T_ = []
R99p_ = []
R99T_ = []
CWD_ = []
CDD_ = []
R10MM_ = []
R20MM_ = []
R25MM_ = []
R50MM_ = []
R65MM_ = []
R115MM_ = []
R205MM_ = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/precip_r/{}'.format(i))
    PRCPTOP_.append(data['PRCPTOP'].mean())
    SDII_.append(data['SDII'].mean())
    RX1D_.append(data['RX1D'].mean())
    RX5D_.append(data['RX5D'].mean())
    R95p_.append(data['R95p'].mean())
    R95T_.append(data['R95T'].mean())
    R99p_.append(data['R99p'].mean())
    R99T_.append(data['R99T'].mean())
    CWD_.append(data['CWD'].mean())
    CDD_.append(data['CDD'].mean())
    R10MM_.append(data['R10MM'].mean())
    R20MM_.append(data['R20MM'].mean())
    R25MM_.append(data['R25MM'].mean())
    R50MM_.append(data['R50MM'].mean())
    R65MM_.append(data['R65MM'].mean())
    R115MM_.append(data['R115MM'].mean())
    R205MM_.append(data['R205MM'].mean())
    
filename = os.listdir('C:/Users/***/Desktop/500_100/DongBei')
PRCPTOP_DongBei = []
SDII_DongBei = []
RX1D_DongBei = []
RX5D_DongBei = []
R95p_DongBei = []
R95T_DongBei = []
R99p_DongBei = []
R99T_DongBei = []
CWD_DongBei= []
CDD_DongBei = []
R10MM_DongBei = []
R20MM_DongBei = []
R25MM_DongBei = []
R50MM_DongBei = []
R65MM_DongBei = []
R115MM_DongBei = []
R205MM_DongBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/DongBei/{}'.format(i))
    PRCPTOP_DongBei.append(data['PRCPTOP'].mean())
    SDII_DongBei.append(data['SDII'].mean())
    RX1D_DongBei.append(data['RX1D'].mean())
    RX5D_DongBei.append(data['RX5D'].mean())
    R95p_DongBei.append(data['R95p'].mean())
    R95T_DongBei.append(data['R95T'].mean())
    R99p_DongBei.append(data['R99p'].mean())
    R99T_DongBei.append(data['R99T'].mean())
    CWD_DongBei.append(data['CWD'].mean())
    CDD_DongBei.append(data['CDD'].mean())
    R10MM_DongBei.append(data['R10MM'].mean())
    R20MM_DongBei.append(data['R20MM'].mean())
    R25MM_DongBei.append(data['R25MM'].mean())
    R50MM_DongBei.append(data['R50MM'].mean())
    R65MM_DongBei.append(data['R65MM'].mean())
    R115MM_DongBei.append(data['R115MM'].mean())
    R205MM_DongBei.append(data['R205MM'].mean())
    
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaBei')
PRCPTOP_HuaBei = []
SDII_HuaBei = []
RX1D_HuaBei = []
RX5D_HuaBei = []
R95p_HuaBei = []
R95T_HuaBei = []
R99p_HuaBei = []
R99T_HuaBei = []
CWD_HuaBei= []
CDD_HuaBei = []
R10MM_HuaBei = []
R20MM_HuaBei = []
R25MM_HuaBei = []
R50MM_HuaBei = []
R65MM_HuaBei = []
R115MM_HuaBei = []
R205MM_HuaBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaBei/{}'.format(i))
    PRCPTOP_HuaBei.append(data['PRCPTOP'].mean())
    SDII_HuaBei.append(data['SDII'].mean())
    RX1D_HuaBei.append(data['RX1D'].mean())
    RX5D_HuaBei.append(data['RX5D'].mean())
    R95p_HuaBei.append(data['R95p'].mean())
    R95T_HuaBei.append(data['R95T'].mean())
    R99p_HuaBei.append(data['R99p'].mean())
    R99T_HuaBei.append(data['R99T'].mean())
    CWD_HuaBei.append(data['CWD'].mean())
    CDD_HuaBei.append(data['CDD'].mean())
    R10MM_HuaBei.append(data['R10MM'].mean())
    R20MM_HuaBei.append(data['R20MM'].mean())
    R25MM_HuaBei.append(data['R25MM'].mean())
    R50MM_HuaBei.append(data['R50MM'].mean())
    R65MM_HuaBei.append(data['R65MM'].mean())
    R115MM_HuaBei.append(data['R115MM'].mean())
    R205MM_HuaBei.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaDong')
PRCPTOP_HuaDong = []
SDII_HuaDong = []
RX1D_HuaDong = []
RX5D_HuaDong = []
R95p_HuaDong = []
R95T_HuaDong = []
R99p_HuaDong = []
R99T_HuaDong = []
CWD_HuaDong = []
CDD_HuaDong = []
R10MM_HuaDong = []
R20MM_HuaDong = []
R25MM_HuaDong = []
R50MM_HuaDong = []
R65MM_HuaDong = []
R115MM_HuaDong = []
R205MM_HuaDong = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaDong/{}'.format(i))
    PRCPTOP_HuaDong.append(data['PRCPTOP'].mean())
    SDII_HuaDong.append(data['SDII'].mean())
    RX1D_HuaDong.append(data['RX1D'].mean())
    RX5D_HuaDong.append(data['RX5D'].mean())
    R95p_HuaDong.append(data['R95p'].mean())
    R95T_HuaDong.append(data['R95T'].mean())
    R99p_HuaDong.append(data['R99p'].mean())
    R99T_HuaDong.append(data['R99T'].mean())
    CWD_HuaDong.append(data['CWD'].mean())
    CDD_HuaDong.append(data['CDD'].mean())
    R10MM_HuaDong.append(data['R10MM'].mean())
    R20MM_HuaDong.append(data['R20MM'].mean())
    R25MM_HuaDong.append(data['R25MM'].mean())
    R50MM_HuaDong.append(data['R50MM'].mean())
    R65MM_HuaDong.append(data['R65MM'].mean())
    R115MM_HuaDong.append(data['R115MM'].mean())
    R205MM_HuaDong.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaNan')
PRCPTOP_HuaNan = []
SDII_HuaNan = []
RX1D_HuaNan = []
RX5D_HuaNan = []
R95p_HuaNan = []
R95T_HuaNan = []
R99p_HuaNan = []
R99T_HuaNan = []
CWD_HuaNan = []
CDD_HuaNan = []
R10MM_HuaNan = []
R20MM_HuaNan = []
R25MM_HuaNan = []
R50MM_HuaNan = []
R65MM_HuaNan = []
R115MM_HuaNan = []
R205MM_HuaNan = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaNan/{}'.format(i))
    PRCPTOP_HuaNan.append(data['PRCPTOP'].mean())
    SDII_HuaNan.append(data['SDII'].mean())
    RX1D_HuaNan.append(data['RX1D'].mean())
    RX5D_HuaNan.append(data['RX5D'].mean())
    R95p_HuaNan.append(data['R95p'].mean())
    R95T_HuaNan.append(data['R95T'].mean())
    R99p_HuaNan.append(data['R99p'].mean())
    R99T_HuaNan.append(data['R99T'].mean())
    CWD_HuaNan.append(data['CWD'].mean())
    CDD_HuaNan.append(data['CDD'].mean())
    R10MM_HuaNan.append(data['R10MM'].mean())
    R20MM_HuaNan.append(data['R20MM'].mean())
    R25MM_HuaNan.append(data['R25MM'].mean())
    R50MM_HuaNan.append(data['R50MM'].mean())
    R65MM_HuaNan.append(data['R65MM'].mean())
    R115MM_HuaNan.append(data['R115MM'].mean())
    R205MM_HuaNan.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaZhong')
PRCPTOP_HuaZhong = []
SDII_HuaZhong = []
RX1D_HuaZhong = []
RX5D_HuaZhong = []
R95p_HuaZhong = []
R95T_HuaZhong = []
R99p_HuaZhong = []
R99T_HuaZhong = []
CWD_HuaZhong = []
CDD_HuaZhong = []
R10MM_HuaZhong = []
R20MM_HuaZhong = []
R25MM_HuaZhong = []
R50MM_HuaZhong = []
R65MM_HuaZhong = []
R115MM_HuaZhong = []
R205MM_HuaZhong = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaZhong/{}'.format(i))
    PRCPTOP_HuaZhong.append(data['PRCPTOP'].mean())
    SDII_HuaZhong.append(data['SDII'].mean())
    RX1D_HuaZhong.append(data['RX1D'].mean())
    RX5D_HuaZhong.append(data['RX5D'].mean())
    R95p_HuaZhong.append(data['R95p'].mean())
    R95T_HuaZhong.append(data['R95T'].mean())
    R99p_HuaZhong.append(data['R99p'].mean())
    R99T_HuaZhong.append(data['R99T'].mean())
    CWD_HuaZhong.append(data['CWD'].mean())
    CDD_HuaZhong.append(data['CDD'].mean())
    R10MM_HuaZhong.append(data['R10MM'].mean())
    R20MM_HuaZhong.append(data['R20MM'].mean())
    R25MM_HuaZhong.append(data['R25MM'].mean())
    R50MM_HuaZhong.append(data['R50MM'].mean())
    R65MM_HuaZhong.append(data['R65MM'].mean())
    R115MM_HuaZhong.append(data['R115MM'].mean())
    R205MM_HuaZhong.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/XiBei')
PRCPTOP_XiBei = []
SDII_XiBei = []
RX1D_XiBei = []
RX5D_XiBei = []
R95p_XiBei = []
R95T_XiBei = []
R99p_XiBei = []
R99T_XiBei = []
CWD_XiBei = []
CDD_XiBei = []
R10MM_XiBei = []
R20MM_XiBei = []
R25MM_XiBei = []
R50MM_XiBei = []
R65MM_XiBei = []
R115MM_XiBei = []
R205MM_XiBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/XiBei/{}'.format(i))
    PRCPTOP_XiBei.append(data['PRCPTOP'].mean())
    SDII_XiBei.append(data['SDII'].mean())
    RX1D_XiBei.append(data['RX1D'].mean())
    RX5D_XiBei.append(data['RX5D'].mean())
    R95p_XiBei.append(data['R95p'].mean())
    R95T_XiBei.append(data['R95T'].mean())
    R99p_XiBei.append(data['R99p'].mean())
    R99T_XiBei.append(data['R99T'].mean())
    CWD_XiBei.append(data['CWD'].mean())
    CDD_XiBei.append(data['CDD'].mean())
    R10MM_XiBei.append(data['R10MM'].mean())
    R20MM_XiBei.append(data['R20MM'].mean())
    R25MM_XiBei.append(data['R25MM'].mean())
    R50MM_XiBei.append(data['R50MM'].mean())
    R65MM_XiBei.append(data['R65MM'].mean())
    R115MM_XiBei.append(data['R115MM'].mean())
    R205MM_XiBei.append(data['R205MM'].mean())

filename = os.listdir('C:/Users/***/Desktop/500_100/XiNan')
PRCPTOP_XiNan = []
SDII_XiNan = []
RX1D_XiNan = []
RX5D_XiNan = []
R95p_XiNan = []
R95T_XiNan = []
R99p_XiNan = []
R99T_XiNan = []
CWD_XiNan = []
CDD_XiNan = []
R10MM_XiNan = []
R20MM_XiNan = []
R25MM_XiNan = []
R50MM_XiNan = []
R65MM_XiNan = []
R115MM_XiNan = []
R205MM_XiNan = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/XiNan/{}'.format(i))
    PRCPTOP_XiNan.append(data['PRCPTOP'].mean())
    SDII_XiNan.append(data['SDII'].mean())
    RX1D_XiNan.append(data['RX1D'].mean())
    RX5D_XiNan.append(data['RX5D'].mean())
    R95p_XiNan.append(data['R95p'].mean())
    R95T_XiNan.append(data['R95T'].mean())
    R99p_XiNan.append(data['R99p'].mean())
    R99T_XiNan.append(data['R99T'].mean())
    CWD_XiNan.append(data['CWD'].mean())
    CDD_XiNan.append(data['CDD'].mean())
    R10MM_XiNan.append(data['R10MM'].mean())
    R20MM_XiNan.append(data['R20MM'].mean())
    R25MM_XiNan.append(data['R25MM'].mean())
    R50MM_XiNan.append(data['R50MM'].mean())
    R65MM_XiNan.append(data['R65MM'].mean())
    R115MM_XiNan.append(data['R115MM'].mean())
    R205MM_XiNan.append(data['R205MM'].mean())
    
fig = sns.kdeplot(R99T_, color="darkorange", cut=0, linewidth = 3)
fig = sns.kdeplot(R99T_DongBei, color="r", cut=0, linewidth = 3)
fig = sns.kdeplot(R99T_HuaBei, color="mediumaquamarine", cut=0, linewidth = 3)
fig = sns.kdeplot(R99T_HuaDong, color="peru", cut=0, linewidth = 3)
fig = sns.kdeplot(R99T_HuaNan, color="tan", cut=0, linewidth = 3)
fig = sns.kdeplot(R99T_HuaZhong, color="teal", cut=0, linewidth = 3)
fig = sns.kdeplot(R99T_XiBei, color="deepskyblue", cut=0, linewidth = 3)
fig = sns.kdeplot(R99T_XiNan, color="b", cut=0, linewidth = 3)
plt.title('R99T',fontdict={'weight':'bold','size': 14})
col_labels = ['District','Mean']
table_vals = [['All',round(np.mean(R99T_))],['DongBei',round(np.mean(R99T_DongBei))],['HuaBei',round(np.mean(R99T_HuaBei))],['HuaDong',round(np.mean(R99T_HuaDong))],['HuaNan',round(np.mean(R99T_HuaNan))],['HuaZhong',round(np.mean(R99T_HuaZhong))],['XiBei',round(np.mean(R99T_XiBei))],['XiNan',round(np.mean(R99T_XiNan))]]
my_table = plt.table(cellText=table_vals, colWidths=[0.1]*8, colLabels=col_labels, loc=2, cellLoc='center', colColours=['gold','gold'])
my_table.scale(1.8, 1.6)
my_table.auto_set_font_size(False)
my_table.set_fontsize(11)
sns.despine()
fig.set_xlabel("R99T(day)", fontsize = 10, weight='bold', style='italic')
ax = plt.gca()
plt.text(-0.15,1, '(h)', fontsize=16, color='k',weight='bold', transform=ax.transAxes)
fig.set_xlim([1.3, 3.2])
fig.set_ylabel('')
plt.savefig('R99T.tiff', dpi = 600)

sns.set(style='darkgrid')
Districts = ['All']*15388+['DongBei']*1424+['HuaBei']*2572+['HuaDong']*1219+['HuaNan']*641+['HuaZhong']*852+['XiBei']*4901+['XiNan']*3445
df = pd.DataFrame({'Districts' : Districts, 
                  'R99T' : R99T_+R99T_DongBei+R99T_HuaBei+R99T_HuaDong+R99T_HuaNan+R99T_HuaZhong+R99T_XiBei+R99T_XiNan})
plt.title('R99T',fontdict={'weight':'bold','size': 14})
fig = sns.violinplot(x='Districts', y='R99T', data=df, linewidth=0.8, palette='Set3', scale='width')
fig.set_ylabel('Density(day)',fontsize = 10, weight='bold', style='italic')
fig.set_xlabel('')
fig.set_xticklabels(labels=['All','DongBei','HuaBei','HuaDong','HuaNan','HuaZhong','XiBei','XiNan'], rotation = 15, fontsize = 10)
ax = plt.gca()
plt.text(-0.15,1, '(h)', fontsize=16, color='k',weight='bold', transform=ax.transAxes)
plt.savefig('R99T.tiff', dpi =600)

sns.set(style='ticks')
filename = os.listdir('C:/Users/***/Desktop/500_100/precip_r')
R99T = pd.DataFrame()
for name in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/precip_r/{}'.format(name))
    R99T.insert(loc=len(R99T.columns), column=name, value=list(data['R99T']))
results = list(R99T.mean(axis=1))
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
years = [i for i in range(1961,2020)]
plt.xticks(years)
ax1.set_xticks([1961,1965,1970,1975,1980,1985,1990,1995,2000,2005,2010,2015,2019])
ax1.set_xticklabels(['1961','1965','1970','1975','1980','1985','1990','1995','2000','2005','2010','2015','2019'], fontsize = 14)
ax1.set_ylabel('R99T(days)', fontsize=16, weight='bold')
ax1.tick_params(axis='y', colors='navy', labelsize=12)
ax1.plot(years, results, 'b--', color = "deepskyblue")
sns.regplot(years, results, color='darkorange')
ax = plt.gca()
plt.text(-0.08,1, '(h)', fontsize=22, color='k', weight='bold', transform=ax.transAxes)
plt.savefig('R99T.tiff',dpi = 600)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import pandas as pd
sns.set(style='ticks')
Districts = ['All of China','DongBei','HuaBei','HuaDong','HuaNan','HuaZhong','XiBei','XiNan']

filename = os.listdir('C:/Users/***/Desktop/500_100/precip_r')
PRCPTOP_ = []
SDII_ = []
RX1D_ = []
RX5D_ = []
R95p_ = []
R95T_ = []
R99p_ = []
R99T_ = []
CWD_ = []
CDD_ = []
R10MM_ = []
R20MM_ = []
R25MM_ = []
R50MM_ = []
R65MM_ = []
R115MM_ = []
R205MM_ = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/precip_r/{}'.format(i))
    PRCPTOP_.append(data['PRCPTOP'].mean())
    SDII_.append(data['SDII'].mean())
    RX1D_.append(data['RX1D'].mean())
    RX5D_.append(data['RX5D'].mean())
    R95p_.append(data['R95p'].mean())
    R95T_.append(data['R95T'].mean())
    R99p_.append(data['R99p'].mean())
    R99T_.append(data['R99T'].mean())
    CWD_.append(data['CWD'].mean())
    CDD_.append(data['CDD'].mean())
    R10MM_.append(data['R10MM'].mean())
    R20MM_.append(data['R20MM'].mean())
    R25MM_.append(data['R25MM'].mean())
    R50MM_.append(data['R50MM'].mean())
    R65MM_.append(data['R65MM'].mean())
    R115MM_.append(data['R115MM'].mean())
    R205MM_.append(data['R205MM'].mean())
    
filename = os.listdir('C:/Users/***/Desktop/500_100/DongBei')
PRCPTOP_DongBei = []
SDII_DongBei = []
RX1D_DongBei = []
RX5D_DongBei = []
R95p_DongBei = []
R95T_DongBei = []
R99p_DongBei = []
R99T_DongBei = []
CWD_DongBei= []
CDD_DongBei = []
R10MM_DongBei = []
R20MM_DongBei = []
R25MM_DongBei = []
R50MM_DongBei = []
R65MM_DongBei = []
R115MM_DongBei = []
R205MM_DongBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/DongBei/{}'.format(i))
    PRCPTOP_DongBei.append(data['PRCPTOP'].mean())
    SDII_DongBei.append(data['SDII'].mean())
    RX1D_DongBei.append(data['RX1D'].mean())
    RX5D_DongBei.append(data['RX5D'].mean())
    R95p_DongBei.append(data['R95p'].mean())
    R95T_DongBei.append(data['R95T'].mean())
    R99p_DongBei.append(data['R99p'].mean())
    R99T_DongBei.append(data['R99T'].mean())
    CWD_DongBei.append(data['CWD'].mean())
    CDD_DongBei.append(data['CDD'].mean())
    R10MM_DongBei.append(data['R10MM'].mean())
    R20MM_DongBei.append(data['R20MM'].mean())
    R25MM_DongBei.append(data['R25MM'].mean())
    R50MM_DongBei.append(data['R50MM'].mean())
    R65MM_DongBei.append(data['R65MM'].mean())
    R115MM_DongBei.append(data['R115MM'].mean())
    R205MM_DongBei.append(data['R205MM'].mean())
    
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaBei')
PRCPTOP_HuaBei = []
SDII_HuaBei = []
RX1D_HuaBei = []
RX5D_HuaBei = []
R95p_HuaBei = []
R95T_HuaBei = []
R99p_HuaBei = []
R99T_HuaBei = []
CWD_HuaBei= []
CDD_HuaBei = []
R10MM_HuaBei = []
R20MM_HuaBei = []
R25MM_HuaBei = []
R50MM_HuaBei = []
R65MM_HuaBei = []
R115MM_HuaBei = []
R205MM_HuaBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaBei/{}'.format(i))
    PRCPTOP_HuaBei.append(data['PRCPTOP'].mean())
    SDII_HuaBei.append(data['SDII'].mean())
    RX1D_HuaBei.append(data['RX1D'].mean())
    RX5D_HuaBei.append(data['RX5D'].mean())
    R95p_HuaBei.append(data['R95p'].mean())
    R95T_HuaBei.append(data['R95T'].mean())
    R99p_HuaBei.append(data['R99p'].mean())
    R99T_HuaBei.append(data['R99T'].mean())
    CWD_HuaBei.append(data['CWD'].mean())
    CDD_HuaBei.append(data['CDD'].mean())
    R10MM_HuaBei.append(data['R10MM'].mean())
    R20MM_HuaBei.append(data['R20MM'].mean())
    R25MM_HuaBei.append(data['R25MM'].mean())
    R50MM_HuaBei.append(data['R50MM'].mean())
    R65MM_HuaBei.append(data['R65MM'].mean())
    R115MM_HuaBei.append(data['R115MM'].mean())
    R205MM_HuaBei.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaDong')
PRCPTOP_HuaDong = []
SDII_HuaDong = []
RX1D_HuaDong = []
RX5D_HuaDong = []
R95p_HuaDong = []
R95T_HuaDong = []
R99p_HuaDong = []
R99T_HuaDong = []
CWD_HuaDong = []
CDD_HuaDong = []
R10MM_HuaDong = []
R20MM_HuaDong = []
R25MM_HuaDong = []
R50MM_HuaDong = []
R65MM_HuaDong = []
R115MM_HuaDong = []
R205MM_HuaDong = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaDong/{}'.format(i))
    PRCPTOP_HuaDong.append(data['PRCPTOP'].mean())
    SDII_HuaDong.append(data['SDII'].mean())
    RX1D_HuaDong.append(data['RX1D'].mean())
    RX5D_HuaDong.append(data['RX5D'].mean())
    R95p_HuaDong.append(data['R95p'].mean())
    R95T_HuaDong.append(data['R95T'].mean())
    R99p_HuaDong.append(data['R99p'].mean())
    R99T_HuaDong.append(data['R99T'].mean())
    CWD_HuaDong.append(data['CWD'].mean())
    CDD_HuaDong.append(data['CDD'].mean())
    R10MM_HuaDong.append(data['R10MM'].mean())
    R20MM_HuaDong.append(data['R20MM'].mean())
    R25MM_HuaDong.append(data['R25MM'].mean())
    R50MM_HuaDong.append(data['R50MM'].mean())
    R65MM_HuaDong.append(data['R65MM'].mean())
    R115MM_HuaDong.append(data['R115MM'].mean())
    R205MM_HuaDong.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaNan')
PRCPTOP_HuaNan = []
SDII_HuaNan = []
RX1D_HuaNan = []
RX5D_HuaNan = []
R95p_HuaNan = []
R95T_HuaNan = []
R99p_HuaNan = []
R99T_HuaNan = []
CWD_HuaNan = []
CDD_HuaNan = []
R10MM_HuaNan = []
R20MM_HuaNan = []
R25MM_HuaNan = []
R50MM_HuaNan = []
R65MM_HuaNan = []
R115MM_HuaNan = []
R205MM_HuaNan = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaNan/{}'.format(i))
    PRCPTOP_HuaNan.append(data['PRCPTOP'].mean())
    SDII_HuaNan.append(data['SDII'].mean())
    RX1D_HuaNan.append(data['RX1D'].mean())
    RX5D_HuaNan.append(data['RX5D'].mean())
    R95p_HuaNan.append(data['R95p'].mean())
    R95T_HuaNan.append(data['R95T'].mean())
    R99p_HuaNan.append(data['R99p'].mean())
    R99T_HuaNan.append(data['R99T'].mean())
    CWD_HuaNan.append(data['CWD'].mean())
    CDD_HuaNan.append(data['CDD'].mean())
    R10MM_HuaNan.append(data['R10MM'].mean())
    R20MM_HuaNan.append(data['R20MM'].mean())
    R25MM_HuaNan.append(data['R25MM'].mean())
    R50MM_HuaNan.append(data['R50MM'].mean())
    R65MM_HuaNan.append(data['R65MM'].mean())
    R115MM_HuaNan.append(data['R115MM'].mean())
    R205MM_HuaNan.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaZhong')
PRCPTOP_HuaZhong = []
SDII_HuaZhong = []
RX1D_HuaZhong = []
RX5D_HuaZhong = []
R95p_HuaZhong = []
R95T_HuaZhong = []
R99p_HuaZhong = []
R99T_HuaZhong = []
CWD_HuaZhong = []
CDD_HuaZhong = []
R10MM_HuaZhong = []
R20MM_HuaZhong = []
R25MM_HuaZhong = []
R50MM_HuaZhong = []
R65MM_HuaZhong = []
R115MM_HuaZhong = []
R205MM_HuaZhong = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaZhong/{}'.format(i))
    PRCPTOP_HuaZhong.append(data['PRCPTOP'].mean())
    SDII_HuaZhong.append(data['SDII'].mean())
    RX1D_HuaZhong.append(data['RX1D'].mean())
    RX5D_HuaZhong.append(data['RX5D'].mean())
    R95p_HuaZhong.append(data['R95p'].mean())
    R95T_HuaZhong.append(data['R95T'].mean())
    R99p_HuaZhong.append(data['R99p'].mean())
    R99T_HuaZhong.append(data['R99T'].mean())
    CWD_HuaZhong.append(data['CWD'].mean())
    CDD_HuaZhong.append(data['CDD'].mean())
    R10MM_HuaZhong.append(data['R10MM'].mean())
    R20MM_HuaZhong.append(data['R20MM'].mean())
    R25MM_HuaZhong.append(data['R25MM'].mean())
    R50MM_HuaZhong.append(data['R50MM'].mean())
    R65MM_HuaZhong.append(data['R65MM'].mean())
    R115MM_HuaZhong.append(data['R115MM'].mean())
    R205MM_HuaZhong.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/XiBei')
PRCPTOP_XiBei = []
SDII_XiBei = []
RX1D_XiBei = []
RX5D_XiBei = []
R95p_XiBei = []
R95T_XiBei = []
R99p_XiBei = []
R99T_XiBei = []
CWD_XiBei = []
CDD_XiBei = []
R10MM_XiBei = []
R20MM_XiBei = []
R25MM_XiBei = []
R50MM_XiBei = []
R65MM_XiBei = []
R115MM_XiBei = []
R205MM_XiBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/XiBei/{}'.format(i))
    PRCPTOP_XiBei.append(data['PRCPTOP'].mean())
    SDII_XiBei.append(data['SDII'].mean())
    RX1D_XiBei.append(data['RX1D'].mean())
    RX5D_XiBei.append(data['RX5D'].mean())
    R95p_XiBei.append(data['R95p'].mean())
    R95T_XiBei.append(data['R95T'].mean())
    R99p_XiBei.append(data['R99p'].mean())
    R99T_XiBei.append(data['R99T'].mean())
    CWD_XiBei.append(data['CWD'].mean())
    CDD_XiBei.append(data['CDD'].mean())
    R10MM_XiBei.append(data['R10MM'].mean())
    R20MM_XiBei.append(data['R20MM'].mean())
    R25MM_XiBei.append(data['R25MM'].mean())
    R50MM_XiBei.append(data['R50MM'].mean())
    R65MM_XiBei.append(data['R65MM'].mean())
    R115MM_XiBei.append(data['R115MM'].mean())
    R205MM_XiBei.append(data['R205MM'].mean())

filename = os.listdir('C:/Users/***/Desktop/500_100/XiNan')
PRCPTOP_XiNan = []
SDII_XiNan = []
RX1D_XiNan = []
RX5D_XiNan = []
R95p_XiNan = []
R95T_XiNan = []
R99p_XiNan = []
R99T_XiNan = []
CWD_XiNan = []
CDD_XiNan = []
R10MM_XiNan = []
R20MM_XiNan = []
R25MM_XiNan = []
R50MM_XiNan = []
R65MM_XiNan = []
R115MM_XiNan = []
R205MM_XiNan = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/XiNan/{}'.format(i))
    PRCPTOP_XiNan.append(data['PRCPTOP'].mean())
    SDII_XiNan.append(data['SDII'].mean())
    RX1D_XiNan.append(data['RX1D'].mean())
    RX5D_XiNan.append(data['RX5D'].mean())
    R95p_XiNan.append(data['R95p'].mean())
    R95T_XiNan.append(data['R95T'].mean())
    R99p_XiNan.append(data['R99p'].mean())
    R99T_XiNan.append(data['R99T'].mean())
    CWD_XiNan.append(data['CWD'].mean())
    CDD_XiNan.append(data['CDD'].mean())
    R10MM_XiNan.append(data['R10MM'].mean())
    R20MM_XiNan.append(data['R20MM'].mean())
    R25MM_XiNan.append(data['R25MM'].mean())
    R50MM_XiNan.append(data['R50MM'].mean())
    R65MM_XiNan.append(data['R65MM'].mean())
    R115MM_XiNan.append(data['R115MM'].mean())
    R205MM_XiNan.append(data['R205MM'].mean())
    
fig = sns.kdeplot(RX1D_, color="darkorange", cut=0, linewidth = 3)
fig = sns.kdeplot(RX1D_DongBei, color="r", cut=0, linewidth = 3)
fig = sns.kdeplot(RX1D_HuaBei, color="mediumaquamarine", cut=0, linewidth = 3)
fig = sns.kdeplot(RX1D_HuaDong, color="peru", cut=0, linewidth = 3)
fig = sns.kdeplot(RX1D_HuaNan, color="tan", cut=0, linewidth = 3)
fig = sns.kdeplot(RX1D_HuaZhong, color="teal", cut=0, linewidth = 3)
fig = sns.kdeplot(RX1D_XiBei, color="deepskyblue", cut=0, linewidth = 3)
fig = sns.kdeplot(RX1D_XiNan, color="b", cut=0, linewidth = 3)
plt.title('RX1D',fontdict={'weight':'bold','size': 14})
col_labels = ['District','Mean']
table_vals = [['All',round(np.mean(RX1D_))],['DongBei',round(np.mean(RX1D_DongBei))],['HuaBei',round(np.mean(RX1D_HuaBei))],['HuaDong',round(np.mean(RX1D_HuaDong))],['HuaNan',round(np.mean(RX1D_HuaNan))],['HuaZhong',round(np.mean(RX1D_HuaZhong))],['XiBei',round(np.mean(RX1D_XiBei))],['XiNan',round(np.mean(RX1D_XiNan))]]
my_table = plt.table(cellText=table_vals, colWidths=[0.1]*8, colLabels=col_labels, loc='best', cellLoc='center', colColours=['gold','gold'])
my_table.scale(1.8, 1.6)
my_table.auto_set_font_size(False)
my_table.set_fontsize(11)
sns.despine()
fig.set_xlabel("RX1D (mm)", fontsize = 10, weight='bold', style='italic')
ax = plt.gca()
plt.text(-0.15,1, '(c)', fontsize=16, color='k',weight='bold', transform=ax.transAxes)
fig.set_xlim([-4, 150])
fig.set_ylabel('')
plt.savefig('RX1D.tiff', dpi = 600)

sns.set(style='darkgrid')
Districts = ['All']*15388+['DongBei']*1424+['HuaBei']*2572+['HuaDong']*1219+['HuaNan']*641+['HuaZhong']*852+['XiBei']*4901+['XiNan']*3445
df = pd.DataFrame({'Districts' : Districts, 
                  'RX1D' : RX1D_+RX1D_DongBei+RX1D_HuaBei+RX1D_HuaDong+RX1D_HuaNan+RX1D_HuaZhong+RX1D_XiBei+RX1D_XiNan})
plt.title('RX1D',fontdict={'weight':'bold','size': 14})
fig = sns.violinplot(x='Districts', y='RX1D', data=df, linewidth=0.8, palette='Set3', scale='width')
fig.set_ylabel('Density(mm)',fontsize = 10, weight='bold', style='italic')
fig.set_xlabel('')
fig.set_xticklabels(labels=['All','DongBei','HuaBei','HuaDong','HuaNan','HuaZhong','XiBei','XiNan'], rotation = 15, fontsize = 10)
ax = plt.gca()
plt.text(-0.15,1, '(c)', fontsize=16, color='k',weight='bold', transform=ax.transAxes)
plt.savefig('RX1D.tiff', dpi =600)

sns.set(style='ticks')
filename = os.listdir('C:/Users/***/Desktop/500_100/precip_r')
RX1D = pd.DataFrame()
for name in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/precip_r/{}'.format(name))
    RX1D.insert(loc=len(RX1D.columns), column=name, value=list(data['RX1D']))
results = list(RX1D.mean(axis=1))
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
years = [i for i in range(1961,2020)]
plt.xticks(years)
ax1.set_xticks([1961,1965,1970,1975,1980,1985,1990,1995,2000,2005,2010,2015,2019])
ax1.set_xticklabels(['1961','1965','1970','1975','1980','1985','1990','1995','2000','2005','2010','2015','2019'], fontsize = 14)
ax1.set_ylabel('RX1D(mm)', fontsize=16, weight='bold')
ax1.tick_params(axis='y', colors='navy', labelsize=12)
ax1.plot(years, results, 'b--', color = "deepskyblue")
sns.regplot(years, results, color='darkorange')
ax = plt.gca()
plt.text(-0.08,1, '(c)', fontsize=22, color='k', weight='bold', transform=ax.transAxes)
plt.savefig('RX1D.tiff',dpi = 600)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import pandas as pd
sns.set(style='ticks')
Districts = ['All of China','DongBei','HuaBei','HuaDong','HuaNan','HuaZhong','XiBei','XiNan']

filename = os.listdir('C:/Users/***/Desktop/500_100/precip_r')
PRCPTOP_ = []
SDII_ = []
RX1D_ = []
RX5D_ = []
R95p_ = []
R95T_ = []
R99p_ = []
R99T_ = []
CWD_ = []
CDD_ = []
R10MM_ = []
R20MM_ = []
R25MM_ = []
R50MM_ = []
R65MM_ = []
R115MM_ = []
R205MM_ = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/precip_r/{}'.format(i))
    PRCPTOP_.append(data['PRCPTOP'].mean())
    SDII_.append(data['SDII'].mean())
    RX1D_.append(data['RX1D'].mean())
    RX5D_.append(data['RX5D'].mean())
    R95p_.append(data['R95p'].mean())
    R95T_.append(data['R95T'].mean())
    R99p_.append(data['R99p'].mean())
    R99T_.append(data['R99T'].mean())
    CWD_.append(data['CWD'].mean())
    CDD_.append(data['CDD'].mean())
    R10MM_.append(data['R10MM'].mean())
    R20MM_.append(data['R20MM'].mean())
    R25MM_.append(data['R25MM'].mean())
    R50MM_.append(data['R50MM'].mean())
    R65MM_.append(data['R65MM'].mean())
    R115MM_.append(data['R115MM'].mean())
    R205MM_.append(data['R205MM'].mean())
    
filename = os.listdir('C:/Users/***/Desktop/500_100/DongBei')
PRCPTOP_DongBei = []
SDII_DongBei = []
RX1D_DongBei = []
RX5D_DongBei = []
R95p_DongBei = []
R95T_DongBei = []
R99p_DongBei = []
R99T_DongBei = []
CWD_DongBei= []
CDD_DongBei = []
R10MM_DongBei = []
R20MM_DongBei = []
R25MM_DongBei = []
R50MM_DongBei = []
R65MM_DongBei = []
R115MM_DongBei = []
R205MM_DongBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/DongBei/{}'.format(i))
    PRCPTOP_DongBei.append(data['PRCPTOP'].mean())
    SDII_DongBei.append(data['SDII'].mean())
    RX1D_DongBei.append(data['RX1D'].mean())
    RX5D_DongBei.append(data['RX5D'].mean())
    R95p_DongBei.append(data['R95p'].mean())
    R95T_DongBei.append(data['R95T'].mean())
    R99p_DongBei.append(data['R99p'].mean())
    R99T_DongBei.append(data['R99T'].mean())
    CWD_DongBei.append(data['CWD'].mean())
    CDD_DongBei.append(data['CDD'].mean())
    R10MM_DongBei.append(data['R10MM'].mean())
    R20MM_DongBei.append(data['R20MM'].mean())
    R25MM_DongBei.append(data['R25MM'].mean())
    R50MM_DongBei.append(data['R50MM'].mean())
    R65MM_DongBei.append(data['R65MM'].mean())
    R115MM_DongBei.append(data['R115MM'].mean())
    R205MM_DongBei.append(data['R205MM'].mean())
    
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaBei')
PRCPTOP_HuaBei = []
SDII_HuaBei = []
RX1D_HuaBei = []
RX5D_HuaBei = []
R95p_HuaBei = []
R95T_HuaBei = []
R99p_HuaBei = []
R99T_HuaBei = []
CWD_HuaBei= []
CDD_HuaBei = []
R10MM_HuaBei = []
R20MM_HuaBei = []
R25MM_HuaBei = []
R50MM_HuaBei = []
R65MM_HuaBei = []
R115MM_HuaBei = []
R205MM_HuaBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaBei/{}'.format(i))
    PRCPTOP_HuaBei.append(data['PRCPTOP'].mean())
    SDII_HuaBei.append(data['SDII'].mean())
    RX1D_HuaBei.append(data['RX1D'].mean())
    RX5D_HuaBei.append(data['RX5D'].mean())
    R95p_HuaBei.append(data['R95p'].mean())
    R95T_HuaBei.append(data['R95T'].mean())
    R99p_HuaBei.append(data['R99p'].mean())
    R99T_HuaBei.append(data['R99T'].mean())
    CWD_HuaBei.append(data['CWD'].mean())
    CDD_HuaBei.append(data['CDD'].mean())
    R10MM_HuaBei.append(data['R10MM'].mean())
    R20MM_HuaBei.append(data['R20MM'].mean())
    R25MM_HuaBei.append(data['R25MM'].mean())
    R50MM_HuaBei.append(data['R50MM'].mean())
    R65MM_HuaBei.append(data['R65MM'].mean())
    R115MM_HuaBei.append(data['R115MM'].mean())
    R205MM_HuaBei.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaDong')
PRCPTOP_HuaDong = []
SDII_HuaDong = []
RX1D_HuaDong = []
RX5D_HuaDong = []
R95p_HuaDong = []
R95T_HuaDong = []
R99p_HuaDong = []
R99T_HuaDong = []
CWD_HuaDong = []
CDD_HuaDong = []
R10MM_HuaDong = []
R20MM_HuaDong = []
R25MM_HuaDong = []
R50MM_HuaDong = []
R65MM_HuaDong = []
R115MM_HuaDong = []
R205MM_HuaDong = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaDong/{}'.format(i))
    PRCPTOP_HuaDong.append(data['PRCPTOP'].mean())
    SDII_HuaDong.append(data['SDII'].mean())
    RX1D_HuaDong.append(data['RX1D'].mean())
    RX5D_HuaDong.append(data['RX5D'].mean())
    R95p_HuaDong.append(data['R95p'].mean())
    R95T_HuaDong.append(data['R95T'].mean())
    R99p_HuaDong.append(data['R99p'].mean())
    R99T_HuaDong.append(data['R99T'].mean())
    CWD_HuaDong.append(data['CWD'].mean())
    CDD_HuaDong.append(data['CDD'].mean())
    R10MM_HuaDong.append(data['R10MM'].mean())
    R20MM_HuaDong.append(data['R20MM'].mean())
    R25MM_HuaDong.append(data['R25MM'].mean())
    R50MM_HuaDong.append(data['R50MM'].mean())
    R65MM_HuaDong.append(data['R65MM'].mean())
    R115MM_HuaDong.append(data['R115MM'].mean())
    R205MM_HuaDong.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaNan')
PRCPTOP_HuaNan = []
SDII_HuaNan = []
RX1D_HuaNan = []
RX5D_HuaNan = []
R95p_HuaNan = []
R95T_HuaNan = []
R99p_HuaNan = []
R99T_HuaNan = []
CWD_HuaNan = []
CDD_HuaNan = []
R10MM_HuaNan = []
R20MM_HuaNan = []
R25MM_HuaNan = []
R50MM_HuaNan = []
R65MM_HuaNan = []
R115MM_HuaNan = []
R205MM_HuaNan = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaNan/{}'.format(i))
    PRCPTOP_HuaNan.append(data['PRCPTOP'].mean())
    SDII_HuaNan.append(data['SDII'].mean())
    RX1D_HuaNan.append(data['RX1D'].mean())
    RX5D_HuaNan.append(data['RX5D'].mean())
    R95p_HuaNan.append(data['R95p'].mean())
    R95T_HuaNan.append(data['R95T'].mean())
    R99p_HuaNan.append(data['R99p'].mean())
    R99T_HuaNan.append(data['R99T'].mean())
    CWD_HuaNan.append(data['CWD'].mean())
    CDD_HuaNan.append(data['CDD'].mean())
    R10MM_HuaNan.append(data['R10MM'].mean())
    R20MM_HuaNan.append(data['R20MM'].mean())
    R25MM_HuaNan.append(data['R25MM'].mean())
    R50MM_HuaNan.append(data['R50MM'].mean())
    R65MM_HuaNan.append(data['R65MM'].mean())
    R115MM_HuaNan.append(data['R115MM'].mean())
    R205MM_HuaNan.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaZhong')
PRCPTOP_HuaZhong = []
SDII_HuaZhong = []
RX1D_HuaZhong = []
RX5D_HuaZhong = []
R95p_HuaZhong = []
R95T_HuaZhong = []
R99p_HuaZhong = []
R99T_HuaZhong = []
CWD_HuaZhong = []
CDD_HuaZhong = []
R10MM_HuaZhong = []
R20MM_HuaZhong = []
R25MM_HuaZhong = []
R50MM_HuaZhong = []
R65MM_HuaZhong = []
R115MM_HuaZhong = []
R205MM_HuaZhong = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaZhong/{}'.format(i))
    PRCPTOP_HuaZhong.append(data['PRCPTOP'].mean())
    SDII_HuaZhong.append(data['SDII'].mean())
    RX1D_HuaZhong.append(data['RX1D'].mean())
    RX5D_HuaZhong.append(data['RX5D'].mean())
    R95p_HuaZhong.append(data['R95p'].mean())
    R95T_HuaZhong.append(data['R95T'].mean())
    R99p_HuaZhong.append(data['R99p'].mean())
    R99T_HuaZhong.append(data['R99T'].mean())
    CWD_HuaZhong.append(data['CWD'].mean())
    CDD_HuaZhong.append(data['CDD'].mean())
    R10MM_HuaZhong.append(data['R10MM'].mean())
    R20MM_HuaZhong.append(data['R20MM'].mean())
    R25MM_HuaZhong.append(data['R25MM'].mean())
    R50MM_HuaZhong.append(data['R50MM'].mean())
    R65MM_HuaZhong.append(data['R65MM'].mean())
    R115MM_HuaZhong.append(data['R115MM'].mean())
    R205MM_HuaZhong.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/XiBei')
PRCPTOP_XiBei = []
SDII_XiBei = []
RX1D_XiBei = []
RX5D_XiBei = []
R95p_XiBei = []
R95T_XiBei = []
R99p_XiBei = []
R99T_XiBei = []
CWD_XiBei = []
CDD_XiBei = []
R10MM_XiBei = []
R20MM_XiBei = []
R25MM_XiBei = []
R50MM_XiBei = []
R65MM_XiBei = []
R115MM_XiBei = []
R205MM_XiBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/XiBei/{}'.format(i))
    PRCPTOP_XiBei.append(data['PRCPTOP'].mean())
    SDII_XiBei.append(data['SDII'].mean())
    RX1D_XiBei.append(data['RX1D'].mean())
    RX5D_XiBei.append(data['RX5D'].mean())
    R95p_XiBei.append(data['R95p'].mean())
    R95T_XiBei.append(data['R95T'].mean())
    R99p_XiBei.append(data['R99p'].mean())
    R99T_XiBei.append(data['R99T'].mean())
    CWD_XiBei.append(data['CWD'].mean())
    CDD_XiBei.append(data['CDD'].mean())
    R10MM_XiBei.append(data['R10MM'].mean())
    R20MM_XiBei.append(data['R20MM'].mean())
    R25MM_XiBei.append(data['R25MM'].mean())
    R50MM_XiBei.append(data['R50MM'].mean())
    R65MM_XiBei.append(data['R65MM'].mean())
    R115MM_XiBei.append(data['R115MM'].mean())
    R205MM_XiBei.append(data['R205MM'].mean())

filename = os.listdir('C:/Users/***/Desktop/500_100/XiNan')
PRCPTOP_XiNan = []
SDII_XiNan = []
RX1D_XiNan = []
RX5D_XiNan = []
R95p_XiNan = []
R95T_XiNan = []
R99p_XiNan = []
R99T_XiNan = []
CWD_XiNan = []
CDD_XiNan = []
R10MM_XiNan = []
R20MM_XiNan = []
R25MM_XiNan = []
R50MM_XiNan = []
R65MM_XiNan = []
R115MM_XiNan = []
R205MM_XiNan = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/XiNan/{}'.format(i))
    PRCPTOP_XiNan.append(data['PRCPTOP'].mean())
    SDII_XiNan.append(data['SDII'].mean())
    RX1D_XiNan.append(data['RX1D'].mean())
    RX5D_XiNan.append(data['RX5D'].mean())
    R95p_XiNan.append(data['R95p'].mean())
    R95T_XiNan.append(data['R95T'].mean())
    R99p_XiNan.append(data['R99p'].mean())
    R99T_XiNan.append(data['R99T'].mean())
    CWD_XiNan.append(data['CWD'].mean())
    CDD_XiNan.append(data['CDD'].mean())
    R10MM_XiNan.append(data['R10MM'].mean())
    R20MM_XiNan.append(data['R20MM'].mean())
    R25MM_XiNan.append(data['R25MM'].mean())
    R50MM_XiNan.append(data['R50MM'].mean())
    R65MM_XiNan.append(data['R65MM'].mean())
    R115MM_XiNan.append(data['R115MM'].mean())
    R205MM_XiNan.append(data['R205MM'].mean())
    
fig = sns.kdeplot(RX5D_, color="darkorange", cut=0, linewidth = 3)
fig = sns.kdeplot(RX5D_DongBei, color="r", cut=0, linewidth = 3)
fig = sns.kdeplot(RX5D_HuaBei, color="mediumaquamarine", cut=0, linewidth = 3)
fig = sns.kdeplot(RX5D_HuaDong, color="peru", cut=0, linewidth = 3)
fig = sns.kdeplot(RX5D_HuaNan, color="tan", cut=0, linewidth = 3)
fig = sns.kdeplot(RX5D_HuaZhong, color="teal", cut=0, linewidth = 3)
fig = sns.kdeplot(RX5D_XiBei, color="deepskyblue", cut=0, linewidth = 3)
fig = sns.kdeplot(RX5D_XiNan, color="b", cut=0, linewidth = 3)
plt.title('RX5D',fontdict={'weight':'bold','size': 14})
col_labels = ['District','Mean']
table_vals = [['All',round(np.mean(RX5D_))],['DongBei',round(np.mean(RX5D_DongBei))],['HuaBei',round(np.mean(RX5D_HuaBei))],['HuaDong',round(np.mean(RX5D_HuaDong))],['HuaNan',round(np.mean(RX5D_HuaNan))],['HuaZhong',round(np.mean(RX5D_HuaZhong))],['XiBei',round(np.mean(RX5D_XiBei))],['XiNan',round(np.mean(RX5D_XiNan))]]
my_table = plt.table(cellText=table_vals, colWidths=[0.1]*8, colLabels=col_labels, loc='best', cellLoc='center', colColours=['gold','gold'])
my_table.scale(1.8, 1.6)
my_table.auto_set_font_size(False)
my_table.set_fontsize(11)
sns.despine()
fig.set_xlabel("RX5D(mm)", fontsize = 10, weight='bold', style='italic')
ax = plt.gca()
plt.text(-0.15,1, '(d)', fontsize=16, color='k',weight='bold', transform=ax.transAxes)
fig.set_xlim([-10, 270])
fig.set_ylabel('')
plt.savefig('RX5D.tiff', dpi = 600)

sns.set(style='darkgrid')
Districts = ['All']*15388+['DongBei']*1424+['HuaBei']*2572+['HuaDong']*1219+['HuaNan']*641+['HuaZhong']*852+['XiBei']*4901+['XiNan']*3445
df = pd.DataFrame({'Districts' : Districts, 
                  'RX5D' : RX5D_+RX5D_DongBei+RX5D_HuaBei+RX5D_HuaDong+RX5D_HuaNan+RX5D_HuaZhong+RX5D_XiBei+RX5D_XiNan})
plt.title('RX5D',fontdict={'weight':'bold','size': 14})
fig = sns.violinplot(x='Districts', y='RX5D', data=df, linewidth=0.8, palette='Set3', scale='width')
fig.set_ylabel('Density(mm)',fontsize = 10, weight='bold', style='italic')
fig.set_xlabel('')
fig.set_xticklabels(labels=['All','DongBei','HuaBei','HuaDong','HuaNan','HuaZhong','XiBei','XiNan'], rotation = 15, fontsize = 10)
ax = plt.gca()
plt.text(-0.15,1, '(d)', fontsize=16, color='k',weight='bold', transform=ax.transAxes)
plt.savefig('RX5D.tiff', dpi =600)

sns.set(style='ticks')
filename = os.listdir('C:/Users/***/Desktop/500_100/precip_r')
RX5D = pd.DataFrame()
for name in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/precip_r/{}'.format(name))
    RX5D.insert(loc=len(RX5D.columns), column=name, value=list(data['RX5D']))
results = list(RX5D.mean(axis=1))
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
years = [i for i in range(1961,2020)]
plt.xticks(years)
ax1.set_xticks([1961,1965,1970,1975,1980,1985,1990,1995,2000,2005,2010,2015,2019])
ax1.set_xticklabels(['1961','1965','1970','1975','1980','1985','1990','1995','2000','2005','2010','2015','2019'], fontsize = 14)
ax1.set_ylabel('RX5D(mm)', fontsize=16, weight='bold')
ax1.tick_params(axis='y', colors='navy', labelsize=12)
ax1.plot(years, results, 'b--', color = "deepskyblue")
sns.regplot(years, results, color='darkorange')
ax = plt.gca()
plt.text(-0.08,1, '(d)', fontsize=22, color='k', weight='bold', transform=ax.transAxes)
plt.savefig('RX5D.tiff',dpi = 600)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import pandas as pd
sns.set(style='ticks')
Districts = ['All of China','DongBei','HuaBei','HuaDong','HuaNan','HuaZhong','XiBei','XiNan']

filename = os.listdir('C:/Users/***/Desktop/500_100/precip_r')
PRCPTOP_ = []
SDII_ = []
RX1D_ = []
RX5D_ = []
R95p_ = []
R95T_ = []
R99p_ = []
R99T_ = []
CWD_ = []
CDD_ = []
R10MM_ = []
R20MM_ = []
R25MM_ = []
R50MM_ = []
R65MM_ = []
R115MM_ = []
R205MM_ = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/precip_r/{}'.format(i))
    PRCPTOP_.append(data['PRCPTOP'].mean())
    SDII_.append(data['SDII'].mean())
    RX1D_.append(data['RX1D'].mean())
    RX5D_.append(data['RX5D'].mean())
    R95p_.append(data['R95p'].mean())
    R95T_.append(data['R95T'].mean())
    R99p_.append(data['R99p'].mean())
    R99T_.append(data['R99T'].mean())
    CWD_.append(data['CWD'].mean())
    CDD_.append(data['CDD'].mean())
    R10MM_.append(data['R10MM'].mean())
    R20MM_.append(data['R20MM'].mean())
    R25MM_.append(data['R25MM'].mean())
    R50MM_.append(data['R50MM'].mean())
    R65MM_.append(data['R65MM'].mean())
    R115MM_.append(data['R115MM'].mean())
    R205MM_.append(data['R205MM'].mean())
    
filename = os.listdir('C:/Users/***/Desktop/500_100/DongBei')
PRCPTOP_DongBei = []
SDII_DongBei = []
RX1D_DongBei = []
RX5D_DongBei = []
R95p_DongBei = []
R95T_DongBei = []
R99p_DongBei = []
R99T_DongBei = []
CWD_DongBei= []
CDD_DongBei = []
R10MM_DongBei = []
R20MM_DongBei = []
R25MM_DongBei = []
R50MM_DongBei = []
R65MM_DongBei = []
R115MM_DongBei = []
R205MM_DongBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/DongBei/{}'.format(i))
    PRCPTOP_DongBei.append(data['PRCPTOP'].mean())
    SDII_DongBei.append(data['SDII'].mean())
    RX1D_DongBei.append(data['RX1D'].mean())
    RX5D_DongBei.append(data['RX5D'].mean())
    R95p_DongBei.append(data['R95p'].mean())
    R95T_DongBei.append(data['R95T'].mean())
    R99p_DongBei.append(data['R99p'].mean())
    R99T_DongBei.append(data['R99T'].mean())
    CWD_DongBei.append(data['CWD'].mean())
    CDD_DongBei.append(data['CDD'].mean())
    R10MM_DongBei.append(data['R10MM'].mean())
    R20MM_DongBei.append(data['R20MM'].mean())
    R25MM_DongBei.append(data['R25MM'].mean())
    R50MM_DongBei.append(data['R50MM'].mean())
    R65MM_DongBei.append(data['R65MM'].mean())
    R115MM_DongBei.append(data['R115MM'].mean())
    R205MM_DongBei.append(data['R205MM'].mean())
    
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaBei')
PRCPTOP_HuaBei = []
SDII_HuaBei = []
RX1D_HuaBei = []
RX5D_HuaBei = []
R95p_HuaBei = []
R95T_HuaBei = []
R99p_HuaBei = []
R99T_HuaBei = []
CWD_HuaBei= []
CDD_HuaBei = []
R10MM_HuaBei = []
R20MM_HuaBei = []
R25MM_HuaBei = []
R50MM_HuaBei = []
R65MM_HuaBei = []
R115MM_HuaBei = []
R205MM_HuaBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaBei/{}'.format(i))
    PRCPTOP_HuaBei.append(data['PRCPTOP'].mean())
    SDII_HuaBei.append(data['SDII'].mean())
    RX1D_HuaBei.append(data['RX1D'].mean())
    RX5D_HuaBei.append(data['RX5D'].mean())
    R95p_HuaBei.append(data['R95p'].mean())
    R95T_HuaBei.append(data['R95T'].mean())
    R99p_HuaBei.append(data['R99p'].mean())
    R99T_HuaBei.append(data['R99T'].mean())
    CWD_HuaBei.append(data['CWD'].mean())
    CDD_HuaBei.append(data['CDD'].mean())
    R10MM_HuaBei.append(data['R10MM'].mean())
    R20MM_HuaBei.append(data['R20MM'].mean())
    R25MM_HuaBei.append(data['R25MM'].mean())
    R50MM_HuaBei.append(data['R50MM'].mean())
    R65MM_HuaBei.append(data['R65MM'].mean())
    R115MM_HuaBei.append(data['R115MM'].mean())
    R205MM_HuaBei.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaDong')
PRCPTOP_HuaDong = []
SDII_HuaDong = []
RX1D_HuaDong = []
RX5D_HuaDong = []
R95p_HuaDong = []
R95T_HuaDong = []
R99p_HuaDong = []
R99T_HuaDong = []
CWD_HuaDong = []
CDD_HuaDong = []
R10MM_HuaDong = []
R20MM_HuaDong = []
R25MM_HuaDong = []
R50MM_HuaDong = []
R65MM_HuaDong = []
R115MM_HuaDong = []
R205MM_HuaDong = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaDong/{}'.format(i))
    PRCPTOP_HuaDong.append(data['PRCPTOP'].mean())
    SDII_HuaDong.append(data['SDII'].mean())
    RX1D_HuaDong.append(data['RX1D'].mean())
    RX5D_HuaDong.append(data['RX5D'].mean())
    R95p_HuaDong.append(data['R95p'].mean())
    R95T_HuaDong.append(data['R95T'].mean())
    R99p_HuaDong.append(data['R99p'].mean())
    R99T_HuaDong.append(data['R99T'].mean())
    CWD_HuaDong.append(data['CWD'].mean())
    CDD_HuaDong.append(data['CDD'].mean())
    R10MM_HuaDong.append(data['R10MM'].mean())
    R20MM_HuaDong.append(data['R20MM'].mean())
    R25MM_HuaDong.append(data['R25MM'].mean())
    R50MM_HuaDong.append(data['R50MM'].mean())
    R65MM_HuaDong.append(data['R65MM'].mean())
    R115MM_HuaDong.append(data['R115MM'].mean())
    R205MM_HuaDong.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaNan')
PRCPTOP_HuaNan = []
SDII_HuaNan = []
RX1D_HuaNan = []
RX5D_HuaNan = []
R95p_HuaNan = []
R95T_HuaNan = []
R99p_HuaNan = []
R99T_HuaNan = []
CWD_HuaNan = []
CDD_HuaNan = []
R10MM_HuaNan = []
R20MM_HuaNan = []
R25MM_HuaNan = []
R50MM_HuaNan = []
R65MM_HuaNan = []
R115MM_HuaNan = []
R205MM_HuaNan = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaNan/{}'.format(i))
    PRCPTOP_HuaNan.append(data['PRCPTOP'].mean())
    SDII_HuaNan.append(data['SDII'].mean())
    RX1D_HuaNan.append(data['RX1D'].mean())
    RX5D_HuaNan.append(data['RX5D'].mean())
    R95p_HuaNan.append(data['R95p'].mean())
    R95T_HuaNan.append(data['R95T'].mean())
    R99p_HuaNan.append(data['R99p'].mean())
    R99T_HuaNan.append(data['R99T'].mean())
    CWD_HuaNan.append(data['CWD'].mean())
    CDD_HuaNan.append(data['CDD'].mean())
    R10MM_HuaNan.append(data['R10MM'].mean())
    R20MM_HuaNan.append(data['R20MM'].mean())
    R25MM_HuaNan.append(data['R25MM'].mean())
    R50MM_HuaNan.append(data['R50MM'].mean())
    R65MM_HuaNan.append(data['R65MM'].mean())
    R115MM_HuaNan.append(data['R115MM'].mean())
    R205MM_HuaNan.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaZhong')
PRCPTOP_HuaZhong = []
SDII_HuaZhong = []
RX1D_HuaZhong = []
RX5D_HuaZhong = []
R95p_HuaZhong = []
R95T_HuaZhong = []
R99p_HuaZhong = []
R99T_HuaZhong = []
CWD_HuaZhong = []
CDD_HuaZhong = []
R10MM_HuaZhong = []
R20MM_HuaZhong = []
R25MM_HuaZhong = []
R50MM_HuaZhong = []
R65MM_HuaZhong = []
R115MM_HuaZhong = []
R205MM_HuaZhong = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaZhong/{}'.format(i))
    PRCPTOP_HuaZhong.append(data['PRCPTOP'].mean())
    SDII_HuaZhong.append(data['SDII'].mean())
    RX1D_HuaZhong.append(data['RX1D'].mean())
    RX5D_HuaZhong.append(data['RX5D'].mean())
    R95p_HuaZhong.append(data['R95p'].mean())
    R95T_HuaZhong.append(data['R95T'].mean())
    R99p_HuaZhong.append(data['R99p'].mean())
    R99T_HuaZhong.append(data['R99T'].mean())
    CWD_HuaZhong.append(data['CWD'].mean())
    CDD_HuaZhong.append(data['CDD'].mean())
    R10MM_HuaZhong.append(data['R10MM'].mean())
    R20MM_HuaZhong.append(data['R20MM'].mean())
    R25MM_HuaZhong.append(data['R25MM'].mean())
    R50MM_HuaZhong.append(data['R50MM'].mean())
    R65MM_HuaZhong.append(data['R65MM'].mean())
    R115MM_HuaZhong.append(data['R115MM'].mean())
    R205MM_HuaZhong.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/XiBei')
PRCPTOP_XiBei = []
SDII_XiBei = []
RX1D_XiBei = []
RX5D_XiBei = []
R95p_XiBei = []
R95T_XiBei = []
R99p_XiBei = []
R99T_XiBei = []
CWD_XiBei = []
CDD_XiBei = []
R10MM_XiBei = []
R20MM_XiBei = []
R25MM_XiBei = []
R50MM_XiBei = []
R65MM_XiBei = []
R115MM_XiBei = []
R205MM_XiBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/XiBei/{}'.format(i))
    PRCPTOP_XiBei.append(data['PRCPTOP'].mean())
    SDII_XiBei.append(data['SDII'].mean())
    RX1D_XiBei.append(data['RX1D'].mean())
    RX5D_XiBei.append(data['RX5D'].mean())
    R95p_XiBei.append(data['R95p'].mean())
    R95T_XiBei.append(data['R95T'].mean())
    R99p_XiBei.append(data['R99p'].mean())
    R99T_XiBei.append(data['R99T'].mean())
    CWD_XiBei.append(data['CWD'].mean())
    CDD_XiBei.append(data['CDD'].mean())
    R10MM_XiBei.append(data['R10MM'].mean())
    R20MM_XiBei.append(data['R20MM'].mean())
    R25MM_XiBei.append(data['R25MM'].mean())
    R50MM_XiBei.append(data['R50MM'].mean())
    R65MM_XiBei.append(data['R65MM'].mean())
    R115MM_XiBei.append(data['R115MM'].mean())
    R205MM_XiBei.append(data['R205MM'].mean())

filename = os.listdir('C:/Users/***/Desktop/500_100/XiNan')
PRCPTOP_XiNan = []
SDII_XiNan = []
RX1D_XiNan = []
RX5D_XiNan = []
R95p_XiNan = []
R95T_XiNan = []
R99p_XiNan = []
R99T_XiNan = []
CWD_XiNan = []
CDD_XiNan = []
R10MM_XiNan = []
R20MM_XiNan = []
R25MM_XiNan = []
R50MM_XiNan = []
R65MM_XiNan = []
R115MM_XiNan = []
R205MM_XiNan = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/XiNan/{}'.format(i))
    PRCPTOP_XiNan.append(data['PRCPTOP'].mean())
    SDII_XiNan.append(data['SDII'].mean())
    RX1D_XiNan.append(data['RX1D'].mean())
    RX5D_XiNan.append(data['RX5D'].mean())
    R95p_XiNan.append(data['R95p'].mean())
    R95T_XiNan.append(data['R95T'].mean())
    R99p_XiNan.append(data['R99p'].mean())
    R99T_XiNan.append(data['R99T'].mean())
    CWD_XiNan.append(data['CWD'].mean())
    CDD_XiNan.append(data['CDD'].mean())
    R10MM_XiNan.append(data['R10MM'].mean())
    R20MM_XiNan.append(data['R20MM'].mean())
    R25MM_XiNan.append(data['R25MM'].mean())
    R50MM_XiNan.append(data['R50MM'].mean())
    R65MM_XiNan.append(data['R65MM'].mean())
    R115MM_XiNan.append(data['R115MM'].mean())
    R205MM_XiNan.append(data['R205MM'].mean())
    
fig = sns.kdeplot(SDII_, color="darkorange", cut=0, linewidth = 3)
fig = sns.kdeplot(SDII_DongBei, color="r", cut=0, linewidth = 3)
fig = sns.kdeplot(SDII_HuaBei, color="mediumaquamarine", cut=0, linewidth = 3)
fig = sns.kdeplot(SDII_HuaDong, color="peru", cut=0, linewidth = 3)
fig = sns.kdeplot(SDII_HuaNan, color="tan", cut=0, linewidth = 3)
fig = sns.kdeplot(SDII_HuaZhong, color="teal", cut=0, linewidth = 3)
fig = sns.kdeplot(SDII_XiBei, color="deepskyblue", cut=0, linewidth = 3)
fig = sns.kdeplot(SDII_XiNan, color="b", cut=0, linewidth = 3)
plt.title('SDII',fontdict={'weight':'bold','size': 14})
col_labels = ['District','Mean']
table_vals = [['All',round(np.mean(SDII_))],['DongBei',round(np.mean(SDII_DongBei))],['HuaBei',round(np.mean(SDII_HuaBei))],['HuaDong',round(np.mean(SDII_HuaDong))],['HuaNan',round(np.mean(SDII_HuaNan))],['HuaZhong',round(np.mean(SDII_HuaZhong))],['XiBei',round(np.mean(SDII_XiBei))],['XiNan',round(np.mean(SDII_XiNan))]]
my_table = plt.table(cellText=table_vals, colWidths=[0.1]*8, colLabels=col_labels, loc='best', cellLoc='center', colColours=['gold','gold'])
my_table.scale(1.8, 1.6)
my_table.auto_set_font_size(False)
my_table.set_fontsize(11)
sns.despine()
fig.set_xlabel("SDII(mm·day$^{-1}$)", fontsize = 10, weight='bold', style='italic')
ax = plt.gca()
plt.text(-0.15,1, '(b)', fontsize=16, color='k',weight='bold', transform=ax.transAxes)
fig.set_ylabel('')
plt.savefig('SDII.tiff', dpi = 600)

sns.set(style='darkgrid')
Districts = ['All']*15388+['DongBei']*1424+['HuaBei']*2572+['HuaDong']*1219+['HuaNan']*641+['HuaZhong']*852+['XiBei']*4901+['XiNan']*3445
df = pd.DataFrame({'Districts' : Districts, 
                  'SDII' : SDII_+SDII_DongBei+SDII_HuaBei+SDII_HuaDong+SDII_HuaNan+SDII_HuaZhong+SDII_XiBei+SDII_XiNan})
plt.title('SDII',fontdict={'weight':'bold','size': 14})
fig = sns.violinplot(x='Districts', y='SDII', data=df, linewidth=0.8, palette='Set3', scale='width')
fig.set_ylabel('Density(mm·day$^{-1}$)',fontsize = 10, weight='bold', style='italic')
fig.set_xlabel('')
fig.set_xticklabels(labels=['All','DongBei','HuaBei','HuaDong','HuaNan','HuaZhong','XiBei','XiNan'], rotation = 15, fontsize = 10)
ax = plt.gca()
plt.text(-0.15,1, '(b)', fontsize=16, color='k',weight='bold', transform=ax.transAxes)
plt.savefig('SDII.tiff', dpi =600)

sns.set(style='ticks')
filename = os.listdir('C:/Users/***/Desktop/500_100/precip_r')
SDII = pd.DataFrame()
for name in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/precip_r/{}'.format(name))
    SDII.insert(loc=len(SDII.columns), column=name, value=list(data['SDII']))
results = list(SDII.mean(axis=1))
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
years = [i for i in range(1961,2020)]
plt.xticks(years)
ax1.set_xticks([1961,1965,1970,1975,1980,1985,1990,1995,2000,2005,2010,2015,2019])
ax1.set_xticklabels(['1961','1965','1970','1975','1980','1985','1990','1995','2000','2005','2010','2015','2019'], fontsize = 14)
ax1.set_ylabel('SDII(mm·day$^{-1}$)', fontsize=16, weight='bold')
ax1.tick_params(axis='y', colors='navy', labelsize=12)
ax1.plot(years, results, 'b--', color = "deepskyblue")
sns.regplot(years, results, color='darkorange')
ax = plt.gca()
plt.text(-0.08,1, '(b)', fontsize=22, color='k', weight='bold', transform=ax.transAxes)
plt.savefig('SDII.tiff',dpi = 600)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import pandas as pd
sns.set(style='ticks')
Districts = ['All of China','DongBei','HuaBei','HuaDong','HuaNan','HuaZhong','XiBei','XiNan']

filename = os.listdir('C:/Users/***/Desktop/500_100/precip_r')
PRCPTOP_ = []
SDII_ = []
RX1D_ = []
RX5D_ = []
R95p_ = []
R95T_ = []
R99p_ = []
R99T_ = []
CWD_ = []
CDD_ = []
R10MM_ = []
R20MM_ = []
R25MM_ = []
R50MM_ = []
R65MM_ = []
R115MM_ = []
R205MM_ = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/precip_r/{}'.format(i))
    PRCPTOP_.append(data['PRCPTOP'].mean())
    SDII_.append(data['SDII'].mean())
    RX1D_.append(data['RX1D'].mean())
    RX5D_.append(data['RX5D'].mean())
    R95p_.append(data['R95p'].mean())
    R95T_.append(data['R95T'].mean())
    R99p_.append(data['R99p'].mean())
    R99T_.append(data['R99T'].mean())
    CWD_.append(data['CWD'].mean())
    CDD_.append(data['CDD'].mean())
    R10MM_.append(data['R10MM'].mean())
    R20MM_.append(data['R20MM'].mean())
    R25MM_.append(data['R25MM'].mean())
    R50MM_.append(data['R50MM'].mean())
    R65MM_.append(data['R65MM'].mean())
    R115MM_.append(data['R115MM'].mean())
    R205MM_.append(data['R205MM'].mean())
    
filename = os.listdir('C:/Users/***/Desktop/500_100/DongBei')
PRCPTOP_DongBei = []
SDII_DongBei = []
RX1D_DongBei = []
RX5D_DongBei = []
R95p_DongBei = []
R95T_DongBei = []
R99p_DongBei = []
R99T_DongBei = []
CWD_DongBei= []
CDD_DongBei = []
R10MM_DongBei = []
R20MM_DongBei = []
R25MM_DongBei = []
R50MM_DongBei = []
R65MM_DongBei = []
R115MM_DongBei = []
R205MM_DongBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/DongBei/{}'.format(i))
    PRCPTOP_DongBei.append(data['PRCPTOP'].mean())
    SDII_DongBei.append(data['SDII'].mean())
    RX1D_DongBei.append(data['RX1D'].mean())
    RX5D_DongBei.append(data['RX5D'].mean())
    R95p_DongBei.append(data['R95p'].mean())
    R95T_DongBei.append(data['R95T'].mean())
    R99p_DongBei.append(data['R99p'].mean())
    R99T_DongBei.append(data['R99T'].mean())
    CWD_DongBei.append(data['CWD'].mean())
    CDD_DongBei.append(data['CDD'].mean())
    R10MM_DongBei.append(data['R10MM'].mean())
    R20MM_DongBei.append(data['R20MM'].mean())
    R25MM_DongBei.append(data['R25MM'].mean())
    R50MM_DongBei.append(data['R50MM'].mean())
    R65MM_DongBei.append(data['R65MM'].mean())
    R115MM_DongBei.append(data['R115MM'].mean())
    R205MM_DongBei.append(data['R205MM'].mean())
    
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaBei')
PRCPTOP_HuaBei = []
SDII_HuaBei = []
RX1D_HuaBei = []
RX5D_HuaBei = []
R95p_HuaBei = []
R95T_HuaBei = []
R99p_HuaBei = []
R99T_HuaBei = []
CWD_HuaBei= []
CDD_HuaBei = []
R10MM_HuaBei = []
R20MM_HuaBei = []
R25MM_HuaBei = []
R50MM_HuaBei = []
R65MM_HuaBei = []
R115MM_HuaBei = []
R205MM_HuaBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaBei/{}'.format(i))
    PRCPTOP_HuaBei.append(data['PRCPTOP'].mean())
    SDII_HuaBei.append(data['SDII'].mean())
    RX1D_HuaBei.append(data['RX1D'].mean())
    RX5D_HuaBei.append(data['RX5D'].mean())
    R95p_HuaBei.append(data['R95p'].mean())
    R95T_HuaBei.append(data['R95T'].mean())
    R99p_HuaBei.append(data['R99p'].mean())
    R99T_HuaBei.append(data['R99T'].mean())
    CWD_HuaBei.append(data['CWD'].mean())
    CDD_HuaBei.append(data['CDD'].mean())
    R10MM_HuaBei.append(data['R10MM'].mean())
    R20MM_HuaBei.append(data['R20MM'].mean())
    R25MM_HuaBei.append(data['R25MM'].mean())
    R50MM_HuaBei.append(data['R50MM'].mean())
    R65MM_HuaBei.append(data['R65MM'].mean())
    R115MM_HuaBei.append(data['R115MM'].mean())
    R205MM_HuaBei.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaDong')
PRCPTOP_HuaDong = []
SDII_HuaDong = []
RX1D_HuaDong = []
RX5D_HuaDong = []
R95p_HuaDong = []
R95T_HuaDong = []
R99p_HuaDong = []
R99T_HuaDong = []
CWD_HuaDong = []
CDD_HuaDong = []
R10MM_HuaDong = []
R20MM_HuaDong = []
R25MM_HuaDong = []
R50MM_HuaDong = []
R65MM_HuaDong = []
R115MM_HuaDong = []
R205MM_HuaDong = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaDong/{}'.format(i))
    PRCPTOP_HuaDong.append(data['PRCPTOP'].mean())
    SDII_HuaDong.append(data['SDII'].mean())
    RX1D_HuaDong.append(data['RX1D'].mean())
    RX5D_HuaDong.append(data['RX5D'].mean())
    R95p_HuaDong.append(data['R95p'].mean())
    R95T_HuaDong.append(data['R95T'].mean())
    R99p_HuaDong.append(data['R99p'].mean())
    R99T_HuaDong.append(data['R99T'].mean())
    CWD_HuaDong.append(data['CWD'].mean())
    CDD_HuaDong.append(data['CDD'].mean())
    R10MM_HuaDong.append(data['R10MM'].mean())
    R20MM_HuaDong.append(data['R20MM'].mean())
    R25MM_HuaDong.append(data['R25MM'].mean())
    R50MM_HuaDong.append(data['R50MM'].mean())
    R65MM_HuaDong.append(data['R65MM'].mean())
    R115MM_HuaDong.append(data['R115MM'].mean())
    R205MM_HuaDong.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaNan')
PRCPTOP_HuaNan = []
SDII_HuaNan = []
RX1D_HuaNan = []
RX5D_HuaNan = []
R95p_HuaNan = []
R95T_HuaNan = []
R99p_HuaNan = []
R99T_HuaNan = []
CWD_HuaNan = []
CDD_HuaNan = []
R10MM_HuaNan = []
R20MM_HuaNan = []
R25MM_HuaNan = []
R50MM_HuaNan = []
R65MM_HuaNan = []
R115MM_HuaNan = []
R205MM_HuaNan = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaNan/{}'.format(i))
    PRCPTOP_HuaNan.append(data['PRCPTOP'].mean())
    SDII_HuaNan.append(data['SDII'].mean())
    RX1D_HuaNan.append(data['RX1D'].mean())
    RX5D_HuaNan.append(data['RX5D'].mean())
    R95p_HuaNan.append(data['R95p'].mean())
    R95T_HuaNan.append(data['R95T'].mean())
    R99p_HuaNan.append(data['R99p'].mean())
    R99T_HuaNan.append(data['R99T'].mean())
    CWD_HuaNan.append(data['CWD'].mean())
    CDD_HuaNan.append(data['CDD'].mean())
    R10MM_HuaNan.append(data['R10MM'].mean())
    R20MM_HuaNan.append(data['R20MM'].mean())
    R25MM_HuaNan.append(data['R25MM'].mean())
    R50MM_HuaNan.append(data['R50MM'].mean())
    R65MM_HuaNan.append(data['R65MM'].mean())
    R115MM_HuaNan.append(data['R115MM'].mean())
    R205MM_HuaNan.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaZhong')
PRCPTOP_HuaZhong = []
SDII_HuaZhong = []
RX1D_HuaZhong = []
RX5D_HuaZhong = []
R95p_HuaZhong = []
R95T_HuaZhong = []
R99p_HuaZhong = []
R99T_HuaZhong = []
CWD_HuaZhong = []
CDD_HuaZhong = []
R10MM_HuaZhong = []
R20MM_HuaZhong = []
R25MM_HuaZhong = []
R50MM_HuaZhong = []
R65MM_HuaZhong = []
R115MM_HuaZhong = []
R205MM_HuaZhong = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaZhong/{}'.format(i))
    PRCPTOP_HuaZhong.append(data['PRCPTOP'].mean())
    SDII_HuaZhong.append(data['SDII'].mean())
    RX1D_HuaZhong.append(data['RX1D'].mean())
    RX5D_HuaZhong.append(data['RX5D'].mean())
    R95p_HuaZhong.append(data['R95p'].mean())
    R95T_HuaZhong.append(data['R95T'].mean())
    R99p_HuaZhong.append(data['R99p'].mean())
    R99T_HuaZhong.append(data['R99T'].mean())
    CWD_HuaZhong.append(data['CWD'].mean())
    CDD_HuaZhong.append(data['CDD'].mean())
    R10MM_HuaZhong.append(data['R10MM'].mean())
    R20MM_HuaZhong.append(data['R20MM'].mean())
    R25MM_HuaZhong.append(data['R25MM'].mean())
    R50MM_HuaZhong.append(data['R50MM'].mean())
    R65MM_HuaZhong.append(data['R65MM'].mean())
    R115MM_HuaZhong.append(data['R115MM'].mean())
    R205MM_HuaZhong.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/XiBei')
PRCPTOP_XiBei = []
SDII_XiBei = []
RX1D_XiBei = []
RX5D_XiBei = []
R95p_XiBei = []
R95T_XiBei = []
R99p_XiBei = []
R99T_XiBei = []
CWD_XiBei = []
CDD_XiBei = []
R10MM_XiBei = []
R20MM_XiBei = []
R25MM_XiBei = []
R50MM_XiBei = []
R65MM_XiBei = []
R115MM_XiBei = []
R205MM_XiBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/XiBei/{}'.format(i))
    PRCPTOP_XiBei.append(data['PRCPTOP'].mean())
    SDII_XiBei.append(data['SDII'].mean())
    RX1D_XiBei.append(data['RX1D'].mean())
    RX5D_XiBei.append(data['RX5D'].mean())
    R95p_XiBei.append(data['R95p'].mean())
    R95T_XiBei.append(data['R95T'].mean())
    R99p_XiBei.append(data['R99p'].mean())
    R99T_XiBei.append(data['R99T'].mean())
    CWD_XiBei.append(data['CWD'].mean())
    CDD_XiBei.append(data['CDD'].mean())
    R10MM_XiBei.append(data['R10MM'].mean())
    R20MM_XiBei.append(data['R20MM'].mean())
    R25MM_XiBei.append(data['R25MM'].mean())
    R50MM_XiBei.append(data['R50MM'].mean())
    R65MM_XiBei.append(data['R65MM'].mean())
    R115MM_XiBei.append(data['R115MM'].mean())
    R205MM_XiBei.append(data['R205MM'].mean())

filename = os.listdir('C:/Users/***/Desktop/500_100/XiNan')
PRCPTOP_XiNan = []
SDII_XiNan = []
RX1D_XiNan = []
RX5D_XiNan = []
R95p_XiNan = []
R95T_XiNan = []
R99p_XiNan = []
R99T_XiNan = []
CWD_XiNan = []
CDD_XiNan = []
R10MM_XiNan = []
R20MM_XiNan = []
R25MM_XiNan = []
R50MM_XiNan = []
R65MM_XiNan = []
R115MM_XiNan = []
R205MM_XiNan = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/XiNan/{}'.format(i))
    PRCPTOP_XiNan.append(data['PRCPTOP'].mean())
    SDII_XiNan.append(data['SDII'].mean())
    RX1D_XiNan.append(data['RX1D'].mean())
    RX5D_XiNan.append(data['RX5D'].mean())
    R95p_XiNan.append(data['R95p'].mean())
    R95T_XiNan.append(data['R95T'].mean())
    R99p_XiNan.append(data['R99p'].mean())
    R99T_XiNan.append(data['R99T'].mean())
    CWD_XiNan.append(data['CWD'].mean())
    CDD_XiNan.append(data['CDD'].mean())
    R10MM_XiNan.append(data['R10MM'].mean())
    R20MM_XiNan.append(data['R20MM'].mean())
    R25MM_XiNan.append(data['R25MM'].mean())
    R50MM_XiNan.append(data['R50MM'].mean())
    R65MM_XiNan.append(data['R65MM'].mean())
    R115MM_XiNan.append(data['R115MM'].mean())
    R205MM_XiNan.append(data['R205MM'].mean())
    
fig = sns.kdeplot(PRCPTOP_, color="darkorange", cut=0, linewidth = 3)
fig = sns.kdeplot(PRCPTOP_DongBei, color="r", cut=0, linewidth = 3)
fig = sns.kdeplot(PRCPTOP_HuaBei, color="mediumaquamarine", cut=0, linewidth = 3)
fig = sns.kdeplot(PRCPTOP_HuaDong, color="peru", cut=0, linewidth = 3)
fig = sns.kdeplot(PRCPTOP_HuaNan, color="tan", cut=0, linewidth = 3)
fig = sns.kdeplot(PRCPTOP_HuaZhong, color="teal", cut=0, linewidth = 3)
fig = sns.kdeplot(PRCPTOP_XiBei, color="deepskyblue", cut=0, linewidth = 3)
fig = sns.kdeplot(PRCPTOP_XiNan, color="b", cut=0, linewidth = 3)
plt.title('PRCPTOP',fontdict={'weight':'bold','size': 14})
col_labels = ['District','Mean']
table_vals = [['All',round(np.mean(PRCPTOP_))],['DongBei',round(np.mean(PRCPTOP_DongBei))],['HuaBei',round(np.mean(PRCPTOP_HuaBei))],['HuaDong',round(np.mean(PRCPTOP_HuaDong))],['HuaNan',round(np.mean(PRCPTOP_HuaNan))],['HuaZhong',round(np.mean(PRCPTOP_HuaZhong))],['XiBei',round(np.mean(PRCPTOP_XiBei))],['XiNan',round(np.mean(PRCPTOP_XiNan))]]
my_table = plt.table(cellText=table_vals, colWidths=[0.1]*8, colLabels=col_labels, loc='best', cellLoc='center', colColours=['gold','gold'])
my_table.scale(1.8, 1.6)
my_table.auto_set_font_size(False)
my_table.set_fontsize(11)
sns.despine()
fig.set_xlabel("PRCPTOP(mm)", fontsize = 10, weight='bold', style='italic')
ax = plt.gca()
plt.text(-0.15,1, '(a)', fontsize=16, color='k',weight='bold', transform=ax.transAxes)
fig.set_xlim([-100, 2700])
fig.set_ylabel('')
plt.savefig('PRCPTOP.tiff', dpi =600)

sns.set(style='darkgrid')
Districts = ['All']*15388+['DongBei']*1424+['HuaBei']*2572+['HuaDong']*1219+['HuaNan']*641+['HuaZhong']*852+['XiBei']*4901+['XiNan']*3445
df = pd.DataFrame({'Districts' : Districts, 
                  'PRCPTOP' : PRCPTOP_+PRCPTOP_DongBei+PRCPTOP_HuaBei+PRCPTOP_HuaDong+PRCPTOP_HuaNan+PRCPTOP_HuaZhong+PRCPTOP_XiBei+PRCPTOP_XiNan})
plt.title('PRCPTOP',fontdict={'weight':'bold','size': 14})
fig = sns.violinplot(x='Districts', y='PRCPTOP', data=df, linewidth=0.8, palette='Set3', scale='width')
fig.set_ylabel('Density(mm)',fontsize = 10, weight='bold', style='italic')
fig.set_xlabel('')
fig.set_xticklabels(labels=['All','DongBei','HuaBei','HuaDong','HuaNan','HuaZhong','XiBei','XiNan'], rotation = 15, fontsize = 10)
ax = plt.gca()
plt.text(-0.15,1, '(a)', fontsize=16, color='k', weight='bold', transform=ax.transAxes)
plt.savefig('PRCPTOP.tiff', dpi =600)

filename = os.listdir('C:/Users/***/Desktop/500_100/precip_r')
PRCPTOP = pd.DataFrame()
for name in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/precip_r/{}'.format(name))
    PRCPTOP.insert(loc=len(PRCPTOP.columns), column=name, value=list(data['PRCPTOP']))
results = list(PRCPTOP.mean(axis=1))
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
years = [i for i in range(1961,2020)]
plt.xticks(years)
ax1.set_xticks([1961,1965,1970,1975,1980,1985,1990,1995,2000,2005,2010,2015,2019])
ax1.set_xticklabels(['1961','1965','1970','1975','1980','1985','1990','1995','2000','2005','2010','2015','2019'], fontsize = 14)
ax1.set_ylabel('PRCPTOP(mm)', fontsize=16, weight='bold')
ax1.tick_params(axis='y', colors='navy', labelsize=12)
ax1.plot(years, results, 'b--', color = "deepskyblue")
sns.regplot(years, results, color='darkorange')
ax = plt.gca()
plt.text(-0.08,1, '(a)', fontsize=22, color='k', weight='bold', transform=ax.transAxes)
plt.savefig('PRCPTOP.tiff',dpi = 600)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import pandas as pd
sns.set(style='ticks')
Districts = ['All of China','DongBei','HuaBei','HuaDong','HuaNan','HuaZhong','XiBei','XiNan']

filename = os.listdir('C:/Users/***/Desktop/500_100/precip_r')
PRCPTOP_ = []
SDII_ = []
RX1D_ = []
RX5D_ = []
R95p_ = []
R95T_ = []
R99p_ = []
R99T_ = []
CWD_ = []
CDD_ = []
R10MM_ = []
R20MM_ = []
R25MM_ = []
R50MM_ = []
R65MM_ = []
R115MM_ = []
R205MM_ = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/precip_r/{}'.format(i))
    PRCPTOP_.append(data['PRCPTOP'].mean())
    SDII_.append(data['SDII'].mean())
    RX1D_.append(data['RX1D'].mean())
    RX5D_.append(data['RX5D'].mean())
    R95p_.append(data['R95p'].mean())
    R95T_.append(data['R95T'].mean())
    R99p_.append(data['R99p'].mean())
    R99T_.append(data['R99T'].mean())
    CWD_.append(data['CWD'].mean())
    CDD_.append(data['CDD'].mean())
    R10MM_.append(data['R10MM'].mean())
    R20MM_.append(data['R20MM'].mean())
    R25MM_.append(data['R25MM'].mean())
    R50MM_.append(data['R50MM'].mean())
    R65MM_.append(data['R65MM'].mean())
    R115MM_.append(data['R115MM'].mean())
    R205MM_.append(data['R205MM'].mean())
    
filename = os.listdir('C:/Users/***/Desktop/500_100/DongBei')
PRCPTOP_DongBei = []
SDII_DongBei = []
RX1D_DongBei = []
RX5D_DongBei = []
R95p_DongBei = []
R95T_DongBei = []
R99p_DongBei = []
R99T_DongBei = []
CWD_DongBei= []
CDD_DongBei = []
R10MM_DongBei = []
R20MM_DongBei = []
R25MM_DongBei = []
R50MM_DongBei = []
R65MM_DongBei = []
R115MM_DongBei = []
R205MM_DongBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/DongBei/{}'.format(i))
    PRCPTOP_DongBei.append(data['PRCPTOP'].mean())
    SDII_DongBei.append(data['SDII'].mean())
    RX1D_DongBei.append(data['RX1D'].mean())
    RX5D_DongBei.append(data['RX5D'].mean())
    R95p_DongBei.append(data['R95p'].mean())
    R95T_DongBei.append(data['R95T'].mean())
    R99p_DongBei.append(data['R99p'].mean())
    R99T_DongBei.append(data['R99T'].mean())
    CWD_DongBei.append(data['CWD'].mean())
    CDD_DongBei.append(data['CDD'].mean())
    R10MM_DongBei.append(data['R10MM'].mean())
    R20MM_DongBei.append(data['R20MM'].mean())
    R25MM_DongBei.append(data['R25MM'].mean())
    R50MM_DongBei.append(data['R50MM'].mean())
    R65MM_DongBei.append(data['R65MM'].mean())
    R115MM_DongBei.append(data['R115MM'].mean())
    R205MM_DongBei.append(data['R205MM'].mean())
    
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaBei')
PRCPTOP_HuaBei = []
SDII_HuaBei = []
RX1D_HuaBei = []
RX5D_HuaBei = []
R95p_HuaBei = []
R95T_HuaBei = []
R99p_HuaBei = []
R99T_HuaBei = []
CWD_HuaBei= []
CDD_HuaBei = []
R10MM_HuaBei = []
R20MM_HuaBei = []
R25MM_HuaBei = []
R50MM_HuaBei = []
R65MM_HuaBei = []
R115MM_HuaBei = []
R205MM_HuaBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaBei/{}'.format(i))
    PRCPTOP_HuaBei.append(data['PRCPTOP'].mean())
    SDII_HuaBei.append(data['SDII'].mean())
    RX1D_HuaBei.append(data['RX1D'].mean())
    RX5D_HuaBei.append(data['RX5D'].mean())
    R95p_HuaBei.append(data['R95p'].mean())
    R95T_HuaBei.append(data['R95T'].mean())
    R99p_HuaBei.append(data['R99p'].mean())
    R99T_HuaBei.append(data['R99T'].mean())
    CWD_HuaBei.append(data['CWD'].mean())
    CDD_HuaBei.append(data['CDD'].mean())
    R10MM_HuaBei.append(data['R10MM'].mean())
    R20MM_HuaBei.append(data['R20MM'].mean())
    R25MM_HuaBei.append(data['R25MM'].mean())
    R50MM_HuaBei.append(data['R50MM'].mean())
    R65MM_HuaBei.append(data['R65MM'].mean())
    R115MM_HuaBei.append(data['R115MM'].mean())
    R205MM_HuaBei.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaDong')
PRCPTOP_HuaDong = []
SDII_HuaDong = []
RX1D_HuaDong = []
RX5D_HuaDong = []
R95p_HuaDong = []
R95T_HuaDong = []
R99p_HuaDong = []
R99T_HuaDong = []
CWD_HuaDong = []
CDD_HuaDong = []
R10MM_HuaDong = []
R20MM_HuaDong = []
R25MM_HuaDong = []
R50MM_HuaDong = []
R65MM_HuaDong = []
R115MM_HuaDong = []
R205MM_HuaDong = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaDong/{}'.format(i))
    PRCPTOP_HuaDong.append(data['PRCPTOP'].mean())
    SDII_HuaDong.append(data['SDII'].mean())
    RX1D_HuaDong.append(data['RX1D'].mean())
    RX5D_HuaDong.append(data['RX5D'].mean())
    R95p_HuaDong.append(data['R95p'].mean())
    R95T_HuaDong.append(data['R95T'].mean())
    R99p_HuaDong.append(data['R99p'].mean())
    R99T_HuaDong.append(data['R99T'].mean())
    CWD_HuaDong.append(data['CWD'].mean())
    CDD_HuaDong.append(data['CDD'].mean())
    R10MM_HuaDong.append(data['R10MM'].mean())
    R20MM_HuaDong.append(data['R20MM'].mean())
    R25MM_HuaDong.append(data['R25MM'].mean())
    R50MM_HuaDong.append(data['R50MM'].mean())
    R65MM_HuaDong.append(data['R65MM'].mean())
    R115MM_HuaDong.append(data['R115MM'].mean())
    R205MM_HuaDong.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaNan')
PRCPTOP_HuaNan = []
SDII_HuaNan = []
RX1D_HuaNan = []
RX5D_HuaNan = []
R95p_HuaNan = []
R95T_HuaNan = []
R99p_HuaNan = []
R99T_HuaNan = []
CWD_HuaNan = []
CDD_HuaNan = []
R10MM_HuaNan = []
R20MM_HuaNan = []
R25MM_HuaNan = []
R50MM_HuaNan = []
R65MM_HuaNan = []
R115MM_HuaNan = []
R205MM_HuaNan = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaNan/{}'.format(i))
    PRCPTOP_HuaNan.append(data['PRCPTOP'].mean())
    SDII_HuaNan.append(data['SDII'].mean())
    RX1D_HuaNan.append(data['RX1D'].mean())
    RX5D_HuaNan.append(data['RX5D'].mean())
    R95p_HuaNan.append(data['R95p'].mean())
    R95T_HuaNan.append(data['R95T'].mean())
    R99p_HuaNan.append(data['R99p'].mean())
    R99T_HuaNan.append(data['R99T'].mean())
    CWD_HuaNan.append(data['CWD'].mean())
    CDD_HuaNan.append(data['CDD'].mean())
    R10MM_HuaNan.append(data['R10MM'].mean())
    R20MM_HuaNan.append(data['R20MM'].mean())
    R25MM_HuaNan.append(data['R25MM'].mean())
    R50MM_HuaNan.append(data['R50MM'].mean())
    R65MM_HuaNan.append(data['R65MM'].mean())
    R115MM_HuaNan.append(data['R115MM'].mean())
    R205MM_HuaNan.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaZhong')
PRCPTOP_HuaZhong = []
SDII_HuaZhong = []
RX1D_HuaZhong = []
RX5D_HuaZhong = []
R95p_HuaZhong = []
R95T_HuaZhong = []
R99p_HuaZhong = []
R99T_HuaZhong = []
CWD_HuaZhong = []
CDD_HuaZhong = []
R10MM_HuaZhong = []
R20MM_HuaZhong = []
R25MM_HuaZhong = []
R50MM_HuaZhong = []
R65MM_HuaZhong = []
R115MM_HuaZhong = []
R205MM_HuaZhong = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaZhong/{}'.format(i))
    PRCPTOP_HuaZhong.append(data['PRCPTOP'].mean())
    SDII_HuaZhong.append(data['SDII'].mean())
    RX1D_HuaZhong.append(data['RX1D'].mean())
    RX5D_HuaZhong.append(data['RX5D'].mean())
    R95p_HuaZhong.append(data['R95p'].mean())
    R95T_HuaZhong.append(data['R95T'].mean())
    R99p_HuaZhong.append(data['R99p'].mean())
    R99T_HuaZhong.append(data['R99T'].mean())
    CWD_HuaZhong.append(data['CWD'].mean())
    CDD_HuaZhong.append(data['CDD'].mean())
    R10MM_HuaZhong.append(data['R10MM'].mean())
    R20MM_HuaZhong.append(data['R20MM'].mean())
    R25MM_HuaZhong.append(data['R25MM'].mean())
    R50MM_HuaZhong.append(data['R50MM'].mean())
    R65MM_HuaZhong.append(data['R65MM'].mean())
    R115MM_HuaZhong.append(data['R115MM'].mean())
    R205MM_HuaZhong.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/XiBei')
PRCPTOP_XiBei = []
SDII_XiBei = []
RX1D_XiBei = []
RX5D_XiBei = []
R95p_XiBei = []
R95T_XiBei = []
R99p_XiBei = []
R99T_XiBei = []
CWD_XiBei = []
CDD_XiBei = []
R10MM_XiBei = []
R20MM_XiBei = []
R25MM_XiBei = []
R50MM_XiBei = []
R65MM_XiBei = []
R115MM_XiBei = []
R205MM_XiBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/XiBei/{}'.format(i))
    PRCPTOP_XiBei.append(data['PRCPTOP'].mean())
    SDII_XiBei.append(data['SDII'].mean())
    RX1D_XiBei.append(data['RX1D'].mean())
    RX5D_XiBei.append(data['RX5D'].mean())
    R95p_XiBei.append(data['R95p'].mean())
    R95T_XiBei.append(data['R95T'].mean())
    R99p_XiBei.append(data['R99p'].mean())
    R99T_XiBei.append(data['R99T'].mean())
    CWD_XiBei.append(data['CWD'].mean())
    CDD_XiBei.append(data['CDD'].mean())
    R10MM_XiBei.append(data['R10MM'].mean())
    R20MM_XiBei.append(data['R20MM'].mean())
    R25MM_XiBei.append(data['R25MM'].mean())
    R50MM_XiBei.append(data['R50MM'].mean())
    R65MM_XiBei.append(data['R65MM'].mean())
    R115MM_XiBei.append(data['R115MM'].mean())
    R205MM_XiBei.append(data['R205MM'].mean())

filename = os.listdir('C:/Users/***/Desktop/500_100/XiNan')
PRCPTOP_XiNan = []
SDII_XiNan = []
RX1D_XiNan = []
RX5D_XiNan = []
R95p_XiNan = []
R95T_XiNan = []
R99p_XiNan = []
R99T_XiNan = []
CWD_XiNan = []
CDD_XiNan = []
R10MM_XiNan = []
R20MM_XiNan = []
R25MM_XiNan = []
R50MM_XiNan = []
R65MM_XiNan = []
R115MM_XiNan = []
R205MM_XiNan = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/XiNan/{}'.format(i))
    PRCPTOP_XiNan.append(data['PRCPTOP'].mean())
    SDII_XiNan.append(data['SDII'].mean())
    RX1D_XiNan.append(data['RX1D'].mean())
    RX5D_XiNan.append(data['RX5D'].mean())
    R95p_XiNan.append(data['R95p'].mean())
    R95T_XiNan.append(data['R95T'].mean())
    R99p_XiNan.append(data['R99p'].mean())
    R99T_XiNan.append(data['R99T'].mean())
    CWD_XiNan.append(data['CWD'].mean())
    CDD_XiNan.append(data['CDD'].mean())
    R10MM_XiNan.append(data['R10MM'].mean())
    R20MM_XiNan.append(data['R20MM'].mean())
    R25MM_XiNan.append(data['R25MM'].mean())
    R50MM_XiNan.append(data['R50MM'].mean())
    R65MM_XiNan.append(data['R65MM'].mean())
    R115MM_XiNan.append(data['R115MM'].mean())
    R205MM_XiNan.append(data['R205MM'].mean())
    
fig = sns.kdeplot(CWD_, color="darkorange", cut=0, linewidth = 3)
fig = sns.kdeplot(CWD_DongBei, color="r", cut=0, linewidth = 3)
fig = sns.kdeplot(CWD_HuaBei, color="mediumaquamarine", cut=0, linewidth = 3)
fig = sns.kdeplot(CWD_HuaDong, color="peru", cut=0, linewidth = 3)
fig = sns.kdeplot(CWD_HuaNan, color="tan", cut=0, linewidth = 3)
fig = sns.kdeplot(CWD_HuaZhong, color="teal", cut=0, linewidth = 3)
fig = sns.kdeplot(CWD_XiBei, color="deepskyblue", cut=0, linewidth = 3)
fig = sns.kdeplot(CWD_XiNan, color="b", cut=0, linewidth = 3)
plt.title('CWD',fontdict={'weight':'bold','size': 14})
col_labels = ['District','Mean']
table_vals = [['All',round(np.mean(CWD_))],['DongBei',round(np.mean(CWD_DongBei))],['HuaBei',round(np.mean(CWD_HuaBei))],['HuaDong',round(np.mean(CWD_HuaDong))],['HuaNan',round(np.mean(CWD_HuaNan))],['HuaZhong',round(np.mean(CWD_HuaZhong))],['XiBei',round(np.mean(CWD_XiBei))],['XiNan',round(np.mean(CWD_XiNan))]]
my_table = plt.table(cellText=table_vals, colWidths=[0.1]*8, colLabels=col_labels, loc='best', cellLoc='center', colColours=['gold','gold'])
my_table.scale(1.8, 1.6)
my_table.auto_set_font_size(False)
my_table.set_fontsize(11)
sns.despine()
fig.set_xlabel("CWD(day)", fontsize = 10, weight='bold', style='italic')
ax = plt.gca()
plt.text(-0.15,1, '(i)', fontsize=16, color='k',weight='bold', transform=ax.transAxes)
fig.set_xlim([0.5, 32.5])
fig.set_ylabel('')
plt.savefig('CWD.tiff', dpi = 600)

sns.set(style='darkgrid')
Districts = ['All']*15388+['DongBei']*1424+['HuaBei']*2572+['HuaDong']*1219+['HuaNan']*641+['HuaZhong']*852+['XiBei']*4901+['XiNan']*3445
df = pd.DataFrame({'Districts' : Districts, 
                  'CWD' : CWD_+CWD_DongBei+CWD_HuaBei+CWD_HuaDong+CWD_HuaNan+CWD_HuaZhong+CWD_XiBei+CWD_XiNan})
plt.title('CWD',fontdict={'weight':'bold','size': 14})
fig = sns.violinplot(x='Districts', y='CWD', data=df, linewidth=0.8, palette='Set3', scale='width')
fig.set_ylabel('Density(day)',fontsize = 10, weight='bold', style='italic')
fig.set_xlabel('')
fig.set_xticklabels(labels=['All','DongBei','HuaBei','HuaDong','HuaNan','HuaZhong','XiBei','XiNan'], rotation = 15, fontsize = 10)
ax = plt.gca()
plt.text(-0.15,1, '(i)', fontsize=16, color='k',weight='bold', transform=ax.transAxes)
plt.savefig('CWD.tiff', dpi =600)

sns.set(style='ticks')
filename = os.listdir('C:/Users/***/Desktop/500_100/precip_r')
CWD = pd.DataFrame()
for name in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/precip_r/{}'.format(name))
    CWD.insert(loc=len(CWD.columns), column=name, value=list(data['CWD']))
results = list(CWD.mean(axis=1))
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
years = [i for i in range(1961,2020)]
plt.xticks(years)
ax1.set_xticks([1961,1965,1970,1975,1980,1985,1990,1995,2000,2005,2010,2015,2019])
ax1.set_xticklabels(['1961','1965','1970','1975','1980','1985','1990','1995','2000','2005','2010','2015','2019'], fontsize = 14)
ax1.set_ylabel('CWD(days)', fontsize=16, weight='bold')
ax1.tick_params(axis='y', colors='navy', labelsize=12)
ax1.plot(years, results, 'b--', color = "deepskyblue")
sns.regplot(years, results, color='darkorange')
ax = plt.gca()
plt.text(-0.08,1, '(i)', fontsize=22, color='k', weight='bold', transform=ax.transAxes)
plt.savefig('CWD.tiff',dpi = 600)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import pandas as pd
sns.set(style='ticks')
Districts = ['All of China','DongBei','HuaBei','HuaDong','HuaNan','HuaZhong','XiBei','XiNan']

filename = os.listdir('C:/Users/***/Desktop/500_100/precip_r')
PRCPTOP_ = []
SDII_ = []
RX1D_ = []
RX5D_ = []
R95p_ = []
R95T_ = []
R99p_ = []
R99T_ = []
CWD_ = []
CDD_ = []
R10MM_ = []
R20MM_ = []
R25MM_ = []
R50MM_ = []
R65MM_ = []
R115MM_ = []
R205MM_ = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/precip_r/{}'.format(i))
    PRCPTOP_.append(data['PRCPTOP'].mean())
    SDII_.append(data['SDII'].mean())
    RX1D_.append(data['RX1D'].mean())
    RX5D_.append(data['RX5D'].mean())
    R95p_.append(data['R95p'].mean())
    R95T_.append(data['R95T'].mean())
    R99p_.append(data['R99p'].mean())
    R99T_.append(data['R99T'].mean())
    CWD_.append(data['CWD'].mean())
    CDD_.append(data['CDD'].mean())
    R10MM_.append(data['R10MM'].mean())
    R20MM_.append(data['R20MM'].mean())
    R25MM_.append(data['R25MM'].mean())
    R50MM_.append(data['R50MM'].mean())
    R65MM_.append(data['R65MM'].mean())
    R115MM_.append(data['R115MM'].mean())
    R205MM_.append(data['R205MM'].mean())
    
filename = os.listdir('C:/Users/***/Desktop/500_100/DongBei')
PRCPTOP_DongBei = []
SDII_DongBei = []
RX1D_DongBei = []
RX5D_DongBei = []
R95p_DongBei = []
R95T_DongBei = []
R99p_DongBei = []
R99T_DongBei = []
CWD_DongBei= []
CDD_DongBei = []
R10MM_DongBei = []
R20MM_DongBei = []
R25MM_DongBei = []
R50MM_DongBei = []
R65MM_DongBei = []
R115MM_DongBei = []
R205MM_DongBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/DongBei/{}'.format(i))
    PRCPTOP_DongBei.append(data['PRCPTOP'].mean())
    SDII_DongBei.append(data['SDII'].mean())
    RX1D_DongBei.append(data['RX1D'].mean())
    RX5D_DongBei.append(data['RX5D'].mean())
    R95p_DongBei.append(data['R95p'].mean())
    R95T_DongBei.append(data['R95T'].mean())
    R99p_DongBei.append(data['R99p'].mean())
    R99T_DongBei.append(data['R99T'].mean())
    CWD_DongBei.append(data['CWD'].mean())
    CDD_DongBei.append(data['CDD'].mean())
    R10MM_DongBei.append(data['R10MM'].mean())
    R20MM_DongBei.append(data['R20MM'].mean())
    R25MM_DongBei.append(data['R25MM'].mean())
    R50MM_DongBei.append(data['R50MM'].mean())
    R65MM_DongBei.append(data['R65MM'].mean())
    R115MM_DongBei.append(data['R115MM'].mean())
    R205MM_DongBei.append(data['R205MM'].mean())
    
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaBei')
PRCPTOP_HuaBei = []
SDII_HuaBei = []
RX1D_HuaBei = []
RX5D_HuaBei = []
R95p_HuaBei = []
R95T_HuaBei = []
R99p_HuaBei = []
R99T_HuaBei = []
CWD_HuaBei= []
CDD_HuaBei = []
R10MM_HuaBei = []
R20MM_HuaBei = []
R25MM_HuaBei = []
R50MM_HuaBei = []
R65MM_HuaBei = []
R115MM_HuaBei = []
R205MM_HuaBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaBei/{}'.format(i))
    PRCPTOP_HuaBei.append(data['PRCPTOP'].mean())
    SDII_HuaBei.append(data['SDII'].mean())
    RX1D_HuaBei.append(data['RX1D'].mean())
    RX5D_HuaBei.append(data['RX5D'].mean())
    R95p_HuaBei.append(data['R95p'].mean())
    R95T_HuaBei.append(data['R95T'].mean())
    R99p_HuaBei.append(data['R99p'].mean())
    R99T_HuaBei.append(data['R99T'].mean())
    CWD_HuaBei.append(data['CWD'].mean())
    CDD_HuaBei.append(data['CDD'].mean())
    R10MM_HuaBei.append(data['R10MM'].mean())
    R20MM_HuaBei.append(data['R20MM'].mean())
    R25MM_HuaBei.append(data['R25MM'].mean())
    R50MM_HuaBei.append(data['R50MM'].mean())
    R65MM_HuaBei.append(data['R65MM'].mean())
    R115MM_HuaBei.append(data['R115MM'].mean())
    R205MM_HuaBei.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaDong')
PRCPTOP_HuaDong = []
SDII_HuaDong = []
RX1D_HuaDong = []
RX5D_HuaDong = []
R95p_HuaDong = []
R95T_HuaDong = []
R99p_HuaDong = []
R99T_HuaDong = []
CWD_HuaDong = []
CDD_HuaDong = []
R10MM_HuaDong = []
R20MM_HuaDong = []
R25MM_HuaDong = []
R50MM_HuaDong = []
R65MM_HuaDong = []
R115MM_HuaDong = []
R205MM_HuaDong = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaDong/{}'.format(i))
    PRCPTOP_HuaDong.append(data['PRCPTOP'].mean())
    SDII_HuaDong.append(data['SDII'].mean())
    RX1D_HuaDong.append(data['RX1D'].mean())
    RX5D_HuaDong.append(data['RX5D'].mean())
    R95p_HuaDong.append(data['R95p'].mean())
    R95T_HuaDong.append(data['R95T'].mean())
    R99p_HuaDong.append(data['R99p'].mean())
    R99T_HuaDong.append(data['R99T'].mean())
    CWD_HuaDong.append(data['CWD'].mean())
    CDD_HuaDong.append(data['CDD'].mean())
    R10MM_HuaDong.append(data['R10MM'].mean())
    R20MM_HuaDong.append(data['R20MM'].mean())
    R25MM_HuaDong.append(data['R25MM'].mean())
    R50MM_HuaDong.append(data['R50MM'].mean())
    R65MM_HuaDong.append(data['R65MM'].mean())
    R115MM_HuaDong.append(data['R115MM'].mean())
    R205MM_HuaDong.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaNan')
PRCPTOP_HuaNan = []
SDII_HuaNan = []
RX1D_HuaNan = []
RX5D_HuaNan = []
R95p_HuaNan = []
R95T_HuaNan = []
R99p_HuaNan = []
R99T_HuaNan = []
CWD_HuaNan = []
CDD_HuaNan = []
R10MM_HuaNan = []
R20MM_HuaNan = []
R25MM_HuaNan = []
R50MM_HuaNan = []
R65MM_HuaNan = []
R115MM_HuaNan = []
R205MM_HuaNan = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaNan/{}'.format(i))
    PRCPTOP_HuaNan.append(data['PRCPTOP'].mean())
    SDII_HuaNan.append(data['SDII'].mean())
    RX1D_HuaNan.append(data['RX1D'].mean())
    RX5D_HuaNan.append(data['RX5D'].mean())
    R95p_HuaNan.append(data['R95p'].mean())
    R95T_HuaNan.append(data['R95T'].mean())
    R99p_HuaNan.append(data['R99p'].mean())
    R99T_HuaNan.append(data['R99T'].mean())
    CWD_HuaNan.append(data['CWD'].mean())
    CDD_HuaNan.append(data['CDD'].mean())
    R10MM_HuaNan.append(data['R10MM'].mean())
    R20MM_HuaNan.append(data['R20MM'].mean())
    R25MM_HuaNan.append(data['R25MM'].mean())
    R50MM_HuaNan.append(data['R50MM'].mean())
    R65MM_HuaNan.append(data['R65MM'].mean())
    R115MM_HuaNan.append(data['R115MM'].mean())
    R205MM_HuaNan.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/HuaZhong')
PRCPTOP_HuaZhong = []
SDII_HuaZhong = []
RX1D_HuaZhong = []
RX5D_HuaZhong = []
R95p_HuaZhong = []
R95T_HuaZhong = []
R99p_HuaZhong = []
R99T_HuaZhong = []
CWD_HuaZhong = []
CDD_HuaZhong = []
R10MM_HuaZhong = []
R20MM_HuaZhong = []
R25MM_HuaZhong = []
R50MM_HuaZhong = []
R65MM_HuaZhong = []
R115MM_HuaZhong = []
R205MM_HuaZhong = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/HuaZhong/{}'.format(i))
    PRCPTOP_HuaZhong.append(data['PRCPTOP'].mean())
    SDII_HuaZhong.append(data['SDII'].mean())
    RX1D_HuaZhong.append(data['RX1D'].mean())
    RX5D_HuaZhong.append(data['RX5D'].mean())
    R95p_HuaZhong.append(data['R95p'].mean())
    R95T_HuaZhong.append(data['R95T'].mean())
    R99p_HuaZhong.append(data['R99p'].mean())
    R99T_HuaZhong.append(data['R99T'].mean())
    CWD_HuaZhong.append(data['CWD'].mean())
    CDD_HuaZhong.append(data['CDD'].mean())
    R10MM_HuaZhong.append(data['R10MM'].mean())
    R20MM_HuaZhong.append(data['R20MM'].mean())
    R25MM_HuaZhong.append(data['R25MM'].mean())
    R50MM_HuaZhong.append(data['R50MM'].mean())
    R65MM_HuaZhong.append(data['R65MM'].mean())
    R115MM_HuaZhong.append(data['R115MM'].mean())
    R205MM_HuaZhong.append(data['R205MM'].mean())
filename = os.listdir('C:/Users/***/Desktop/500_100/XiBei')
PRCPTOP_XiBei = []
SDII_XiBei = []
RX1D_XiBei = []
RX5D_XiBei = []
R95p_XiBei = []
R95T_XiBei = []
R99p_XiBei = []
R99T_XiBei = []
CWD_XiBei = []
CDD_XiBei = []
R10MM_XiBei = []
R20MM_XiBei = []
R25MM_XiBei = []
R50MM_XiBei = []
R65MM_XiBei = []
R115MM_XiBei = []
R205MM_XiBei = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/XiBei/{}'.format(i))
    PRCPTOP_XiBei.append(data['PRCPTOP'].mean())
    SDII_XiBei.append(data['SDII'].mean())
    RX1D_XiBei.append(data['RX1D'].mean())
    RX5D_XiBei.append(data['RX5D'].mean())
    R95p_XiBei.append(data['R95p'].mean())
    R95T_XiBei.append(data['R95T'].mean())
    R99p_XiBei.append(data['R99p'].mean())
    R99T_XiBei.append(data['R99T'].mean())
    CWD_XiBei.append(data['CWD'].mean())
    CDD_XiBei.append(data['CDD'].mean())
    R10MM_XiBei.append(data['R10MM'].mean())
    R20MM_XiBei.append(data['R20MM'].mean())
    R25MM_XiBei.append(data['R25MM'].mean())
    R50MM_XiBei.append(data['R50MM'].mean())
    R65MM_XiBei.append(data['R65MM'].mean())
    R115MM_XiBei.append(data['R115MM'].mean())
    R205MM_XiBei.append(data['R205MM'].mean())

filename = os.listdir('C:/Users/***/Desktop/500_100/XiNan')
PRCPTOP_XiNan = []
SDII_XiNan = []
RX1D_XiNan = []
RX5D_XiNan = []
R95p_XiNan = []
R95T_XiNan = []
R99p_XiNan = []
R99T_XiNan = []
CWD_XiNan = []
CDD_XiNan = []
R10MM_XiNan = []
R20MM_XiNan = []
R25MM_XiNan = []
R50MM_XiNan = []
R65MM_XiNan = []
R115MM_XiNan = []
R205MM_XiNan = []

for i in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/XiNan/{}'.format(i))
    PRCPTOP_XiNan.append(data['PRCPTOP'].mean())
    SDII_XiNan.append(data['SDII'].mean())
    RX1D_XiNan.append(data['RX1D'].mean())
    RX5D_XiNan.append(data['RX5D'].mean())
    R95p_XiNan.append(data['R95p'].mean())
    R95T_XiNan.append(data['R95T'].mean())
    R99p_XiNan.append(data['R99p'].mean())
    R99T_XiNan.append(data['R99T'].mean())
    CWD_XiNan.append(data['CWD'].mean())
    CDD_XiNan.append(data['CDD'].mean())
    R10MM_XiNan.append(data['R10MM'].mean())
    R20MM_XiNan.append(data['R20MM'].mean())
    R25MM_XiNan.append(data['R25MM'].mean())
    R50MM_XiNan.append(data['R50MM'].mean())
    R65MM_XiNan.append(data['R65MM'].mean())
    R115MM_XiNan.append(data['R115MM'].mean())
    R205MM_XiNan.append(data['R205MM'].mean())
    
fig = sns.kdeplot(CDD_, color="darkorange", cut=0, linewidth = 3)
fig = sns.kdeplot(CDD_DongBei, color="r", cut=0, linewidth = 3)
fig = sns.kdeplot(CDD_HuaBei, color="mediumaquamarine", cut=0, linewidth = 3)
fig = sns.kdeplot(CDD_HuaDong, color="peru", cut=0, linewidth = 3)
fig = sns.kdeplot(CDD_HuaNan, color="tan", cut=0, linewidth = 3)
fig = sns.kdeplot(CDD_HuaZhong, color="teal", cut=0, linewidth = 3)
fig = sns.kdeplot(CDD_XiBei, color="deepskyblue", cut=0, linewidth = 3)
fig = sns.kdeplot(CDD_XiNan, color="b", cut=0, linewidth = 3)
plt.title('CDD',fontdict={'weight':'bold','size': 14})
col_labels = ['District','Mean']
table_vals = [['All',round(np.mean(CDD_))],['DongBei',round(np.mean(CDD_DongBei))],['HuaBei',round(np.mean(CDD_HuaBei))],['HuaDong',round(np.mean(CDD_HuaDong))],['HuaNan',round(np.mean(CDD_HuaNan))],['HuaZhong',round(np.mean(CDD_HuaZhong))],['XiBei',round(np.mean(CDD_XiBei))],['XiNan',round(np.mean(CDD_XiNan))]]
my_table = plt.table(cellText=table_vals, colWidths=[0.1]*8, colLabels=col_labels, loc='best', cellLoc='center', colColours=['gold','gold'])
my_table.scale(1.8, 1.6)
my_table.auto_set_font_size(False)
my_table.set_fontsize(11)
sns.despine()
fig.set_xlabel("CDD(day)", fontsize = 10, weight='bold', style='italic')
ax = plt.gca()
plt.text(-0.15,1, '(j)', fontsize=16, color='k',weight='bold', transform=ax.transAxes)
fig.set_xlim([8, 180])
fig.set_ylabel('')
plt.savefig('CDD.tiff', dpi = 600)

sns.set(style='darkgrid')
Districts = ['All']*15388+['DongBei']*1424+['HuaBei']*2572+['HuaDong']*1219+['HuaNan']*641+['HuaZhong']*852+['XiBei']*4901+['XiNan']*3445
df = pd.DataFrame({'Districts' : Districts, 
                  'CDD' : CDD_+CDD_DongBei+CDD_HuaBei+CDD_HuaDong+CDD_HuaNan+CDD_HuaZhong+CDD_XiBei+CDD_XiNan})
plt.title('CDD',fontdict={'weight':'bold','size': 14})
fig = sns.violinplot(x='Districts', y='CDD', data=df, linewidth=0.8, palette='Set3', scale='width')
fig.set_ylabel('Density(day)',fontsize = 10, weight='bold', style='italic')
fig.set_xlabel('')
fig.set_xticklabels(labels=['All','DongBei','HuaBei','HuaDong','HuaNan','HuaZhong','XiBei','XiNan'], rotation = 15, fontsize = 10)
ax = plt.gca()
plt.text(-0.15,1, '(j)', fontsize=16, color='k',weight='bold', transform=ax.transAxes)
plt.savefig('CDD.tiff', dpi =600)

sns.set(style='ticks')
filename = os.listdir('C:/Users/***/Desktop/500_100/precip_r')
CDD = pd.DataFrame()
for name in filename:
    data = pd.read_csv('C:/Users/***/Desktop/500_100/precip_r/{}'.format(name))
    CDD.insert(loc=len(CDD.columns), column=name, value=list(data['CDD']))
results = list(CDD.mean(axis=1))
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
years = [i for i in range(1961,2020)]
plt.xticks(years)
ax1.set_xticks([1961,1965,1970,1975,1980,1985,1990,1995,2000,2005,2010,2015,2019])
ax1.set_xticklabels(['1961','1965','1970','1975','1980','1985','1990','1995','2000','2005','2010','2015','2019'], fontsize = 14)
ax1.set_ylabel('CDD(days)', fontsize=16, weight='bold')
ax1.tick_params(axis='y', colors='navy', labelsize=12)
ax1.plot(years, results, 'b--', color = "deepskyblue")
sns.regplot(years, results, color='darkorange')
ax = plt.gca()
plt.text(-0.08,1, '(i)', fontsize=22, color='k', weight='bold', transform=ax.transAxes)
plt.savefig('CDD.tiff',dpi = 600)
