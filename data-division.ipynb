# %%
import numpy as np
import os
from scipy import optimize
import pandas as pd
import math 
import xarray as xr
from shutil import copy
filename = os.listdir('C:/Users/***/Desktop/7_dis/DongBei')
for i in range(len(filename)):
    path = 'C:/Users/***/Desktop/7_dis/DongBei/{}'.format(filename[i])
    file = xr.open_dataset(path) 
    lat = np.array(file['lat'])
    lon = np.array(file['lon'])
    lp=[]
    for i in range(len(lat)):
        for j in range(len(lon)):
            if file['1961-2019 logistic values'][i,j]>0:
                lp.append((lat[i],lon[j]))
    file_list = [str(i[0])+'_'+str(i[1])+'.csv' for i in lp]
    for a in file_list:
        old_path = 'C:/Users/***/Desktop/500_100/all'
        new_path = 'C:/Users/***/Desktop/500_100/7_dis/DongBei' 
        from_path = old_path + "/" + a
        to_path = new_path + "/" + a 
        copy(from_path, to_path)

filename = os.listdir('C:/Users/***/Desktop/7_dis/HuaBei')
for i in range(len(filename)):
    path = 'C:/Users/***/Desktop/7_dis/HuaBei/{}'.format(filename[i])
    file = xr.open_dataset(path) 
    lat = np.array(file['lat'])
    lon = np.array(file['lon'])
    lp=[]
    for i in range(len(lat)):
        for j in range(len(lon)):
            if file['1961-2019 logistic values'][i,j]>0:
                lp.append((lat[i],lon[j]))
    file_list = [str(i[0])+'_'+str(i[1])+'.csv' for i in lp]
    for a in file_list:
        old_path = 'C:/Users/***/Desktop/500_100/all' 
        new_path = 'C:/Users/***/Desktop/500_100/7_dis/HuaBei'   
        from_path = old_path + "/" + a  
        to_path = new_path + "/" + a   
        copy(from_path, to_path)
        
filename = os.listdir('C:/Users/***/Desktop/7_dis/HuaDong')
for i in range(len(filename)):
    path = 'C:/Users/***/Desktop/7_dis/HuaDong/{}'.format(filename[i])
    file = xr.open_dataset(path) 
    lat = np.array(file['lat'])
    lon = np.array(file['lon'])
    lp=[]
    for i in range(len(lat)):
        for j in range(len(lon)):
            if file['1961-2019 logistic values'][i,j]>0:
                lp.append((lat[i],lon[j]))
    file_list = [str(i[0])+'_'+str(i[1])+'.csv' for i in lp]
    for a in file_list:
        old_path = 'C:/Users/***/Desktop/500_100/all' 
        new_path = 'C:/Users/***/Desktop/500_100/7_dis/HuaDong' 
        from_path = old_path + "/" + a  
        to_path = new_path + "/" + a    
        copy(from_path, to_path) 
        
filename = os.listdir('C:/Users/***/Desktop/7_dis/HuaNan')
for i in range(len(filename)):
    path = 'C:/Users/***/Desktop/7_dis/HuaNan/{}'.format(filename[i])
    file = xr.open_dataset(path) 
    lat = np.array(file['lat'])
    lon = np.array(file['lon'])
    lp=[]
    for i in range(len(lat)):
        for j in range(len(lon)):
            if file['1961-2019 logistic values'][i,j]>0:
                lp.append((lat[i],lon[j]))
    file_list = [str(i[0])+'_'+str(i[1])+'.csv' for i in lp]
    for a in file_list:
        old_path = 'C:/Users/***/Desktop/500_100/all'  
        new_path = 'C:/Users/***/Desktop/500_100/7_dis/HuaNan' 
        from_path = old_path + "/" + a  
        to_path = new_path + "/" + a  
        copy(from_path, to_path) 
        
filename = os.listdir('C:/Users/***/Desktop/7_dis/HuaZhong')
for i in range(len(filename)):
    path = 'C:/Users/***/Desktop/7_dis/HuaZhong/{}'.format(filename[i])
    file = xr.open_dataset(path) 
    lat = np.array(file['lat'])
    lon = np.array(file['lon'])
    lp=[]
    for i in range(len(lat)):
        for j in range(len(lon)):
            if file['1961-2019 logistic values'][i,j]>0:
                lp.append((lat[i],lon[j]))
    file_list = [str(i[0])+'_'+str(i[1])+'.csv' for i in lp]
    for a in file_list:
        old_path = 'C:/Users/***/Desktop/500_100/all'  
        new_path = 'C:/Users/***/Desktop/500_100/7_dis/HuaZhong'   
        from_path = old_path + "/" + a   
        to_path = new_path + "/" + a    
        copy(from_path, to_path)  
        
filename = os.listdir('C:/Users/***/Desktop/7_dis/XiBei')
for i in range(len(filename)):
    path = 'C:/Users/***/Desktop/7_dis/XiBei/{}'.format(filename[i])
    file = xr.open_dataset(path) 
    lat = np.array(file['lat'])
    lon = np.array(file['lon'])
    lp=[]
    for i in range(len(lat)):
        for j in range(len(lon)):
            if file['1961-2019 logistic values'][i,j]>0:
                lp.append((lat[i],lon[j]))
    file_list = [str(i[0])+'_'+str(i[1])+'.csv' for i in lp]
    for a in file_list:
        old_path = 'C:/Users/***/Desktop/500_100/all'  
        new_path = 'C:/Users/***/Desktop/500_100/7_dis/XiBei'
        from_path = old_path + "/" + a  
        to_path = new_path + "/" + a  
        copy(from_path, to_path)
        
filename = os.listdir('C:/Users/***/Desktop/7_dis/XiNan')
for i in range(len(filename)):
    path = 'C:/Users/***/Desktop/7_dis/XiNan/{}'.format(filename[i])
    file = xr.open_dataset(path) 
    lat = np.array(file['lat'])
    lon = np.array(file['lon'])
    lp=[]
    for i in range(len(lat)):
        for j in range(len(lon)):
            if file['1961-2019 logistic values'][i,j]>0:
                lp.append((lat[i],lon[j]))
    file_list = [str(i[0])+'_'+str(i[1])+'.csv' for i in lp]
    for a in file_list:
        old_path = 'C:/Users/***/Desktop/500_100/all'
        new_path = 'C:/Users/***/Desktop/500_100/7_dis/XiNan'  
        from_path = old_path + "/" + a  
        to_path = new_path + "/" + a   
        copy(from_path, to_path)
